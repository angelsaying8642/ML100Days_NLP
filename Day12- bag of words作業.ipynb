# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
corpus[0]
# Out:
# 'Wow... Loved this place.'

# %%
nltk.word_tokenize(corpus[0])
# Out:
# ['Wow', '...', 'Loved', 'this', 'place', '.']

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
len(set(whole_words))
# Out:
# 2351

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2351個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
whole_words
# Out:
# {'lady',
#  'events',
#  'AVOID',
#  '....',
#  'thumbs',
#  'raspberry',
#  'connoisseur',
#  'when',
#  'box',
#  'unhealthy',
#  'Went',
#  'Taco',
#  'go',
#  'Stars',
#  'evening',
#  'similar',
#  'finish',
#  'tastings',
#  'decorated',
#  'warm',
#  'next',
#  'Outstanding',
#  'dates',
#  'beef',
#  'When',
#  'Everyone',
#  'correct',
#  'massive',
#  'hardly',
#  'Lox',
#  'restaurants',
#  'sever',
#  'Point',
#  'wine',
#  'without',
#  '11.99',
#  'gave',
#  'Tasty',
#  'Christmas',
#  'paid',
#  'Ganoush',
#  'bill',
#  'Poor',
#  'from',
#  'Last',
#  'rushed',
#  'space',
#  'nutshell',
#  'large',
#  'market',
#  'rings',
#  'definately',
#  'egg',
#  'legs',
#  'packed',
#  'die',
#  'myself',
#  'lot',
#  'buffets',
#  'stood',
#  'email',
#  'mein',
#  'bamboo',
#  'bar',
#  'foot',
#  'jerk',
#  'dinners',
#  'brownish',
#  'Always',
#  'pack',
#  'barely',
#  'authentic',
#  'perpared',
#  'drawing',
#  'joint',
#  'Soups',
#  'greasy',
#  'six',
#  'bathroom',
#  'roast',
#  'solid',
#  'almost',
#  'door',
#  'same',
#  'drunk',
#  '*',
#  'somewhat',
#  'weekend',
#  'problem',
#  'disappoint',
#  'Fridays',
#  'hearts',
#  'tapas',
#  'donut',
#  'lunch',
#  'imagined',
#  'providing',
#  'day',
#  'Veggitarian',
#  'hereas',
#  'Mary',
#  'today',
#  'impressive',
#  'SCREAMS',
#  'caterpillar',
#  'light',
#  'dressed',
#  'disagree',
#  'hands-down',
#  'certainly',
#  'attentive',
#  'crust',
#  'raving',
#  'speedy',
#  'naan',
#  'stomach',
#  'are',
#  'Tucson',
#  'struck',
#  'such',
#  'smoothies',
#  'meals',
#  'Standard',
#  'towards',
#  'between',
#  'trying',
#  'totally',
#  'Wo',
#  'end',
#  'pancake',
#  'airline',
#  'apparently',
#  'red',
#  'highly',
#  'Panna',
#  'Big',
#  'uploaded',
#  'baklava',
#  'equally',
#  'business',
#  'attached',
#  'Bean',
#  "'s",
#  'fails',
#  'shoots',
#  'over-whelm',
#  'Sadly',
#  'NO',
#  'expectations',
#  'Han',
#  'poisoning',
#  '2',
#  'sticks',
#  'Nan',
#  'jalapeno',
#  'chains',
#  'appetizers',
#  'Blah',
#  'portion',
#  'papers',
#  'grocery',
#  'pissd',
#  'tartare',
#  'mixed',
#  'discount',
#  'disappointment',
#  'personable',
#  'Then',
#  'Your',
#  'arrives',
#  'promise',
#  'anticipated',
#  'cold',
#  'Large',
#  'Which',
#  'covers',
#  'WILL',
#  'single',
#  'word',
#  'bartenders',
#  'small',
#  '6',
#  'Four',
#  'By',
#  'folks',
#  'Voodoo',
#  'take',
#  'Every',
#  'familiar',
#  'tasteless',
#  'hella',
#  'OMG',
#  'Nice',
#  'judging',
#  'WAAAAAAyyyyyyyyyy',
#  'sunglasses',
#  'spring',
#  'companions',
#  'fine',
#  'Sushi',
#  'patron',
#  'leave',
#  'real',
#  'bunch',
#  'serves',
#  'out',
#  'quality',
#  'sorely',
#  'idea',
#  'quit',
#  'ribeye',
#  'simple',
#  'uninspired',
#  'version',
#  'unexperienced',
#  'law',
#  '5',
#  'MUST',
#  'positive',
#  'Back',
#  'garden',
#  'profound',
#  'their',
#  "n't",
#  'These',
#  'thats',
#  'looking',
#  'Pizza',
#  'plus',
#  'amazing',
#  'friend',
#  'mom',
#  'letdown',
#  'The',
#  'Hard',
#  'him',
#  'believe',
#  'ball',
#  'took',
#  'stuff',
#  'outstanding',
#  'You',
#  '/hand',
#  'rest',
#  'takeout',
#  'yukon',
#  'callings',
#  'reasons',
#  'blanket',
#  'else',
#  'multiple',
#  'which',
#  'dessert',
#  'first',
#  'larger',
#  'work',
#  'besides',
#  'regular',
#  '8',
#  'cannoli',
#  'olives',
#  'lived',
#  'Bellagio',
#  'seasoned',
#  'each',
#  'Jeff',
#  'better',
#  'he',
#  '45',
#  'circumstances',
#  'clean',
#  'seemed',
#  'nay',
#  'Insults',
#  'muffin',
#  'lacking',
#  'correction',
#  'giant',
#  'Appetite',
#  'too',
#  'However',
#  'wrapped',
#  'beer',
#  'live',
#  'accountant',
#  'pepper',
#  'hole',
#  'strawberry',
#  'until',
#  'again',
#  'side',
#  'ever',
#  'pastry',
#  'above',
#  'ordered',
#  'either',
#  'breakfast',
#  'professional',
#  '15',
#  'read',
#  'whatsoever',
#  'sad',
#  'Eclectic',
#  'home',
#  'funny',
#  'high',
#  'asking',
#  'Noca',
#  'Greek',
#  'mussels',
#  'Yelpers',
#  'this',
#  'wines',
#  'deep',
#  'drag',
#  'tell',
#  'decent',
#  'want',
#  'ethic',
#  'sore',
#  'High-quality',
#  'edible',
#  'REALLY',
#  'turn',
#  'delight',
#  'Loved',
#  'Soi',
#  'beers',
#  'were',
#  'Heimer',
#  'Delicious',
#  'recommended',
#  'LEGIT',
#  'bars',
#  'teeth',
#  'saganaki',
#  'wildly',
#  'ALL',
#  'dedicated',
#  'why',
#  'nachos',
#  'second',
#  'changing',
#  'wontons',
#  'family',
#  'consider',
#  'smells',
#  'expert/connisseur',
#  'temp.I',
#  'experience',
#  'hostess',
#  'return',
#  'cover',
#  'itself',
#  'dealing',
#  'enjoyable',
#  'pneumatic',
#  'Seat',
#  'metro',
#  'Bacon',
#  'drastically',
#  'special',
#  'That',
#  'disgrace',
#  'Mom',
#  'cute',
#  'combination',
#  'sucker',
#  'flat',
#  'flair',
#  'most',
#  'suggestions',
#  'sexy',
#  'After',
#  'perfection',
#  'crusty',
#  'brisket',
#  'care',
#  'loves',
#  'mouth',
#  'Thai',
#  'unbelievable',
#  'happened',
#  '35',
#  'incredible',
#  'felt',
#  'Caesar',
#  'T.',
#  'pork',
#  'bloodiest',
#  'Baseball',
#  'bloddy',
#  'An',
#  'cocktails',
#  'during',
#  'Although',
#  'Phoenix',
#  'leftover',
#  'Sprouts',
#  'establishment',
#  'vegetables',
#  'Madison',
#  'compliments',
#  'sides',
#  'transcendant',
#  'about',
#  'Ians',
#  'welcome',
#  'bartender',
#  'deserves',
#  '70+',
#  'Elk',
#  'Chinese',
#  'who',
#  'restaraunt',
#  'mac',
#  'years',
#  'eggplant',
#  'lacked',
#  'play',
#  'courteous',
#  'front',
#  'dish',
#  'Bisque',
#  'visited',
#  'tepid',
#  '4.00',
#  'IN',
#  'Worst',
#  'whether',
#  'swung',
#  'North',
#  'tuna',
#  'Dos',
#  'Really',
#  'sucked',
#  'climbing',
#  'and',
#  'shoe',
#  'worries',
#  'ok',
#  'fruit',
#  'good',
#  'huge',
#  'done',
#  'show',
#  'may',
#  'Firehouse',
#  'dishes',
#  'section',
#  'including',
#  'nut',
#  'charcoal',
#  'loyal',
#  'char',
#  'expect',
#  'thanks',
#  'margaritas',
#  'atmosphere',
#  'piano',
#  'returning',
#  'offers',
#  'hungry',
#  'guests',
#  'cart',
#  'appetizer',
#  'Cod',
#  'does',
#  'dine',
#  'tried',
#  'area',
#  'complaints',
#  'tacos',
#  'court',
#  'article',
#  'pretty',
#  'Before',
#  'fan',
#  'ago',
#  'melt',
#  'awkwardly',
#  'Hopefully',
#  'happier',
#  'healthy',
#  'seriously',
#  'power',
#  'Sunday',
#  'lovers',
#  '%',
#  'largely',
#  'Las',
#  'calamari',
#  'winner',
#  'HAD',
#  'rubber',
#  'offered',
#  'accommodations',
#  'succulent',
#  'voted',
#  'Nothing',
#  'tops',
#  'Unfortunately',
#  'entire',
#  'No',
#  'Ramsey',
#  'human',
#  'son',
#  'bakery',
#  'grow',
#  'Filet',
#  'girlfriend',
#  'doughy',
#  'blown',
#  'Bunch',
#  'two',
#  'seasonal',
#  'peanuts',
#  'movies',
#  'closed',
#  'very',
#  'do',
#  'nigiri',
#  'heart',
#  'needs',
#  'fabulous',
#  'into',
#  'miss',
#  'shops',
#  'receives',
#  'guacamole',
#  'enjoyed',
#  'Dog',
#  'So',
#  'promptly',
#  'tomato',
#  'Maria',
#  'refill',
#  'specials',
#  'pleasure',
#  'pine',
#  'my',
#  'frustrated',
#  'generic',
#  'disaster',
#  'outshining',
#  'rave',
#  'menus',
#  'sign',
#  'Italian',
#  'opened',
#  'hate',
#  'yay',
#  'pleased',
#  'final',
#  'Coming',
#  'overcooked',
#  'outrageously',
#  'received',
#  'exquisite',
#  'kind',
#  'hour',
#  'exceptional',
#  'old',
#  'places',
#  'NYC',
#  'tip',
#  'empty',
#  'come',
#  'Food',
#  'par',
#  'Nargile',
#  'taste',
#  'bread',
#  'overhaul',
#  'Check',
#  'despicable',
#  'fact',
#  'Frenchman',
#  'decor',
#  'then',
#  'biggest',
#  'MANAGEMENT',
#  'bought',
#  'limited',
#  'eel',
#  '!',
#  'reheated',
#  'ladies',
#  'couple',
#  'mouths',
#  'lack',
#  'tater',
#  'groups',
#  'usual',
#  'OVERPRICED',
#  'almonds',
#  'sewer',
#  'Roll',
#  'guy',
#  'shall',
#  'songs',
#  'hello',
#  'sub',
#  'Cartel',
#  'though',
#  'tables',
#  'how',
#  'due',
#  'name',
#  'ways',
#  'room',
#  'Maybe',
#  'vinegrette',
#  'Philadelphia',
#  'cheated',
#  'half',
#  'puréed',
#  'capers',
#  'overpriced',
#  'had',
#  'Crystals',
#  'relax',
#  'check',
#  'typical',
#  'chocolate',
#  'generous',
#  'NASTY',
#  'set',
#  'service',
#  'puree',
#  'sergeant',
#  'all',
#  'disappointing',
#  'walls',
#  'think',
#  'fill',
#  'tap',
#  'fat',
#  'boyfriend',
#  'polite',
#  'GO',
#  'lawyers',
#  'genuinely',
#  'FANTASTIC',
#  'patty',
#  'Waitress',
#  'past',
#  'mistake',
#  'grab',
#  'ordering',
#  'possible',
#  'thirty',
#  'Hiro',
#  'they',
#  'mostly',
#  'immediately',
#  'note',
#  'living',
#  'three',
#  'probably',
#  'Eew',
#  'signs',
#  'talk',
#  ')',
#  'wall',
#  'Omelets',
#  '.',
#  '...',
#  'stinks',
#  'unless',
#  'treat',
#  'thought',
#  'businesses',
#  'starving',
#  'Why',
#  'Highly',
#  'head',
#  'say',
#  'vibe',
#  'kid',
#  'thick',
#  'Overall',
#  'food/service',
#  'grease',
#  'spaghetti',
#  'overwhelmed',
#  'BACK',
#  'understand',
#  'begin',
#  'eat',
#  'sangria',
#  'douchey',
#  'strange',
#  'them',
#  'dipping',
#  'also',
#  'It',
#  'inspired',
#  'drinks',
#  'week',
#  'a',
#  'Flower',
#  'sense',
#  'ahead',
#  'ventilation',
#  'but',
#  'over',
#  'salad',
#  '20',
#  'occasions',
#  'up',
#  'try',
#  'dispenser',
#  'beyond',
#  'profiterole',
#  'serivce',
#  'Eggplant',
#  'bother',
#  'THIS',
#  'decision',
#  'writing',
#  'anymore',
#  'completely',
#  'Horrible',
#  'waiting',
#  'petrified',
#  'covered',
#  'Burrittos',
#  'pears',
#  'ca',
#  'handed',
#  'croutons',
#  'hooked',
#  'relationship',
#  'convenient',
#  'Service-check',
#  'truly',
#  'Waiter',
#  'especially',
#  'anytime',
#  '&',
#  'pizzas',
#  'Joey',
#  'unfortunately',
#  'soggy',
#  'clue',
#  'crab',
#  'under-services',
#  'cheek',
#  'Mellow',
#  'app',
#  'fail',
#  'presentation',
#  'Ha',
#  'owner/chef',
#  'flavorful',
#  'milkshake',
#  'to-go',
#  'proclaimed',
#  'Attack',
#  'eating',
#  'bird',
#  'Very',
#  'thing',
#  'affordable',
#  'Hot',
#  'honest',
#  'wedges',
#  'count',
#  'flirting',
#  'making',
#  'right',
#  'biscuits',
#  'rudely',
#  'away',
#  'point',
#  'Go',
#  'Vegetarian',
#  'Francisco',
#  'tummy',
#  'definitely',
#  'moist',
#  'passed',
#  'iced',
#  'horrible',
#  'in',
#  'PEOPLE',
#  'please',
#  'steaks',
#  'obviously',
#  'Disappointing',
#  'Gordon',
#  'somethat',
#  'Disappointed',
#  'Google',
#  'combo',
#  'checked',
#  'short',
#  'revisiting',
#  'accordingly',
#  'Crust',
#  'chip',
#  'might',
#  'crazy',
#  'HANDS',
#  'fuzzy',
#  'other',
#  'many',
#  'mean',
#  'made',
#  'rude',
#  'vain',
#  'fun',
#  'exactly',
#  'delicate',
#  'average',
#  'considering',
#  'held',
#  'And',
#  'brought',
#  'butter',
#  'store',
#  'fiancé',
#  'Dylan',
#  'shopping',
#  'literally',
#  'refused',
#  'Kabuki',
#  'daily',
#  'down',
#  'redeeming',
#  'last',
#  'wonderful',
#  'opposed',
#  'Buldogis',
#  'Baba',
#  'imaginative',
#  'helpful',
#  'brunch',
#  'mary',
#  'We',
#  'recall',
#  'what',
#  'grossed',
#  'Steak',
#  "ya'all",
#  'common',
#  'GREAT',
#  'They',
#  'street',
#  'Gave',
#  'touched',
#  'prefer',
#  'gristle',
#  'hit',
#  'Japanese',
#  'event',
#  'cook',
#  'neighborhood',
#  'star',
#  'First',
#  'disappointed',
#  'plantains',
#  'etc',
#  'Mediterranean',
#  'INCONSIDERATE',
#  'worst',
#  'falafels',
#  'gross',
#  'money',
#  'Favorite',
#  'Awesome',
#  'fish',
#  'satifying',
#  'Overpriced',
#  'golden-crispy',
#  'register',
#  'Rice',
#  'Mandalay',
#  'one',
#  'Camelback',
#  'readers',
#  'desired',
#  'vomited',
#  'Reasonably',
#  'prepare',
#  'bottom',
#  'course',
#  'waited',
#  'always',
#  'pasta',
#  'outside',
#  'refried',
#  'greatest',
#  'dripping',
#  'Stopped',
#  'parents',
#  'cooking',
#  'warmer',
#  'sound',
#  'oven',
#  '7',
#  '$',
#  'wants',
#  'Halibut',
#  'his',
#  'afternoon',
#  'skimp',
#  'informative',
#  'low-key',
#  'ranch',
#  'Over',
#  'Once',
#  'little',
#  'Have',
#  'Rock',
#  'ourselves',
#  'CONCLUSION',
#  'giving',
#  'satisfied',
#  'meet',
#  'hottest',
#  'favor',
#  'FS',
#  'be',
#  'Rick',
#  'spicier',
#  'toro',
#  'on',
#  'cocktail',
#  'expected',
#  'tots',
#  'glad',
#  'could',
#  'favorite',
#  'non-customer',
#  'allergy',
#  'hard',
#  'group',
#  '12',
#  'joy',
#  'gloves.Everything',
#  'Owner',
#  'WEAK',
#  'did',
#  'tiny',
#  'stop',
#  'disgust',
#  'handled',
#  'suck',
#  'MGM',
#  'stupid',
#  'melted',
#  'Ample',
#  'FORWARD',
#  'late',
#  'Boy',
#  'Toast',
#  'Sour',
#  'Nicest',
#  'soundtrack',
#  'these',
#  'mmmm',
#  'disgraceful',
#  'Same',
#  'soup',
#  'wire',
#  'disrespected',
#  'Casino',
#  'here',
#  'ravoli',
#  'Seriously',
#  'Costco',
#  'reminded',
#  'wave',
#  'house',
#  'ten',
#  'To',
#  'showed',
#  'greens',
#  'wish',
#  'forever',
#  '3/4ths',
#  'daughter',
#  'staff',
#  'bigger',
#  'in-house',
#  'charged',
#  'burger',
#  'under',
#  'Level',
#  'Denny',
#  'lighting',
#  'contain',
#  'our',
#  'wings',
#  'meatloaf',
#  'guess',
#  'This',
#  'privileged',
#  ...}

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    word_index[word] = n
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'lady': 0,
#  'events': 1,
#  'AVOID': 2,
#  '....': 3,
#  'thumbs': 4,
#  'raspberry': 5,
#  'connoisseur': 6,
#  'when': 7,
#  'box': 8,
#  'unhealthy': 9,
#  'Went': 10,
#  'Taco': 11,
#  'go': 12,
#  'Stars': 13,
#  'evening': 14,
#  'similar': 15,
#  'finish': 16,
#  'tastings': 17,
#  'decorated': 18,
#  'warm': 19,
#  'next': 20,
#  'Outstanding': 21,
#  'dates': 22,
#  'beef': 23,
#  'When': 24,
#  'Everyone': 25,
#  'correct': 26,
#  'massive': 27,
#  'hardly': 28,
#  'Lox': 29,
#  'restaurants': 30,
#  'sever': 31,
#  'Point': 32,
#  'wine': 33,
#  'without': 34,
#  '11.99': 35,
#  'gave': 36,
#  'Tasty': 37,
#  'Christmas': 38,
#  'paid': 39,
#  'Ganoush': 40,
#  'bill': 41,
#  'Poor': 42,
#  'from': 43,
#  'Last': 44,
#  'rushed': 45,
#  'space': 46,
#  'nutshell': 47,
#  'large': 48,
#  'market': 49,
#  'rings': 50,
#  'definately': 51,
#  'egg': 52,
#  'legs': 53,
#  'packed': 54,
#  'die': 55,
#  'myself': 56,
#  'lot': 57,
#  'buffets': 58,
#  'stood': 59,
#  'email': 60,
#  'mein': 61,
#  'bamboo': 62,
#  'bar': 63,
#  'foot': 64,
#  'jerk': 65,
#  'dinners': 66,
#  'brownish': 67,
#  'Always': 68,
#  'pack': 69,
#  'barely': 70,
#  'authentic': 71,
#  'perpared': 72,
#  'drawing': 73,
#  'joint': 74,
#  'Soups': 75,
#  'greasy': 76,
#  'six': 77,
#  'bathroom': 78,
#  'roast': 79,
#  'solid': 80,
#  'almost': 81,
#  'door': 82,
#  'same': 83,
#  'drunk': 84,
#  '*': 85,
#  'somewhat': 86,
#  'weekend': 87,
#  'problem': 88,
#  'disappoint': 89,
#  'Fridays': 90,
#  'hearts': 91,
#  'tapas': 92,
#  'donut': 93,
#  'lunch': 94,
#  'imagined': 95,
#  'providing': 96,
#  'day': 97,
#  'Veggitarian': 98,
#  'hereas': 99,
#  'Mary': 100,
#  'today': 101,
#  'impressive': 102,
#  'SCREAMS': 103,
#  'caterpillar': 104,
#  'light': 105,
#  'dressed': 106,
#  'disagree': 107,
#  'hands-down': 108,
#  'certainly': 109,
#  'attentive': 110,
#  'crust': 111,
#  'raving': 112,
#  'speedy': 113,
#  'naan': 114,
#  'stomach': 115,
#  'are': 116,
#  'Tucson': 117,
#  'struck': 118,
#  'such': 119,
#  'smoothies': 120,
#  'meals': 121,
#  'Standard': 122,
#  'towards': 123,
#  'between': 124,
#  'trying': 125,
#  'totally': 126,
#  'Wo': 127,
#  'end': 128,
#  'pancake': 129,
#  'airline': 130,
#  'apparently': 131,
#  'red': 132,
#  'highly': 133,
#  'Panna': 134,
#  'Big': 135,
#  'uploaded': 136,
#  'baklava': 137,
#  'equally': 138,
#  'business': 139,
#  'attached': 140,
#  'Bean': 141,
#  "'s": 142,
#  'fails': 143,
#  'shoots': 144,
#  'over-whelm': 145,
#  'Sadly': 146,
#  'NO': 147,
#  'expectations': 148,
#  'Han': 149,
#  'poisoning': 150,
#  '2': 151,
#  'sticks': 152,
#  'Nan': 153,
#  'jalapeno': 154,
#  'chains': 155,
#  'appetizers': 156,
#  'Blah': 157,
#  'portion': 158,
#  'papers': 159,
#  'grocery': 160,
#  'pissd': 161,
#  'tartare': 162,
#  'mixed': 163,
#  'discount': 164,
#  'disappointment': 165,
#  'personable': 166,
#  'Then': 167,
#  'Your': 168,
#  'arrives': 169,
#  'promise': 170,
#  'anticipated': 171,
#  'cold': 172,
#  'Large': 173,
#  'Which': 174,
#  'covers': 175,
#  'WILL': 176,
#  'single': 177,
#  'word': 178,
#  'bartenders': 179,
#  'small': 180,
#  '6': 181,
#  'Four': 182,
#  'By': 183,
#  'folks': 184,
#  'Voodoo': 185,
#  'take': 186,
#  'Every': 187,
#  'familiar': 188,
#  'tasteless': 189,
#  'hella': 190,
#  'OMG': 191,
#  'Nice': 192,
#  'judging': 193,
#  'WAAAAAAyyyyyyyyyy': 194,
#  'sunglasses': 195,
#  'spring': 196,
#  'companions': 197,
#  'fine': 198,
#  'Sushi': 199,
#  'patron': 200,
#  'leave': 201,
#  'real': 202,
#  'bunch': 203,
#  'serves': 204,
#  'out': 205,
#  'quality': 206,
#  'sorely': 207,
#  'idea': 208,
#  'quit': 209,
#  'ribeye': 210,
#  'simple': 211,
#  'uninspired': 212,
#  'version': 213,
#  'unexperienced': 214,
#  'law': 215,
#  '5': 216,
#  'MUST': 217,
#  'positive': 218,
#  'Back': 219,
#  'garden': 220,
#  'profound': 221,
#  'their': 222,
#  "n't": 223,
#  'These': 224,
#  'thats': 225,
#  'looking': 226,
#  'Pizza': 227,
#  'plus': 228,
#  'amazing': 229,
#  'friend': 230,
#  'mom': 231,
#  'letdown': 232,
#  'The': 233,
#  'Hard': 234,
#  'him': 235,
#  'believe': 236,
#  'ball': 237,
#  'took': 238,
#  'stuff': 239,
#  'outstanding': 240,
#  'You': 241,
#  '/hand': 242,
#  'rest': 243,
#  'takeout': 244,
#  'yukon': 245,
#  'callings': 246,
#  'reasons': 247,
#  'blanket': 248,
#  'else': 249,
#  'multiple': 250,
#  'which': 251,
#  'dessert': 252,
#  'first': 253,
#  'larger': 254,
#  'work': 255,
#  'besides': 256,
#  'regular': 257,
#  '8': 258,
#  'cannoli': 259,
#  'olives': 260,
#  'lived': 261,
#  'Bellagio': 262,
#  'seasoned': 263,
#  'each': 264,
#  'Jeff': 265,
#  'better': 266,
#  'he': 267,
#  '45': 268,
#  'circumstances': 269,
#  'clean': 270,
#  'seemed': 271,
#  'nay': 272,
#  'Insults': 273,
#  'muffin': 274,
#  'lacking': 275,
#  'correction': 276,
#  'giant': 277,
#  'Appetite': 278,
#  'too': 279,
#  'However': 280,
#  'wrapped': 281,
#  'beer': 282,
#  'live': 283,
#  'accountant': 284,
#  'pepper': 285,
#  'hole': 286,
#  'strawberry': 287,
#  'until': 288,
#  'again': 289,
#  'side': 290,
#  'ever': 291,
#  'pastry': 292,
#  'above': 293,
#  'ordered': 294,
#  'either': 295,
#  'breakfast': 296,
#  'professional': 297,
#  '15': 298,
#  'read': 299,
#  'whatsoever': 300,
#  'sad': 301,
#  'Eclectic': 302,
#  'home': 303,
#  'funny': 304,
#  'high': 305,
#  'asking': 306,
#  'Noca': 307,
#  'Greek': 308,
#  'mussels': 309,
#  'Yelpers': 310,
#  'this': 311,
#  'wines': 312,
#  'deep': 313,
#  'drag': 314,
#  'tell': 315,
#  'decent': 316,
#  'want': 317,
#  'ethic': 318,
#  'sore': 319,
#  'High-quality': 320,
#  'edible': 321,
#  'REALLY': 322,
#  'turn': 323,
#  'delight': 324,
#  'Loved': 325,
#  'Soi': 326,
#  'beers': 327,
#  'were': 328,
#  'Heimer': 329,
#  'Delicious': 330,
#  'recommended': 331,
#  'LEGIT': 332,
#  'bars': 333,
#  'teeth': 334,
#  'saganaki': 335,
#  'wildly': 336,
#  'ALL': 337,
#  'dedicated': 338,
#  'why': 339,
#  'nachos': 340,
#  'second': 341,
#  'changing': 342,
#  'wontons': 343,
#  'family': 344,
#  'consider': 345,
#  'smells': 346,
#  'expert/connisseur': 347,
#  'temp.I': 348,
#  'experience': 349,
#  'hostess': 350,
#  'return': 351,
#  'cover': 352,
#  'itself': 353,
#  'dealing': 354,
#  'enjoyable': 355,
#  'pneumatic': 356,
#  'Seat': 357,
#  'metro': 358,
#  'Bacon': 359,
#  'drastically': 360,
#  'special': 361,
#  'That': 362,
#  'disgrace': 363,
#  'Mom': 364,
#  'cute': 365,
#  'combination': 366,
#  'sucker': 367,
#  'flat': 368,
#  'flair': 369,
#  'most': 370,
#  'suggestions': 371,
#  'sexy': 372,
#  'After': 373,
#  'perfection': 374,
#  'crusty': 375,
#  'brisket': 376,
#  'care': 377,
#  'loves': 378,
#  'mouth': 379,
#  'Thai': 380,
#  'unbelievable': 381,
#  'happened': 382,
#  '35': 383,
#  'incredible': 384,
#  'felt': 385,
#  'Caesar': 386,
#  'T.': 387,
#  'pork': 388,
#  'bloodiest': 389,
#  'Baseball': 390,
#  'bloddy': 391,
#  'An': 392,
#  'cocktails': 393,
#  'during': 394,
#  'Although': 395,
#  'Phoenix': 396,
#  'leftover': 397,
#  'Sprouts': 398,
#  'establishment': 399,
#  'vegetables': 400,
#  'Madison': 401,
#  'compliments': 402,
#  'sides': 403,
#  'transcendant': 404,
#  'about': 405,
#  'Ians': 406,
#  'welcome': 407,
#  'bartender': 408,
#  'deserves': 409,
#  '70+': 410,
#  'Elk': 411,
#  'Chinese': 412,
#  'who': 413,
#  'restaraunt': 414,
#  'mac': 415,
#  'years': 416,
#  'eggplant': 417,
#  'lacked': 418,
#  'play': 419,
#  'courteous': 420,
#  'front': 421,
#  'dish': 422,
#  'Bisque': 423,
#  'visited': 424,
#  'tepid': 425,
#  '4.00': 426,
#  'IN': 427,
#  'Worst': 428,
#  'whether': 429,
#  'swung': 430,
#  'North': 431,
#  'tuna': 432,
#  'Dos': 433,
#  'Really': 434,
#  'sucked': 435,
#  'climbing': 436,
#  'and': 437,
#  'shoe': 438,
#  'worries': 439,
#  'ok': 440,
#  'fruit': 441,
#  'good': 442,
#  'huge': 443,
#  'done': 444,
#  'show': 445,
#  'may': 446,
#  'Firehouse': 447,
#  'dishes': 448,
#  'section': 449,
#  'including': 450,
#  'nut': 451,
#  'charcoal': 452,
#  'loyal': 453,
#  'char': 454,
#  'expect': 455,
#  'thanks': 456,
#  'margaritas': 457,
#  'atmosphere': 458,
#  'piano': 459,
#  'returning': 460,
#  'offers': 461,
#  'hungry': 462,
#  'guests': 463,
#  'cart': 464,
#  'appetizer': 465,
#  'Cod': 466,
#  'does': 467,
#  'dine': 468,
#  'tried': 469,
#  'area': 470,
#  'complaints': 471,
#  'tacos': 472,
#  'court': 473,
#  'article': 474,
#  'pretty': 475,
#  'Before': 476,
#  'fan': 477,
#  'ago': 478,
#  'melt': 479,
#  'awkwardly': 480,
#  'Hopefully': 481,
#  'happier': 482,
#  'healthy': 483,
#  'seriously': 484,
#  'power': 485,
#  'Sunday': 486,
#  'lovers': 487,
#  '%': 488,
#  'largely': 489,
#  'Las': 490,
#  'calamari': 491,
#  'winner': 492,
#  'HAD': 493,
#  'rubber': 494,
#  'offered': 495,
#  'accommodations': 496,
#  'succulent': 497,
#  'voted': 498,
#  'Nothing': 499,
#  'tops': 500,
#  'Unfortunately': 501,
#  'entire': 502,
#  'No': 503,
#  'Ramsey': 504,
#  'human': 505,
#  'son': 506,
#  'bakery': 507,
#  'grow': 508,
#  'Filet': 509,
#  'girlfriend': 510,
#  'doughy': 511,
#  'blown': 512,
#  'Bunch': 513,
#  'two': 514,
#  'seasonal': 515,
#  'peanuts': 516,
#  'movies': 517,
#  'closed': 518,
#  'very': 519,
#  'do': 520,
#  'nigiri': 521,
#  'heart': 522,
#  'needs': 523,
#  'fabulous': 524,
#  'into': 525,
#  'miss': 526,
#  'shops': 527,
#  'receives': 528,
#  'guacamole': 529,
#  'enjoyed': 530,
#  'Dog': 531,
#  'So': 532,
#  'promptly': 533,
#  'tomato': 534,
#  'Maria': 535,
#  'refill': 536,
#  'specials': 537,
#  'pleasure': 538,
#  'pine': 539,
#  'my': 540,
#  'frustrated': 541,
#  'generic': 542,
#  'disaster': 543,
#  'outshining': 544,
#  'rave': 545,
#  'menus': 546,
#  'sign': 547,
#  'Italian': 548,
#  'opened': 549,
#  'hate': 550,
#  'yay': 551,
#  'pleased': 552,
#  'final': 553,
#  'Coming': 554,
#  'overcooked': 555,
#  'outrageously': 556,
#  'received': 557,
#  'exquisite': 558,
#  'kind': 559,
#  'hour': 560,
#  'exceptional': 561,
#  'old': 562,
#  'places': 563,
#  'NYC': 564,
#  'tip': 565,
#  'empty': 566,
#  'come': 567,
#  'Food': 568,
#  'par': 569,
#  'Nargile': 570,
#  'taste': 571,
#  'bread': 572,
#  'overhaul': 573,
#  'Check': 574,
#  'despicable': 575,
#  'fact': 576,
#  'Frenchman': 577,
#  'decor': 578,
#  'then': 579,
#  'biggest': 580,
#  'MANAGEMENT': 581,
#  'bought': 582,
#  'limited': 583,
#  'eel': 584,
#  '!': 585,
#  'reheated': 586,
#  'ladies': 587,
#  'couple': 588,
#  'mouths': 589,
#  'lack': 590,
#  'tater': 591,
#  'groups': 592,
#  'usual': 593,
#  'OVERPRICED': 594,
#  'almonds': 595,
#  'sewer': 596,
#  'Roll': 597,
#  'guy': 598,
#  'shall': 599,
#  'songs': 600,
#  'hello': 601,
#  'sub': 602,
#  'Cartel': 603,
#  'though': 604,
#  'tables': 605,
#  'how': 606,
#  'due': 607,
#  'name': 608,
#  'ways': 609,
#  'room': 610,
#  'Maybe': 611,
#  'vinegrette': 612,
#  'Philadelphia': 613,
#  'cheated': 614,
#  'half': 615,
#  'puréed': 616,
#  'capers': 617,
#  'overpriced': 618,
#  'had': 619,
#  'Crystals': 620,
#  'relax': 621,
#  'check': 622,
#  'typical': 623,
#  'chocolate': 624,
#  'generous': 625,
#  'NASTY': 626,
#  'set': 627,
#  'service': 628,
#  'puree': 629,
#  'sergeant': 630,
#  'all': 631,
#  'disappointing': 632,
#  'walls': 633,
#  'think': 634,
#  'fill': 635,
#  'tap': 636,
#  'fat': 637,
#  'boyfriend': 638,
#  'polite': 639,
#  'GO': 640,
#  'lawyers': 641,
#  'genuinely': 642,
#  'FANTASTIC': 643,
#  'patty': 644,
#  'Waitress': 645,
#  'past': 646,
#  'mistake': 647,
#  'grab': 648,
#  'ordering': 649,
#  'possible': 650,
#  'thirty': 651,
#  'Hiro': 652,
#  'they': 653,
#  'mostly': 654,
#  'immediately': 655,
#  'note': 656,
#  'living': 657,
#  'three': 658,
#  'probably': 659,
#  'Eew': 660,
#  'signs': 661,
#  'talk': 662,
#  ')': 663,
#  'wall': 664,
#  'Omelets': 665,
#  '.': 666,
#  '...': 667,
#  'stinks': 668,
#  'unless': 669,
#  'treat': 670,
#  'thought': 671,
#  'businesses': 672,
#  'starving': 673,
#  'Why': 674,
#  'Highly': 675,
#  'head': 676,
#  'say': 677,
#  'vibe': 678,
#  'kid': 679,
#  'thick': 680,
#  'Overall': 681,
#  'food/service': 682,
#  'grease': 683,
#  'spaghetti': 684,
#  'overwhelmed': 685,
#  'BACK': 686,
#  'understand': 687,
#  'begin': 688,
#  'eat': 689,
#  'sangria': 690,
#  'douchey': 691,
#  'strange': 692,
#  'them': 693,
#  'dipping': 694,
#  'also': 695,
#  'It': 696,
#  'inspired': 697,
#  'drinks': 698,
#  'week': 699,
#  'a': 700,
#  'Flower': 701,
#  'sense': 702,
#  'ahead': 703,
#  'ventilation': 704,
#  'but': 705,
#  'over': 706,
#  'salad': 707,
#  '20': 708,
#  'occasions': 709,
#  'up': 710,
#  'try': 711,
#  'dispenser': 712,
#  'beyond': 713,
#  'profiterole': 714,
#  'serivce': 715,
#  'Eggplant': 716,
#  'bother': 717,
#  'THIS': 718,
#  'decision': 719,
#  'writing': 720,
#  'anymore': 721,
#  'completely': 722,
#  'Horrible': 723,
#  'waiting': 724,
#  'petrified': 725,
#  'covered': 726,
#  'Burrittos': 727,
#  'pears': 728,
#  'ca': 729,
#  'handed': 730,
#  'croutons': 731,
#  'hooked': 732,
#  'relationship': 733,
#  'convenient': 734,
#  'Service-check': 735,
#  'truly': 736,
#  'Waiter': 737,
#  'especially': 738,
#  'anytime': 739,
#  '&': 740,
#  'pizzas': 741,
#  'Joey': 742,
#  'unfortunately': 743,
#  'soggy': 744,
#  'clue': 745,
#  'crab': 746,
#  'under-services': 747,
#  'cheek': 748,
#  'Mellow': 749,
#  'app': 750,
#  'fail': 751,
#  'presentation': 752,
#  'Ha': 753,
#  'owner/chef': 754,
#  'flavorful': 755,
#  'milkshake': 756,
#  'to-go': 757,
#  'proclaimed': 758,
#  'Attack': 759,
#  'eating': 760,
#  'bird': 761,
#  'Very': 762,
#  'thing': 763,
#  'affordable': 764,
#  'Hot': 765,
#  'honest': 766,
#  'wedges': 767,
#  'count': 768,
#  'flirting': 769,
#  'making': 770,
#  'right': 771,
#  'biscuits': 772,
#  'rudely': 773,
#  'away': 774,
#  'point': 775,
#  'Go': 776,
#  'Vegetarian': 777,
#  'Francisco': 778,
#  'tummy': 779,
#  'definitely': 780,
#  'moist': 781,
#  'passed': 782,
#  'iced': 783,
#  'horrible': 784,
#  'in': 785,
#  'PEOPLE': 786,
#  'please': 787,
#  'steaks': 788,
#  'obviously': 789,
#  'Disappointing': 790,
#  'Gordon': 791,
#  'somethat': 792,
#  'Disappointed': 793,
#  'Google': 794,
#  'combo': 795,
#  'checked': 796,
#  'short': 797,
#  'revisiting': 798,
#  'accordingly': 799,
#  'Crust': 800,
#  'chip': 801,
#  'might': 802,
#  'crazy': 803,
#  'HANDS': 804,
#  'fuzzy': 805,
#  'other': 806,
#  'many': 807,
#  'mean': 808,
#  'made': 809,
#  'rude': 810,
#  'vain': 811,
#  'fun': 812,
#  'exactly': 813,
#  'delicate': 814,
#  'average': 815,
#  'considering': 816,
#  'held': 817,
#  'And': 818,
#  'brought': 819,
#  'butter': 820,
#  'store': 821,
#  'fiancé': 822,
#  'Dylan': 823,
#  'shopping': 824,
#  'literally': 825,
#  'refused': 826,
#  'Kabuki': 827,
#  'daily': 828,
#  'down': 829,
#  'redeeming': 830,
#  'last': 831,
#  'wonderful': 832,
#  'opposed': 833,
#  'Buldogis': 834,
#  'Baba': 835,
#  'imaginative': 836,
#  'helpful': 837,
#  'brunch': 838,
#  'mary': 839,
#  'We': 840,
#  'recall': 841,
#  'what': 842,
#  'grossed': 843,
#  'Steak': 844,
#  "ya'all": 845,
#  'common': 846,
#  'GREAT': 847,
#  'They': 848,
#  'street': 849,
#  'Gave': 850,
#  'touched': 851,
#  'prefer': 852,
#  'gristle': 853,
#  'hit': 854,
#  'Japanese': 855,
#  'event': 856,
#  'cook': 857,
#  'neighborhood': 858,
#  'star': 859,
#  'First': 860,
#  'disappointed': 861,
#  'plantains': 862,
#  'etc': 863,
#  'Mediterranean': 864,
#  'INCONSIDERATE': 865,
#  'worst': 866,
#  'falafels': 867,
#  'gross': 868,
#  'money': 869,
#  'Favorite': 870,
#  'Awesome': 871,
#  'fish': 872,
#  'satifying': 873,
#  'Overpriced': 874,
#  'golden-crispy': 875,
#  'register': 876,
#  'Rice': 877,
#  'Mandalay': 878,
#  'one': 879,
#  'Camelback': 880,
#  'readers': 881,
#  'desired': 882,
#  'vomited': 883,
#  'Reasonably': 884,
#  'prepare': 885,
#  'bottom': 886,
#  'course': 887,
#  'waited': 888,
#  'always': 889,
#  'pasta': 890,
#  'outside': 891,
#  'refried': 892,
#  'greatest': 893,
#  'dripping': 894,
#  'Stopped': 895,
#  'parents': 896,
#  'cooking': 897,
#  'warmer': 898,
#  'sound': 899,
#  'oven': 900,
#  '7': 901,
#  '$': 902,
#  'wants': 903,
#  'Halibut': 904,
#  'his': 905,
#  'afternoon': 906,
#  'skimp': 907,
#  'informative': 908,
#  'low-key': 909,
#  'ranch': 910,
#  'Over': 911,
#  'Once': 912,
#  'little': 913,
#  'Have': 914,
#  'Rock': 915,
#  'ourselves': 916,
#  'CONCLUSION': 917,
#  'giving': 918,
#  'satisfied': 919,
#  'meet': 920,
#  'hottest': 921,
#  'favor': 922,
#  'FS': 923,
#  'be': 924,
#  'Rick': 925,
#  'spicier': 926,
#  'toro': 927,
#  'on': 928,
#  'cocktail': 929,
#  'expected': 930,
#  'tots': 931,
#  'glad': 932,
#  'could': 933,
#  'favorite': 934,
#  'non-customer': 935,
#  'allergy': 936,
#  'hard': 937,
#  'group': 938,
#  '12': 939,
#  'joy': 940,
#  'gloves.Everything': 941,
#  'Owner': 942,
#  'WEAK': 943,
#  'did': 944,
#  'tiny': 945,
#  'stop': 946,
#  'disgust': 947,
#  'handled': 948,
#  'suck': 949,
#  'MGM': 950,
#  'stupid': 951,
#  'melted': 952,
#  'Ample': 953,
#  'FORWARD': 954,
#  'late': 955,
#  'Boy': 956,
#  'Toast': 957,
#  'Sour': 958,
#  'Nicest': 959,
#  'soundtrack': 960,
#  'these': 961,
#  'mmmm': 962,
#  'disgraceful': 963,
#  'Same': 964,
#  'soup': 965,
#  'wire': 966,
#  'disrespected': 967,
#  'Casino': 968,
#  'here': 969,
#  'ravoli': 970,
#  'Seriously': 971,
#  'Costco': 972,
#  'reminded': 973,
#  'wave': 974,
#  'house': 975,
#  'ten': 976,
#  'To': 977,
#  'showed': 978,
#  'greens': 979,
#  'wish': 980,
#  'forever': 981,
#  '3/4ths': 982,
#  'daughter': 983,
#  'staff': 984,
#  'bigger': 985,
#  'in-house': 986,
#  'charged': 987,
#  'burger': 988,
#  'under': 989,
#  'Level': 990,
#  'Denny': 991,
#  'lighting': 992,
#  'contain': 993,
#  'our': 994,
#  'wings': 995,
#  'meatloaf': 996,
#  'guess': 997,
#  'This': 998,
#  'privileged': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'lady',
#  1: 'events',
#  2: 'AVOID',
#  3: '....',
#  4: 'thumbs',
#  5: 'raspberry',
#  6: 'connoisseur',
#  7: 'when',
#  8: 'box',
#  9: 'unhealthy',
#  10: 'Went',
#  11: 'Taco',
#  12: 'go',
#  13: 'Stars',
#  14: 'evening',
#  15: 'similar',
#  16: 'finish',
#  17: 'tastings',
#  18: 'decorated',
#  19: 'warm',
#  20: 'next',
#  21: 'Outstanding',
#  22: 'dates',
#  23: 'beef',
#  24: 'When',
#  25: 'Everyone',
#  26: 'correct',
#  27: 'massive',
#  28: 'hardly',
#  29: 'Lox',
#  30: 'restaurants',
#  31: 'sever',
#  32: 'Point',
#  33: 'wine',
#  34: 'without',
#  35: '11.99',
#  36: 'gave',
#  37: 'Tasty',
#  38: 'Christmas',
#  39: 'paid',
#  40: 'Ganoush',
#  41: 'bill',
#  42: 'Poor',
#  43: 'from',
#  44: 'Last',
#  45: 'rushed',
#  46: 'space',
#  47: 'nutshell',
#  48: 'large',
#  49: 'market',
#  50: 'rings',
#  51: 'definately',
#  52: 'egg',
#  53: 'legs',
#  54: 'packed',
#  55: 'die',
#  56: 'myself',
#  57: 'lot',
#  58: 'buffets',
#  59: 'stood',
#  60: 'email',
#  61: 'mein',
#  62: 'bamboo',
#  63: 'bar',
#  64: 'foot',
#  65: 'jerk',
#  66: 'dinners',
#  67: 'brownish',
#  68: 'Always',
#  69: 'pack',
#  70: 'barely',
#  71: 'authentic',
#  72: 'perpared',
#  73: 'drawing',
#  74: 'joint',
#  75: 'Soups',
#  76: 'greasy',
#  77: 'six',
#  78: 'bathroom',
#  79: 'roast',
#  80: 'solid',
#  81: 'almost',
#  82: 'door',
#  83: 'same',
#  84: 'drunk',
#  85: '*',
#  86: 'somewhat',
#  87: 'weekend',
#  88: 'problem',
#  89: 'disappoint',
#  90: 'Fridays',
#  91: 'hearts',
#  92: 'tapas',
#  93: 'donut',
#  94: 'lunch',
#  95: 'imagined',
#  96: 'providing',
#  97: 'day',
#  98: 'Veggitarian',
#  99: 'hereas',
#  100: 'Mary',
#  101: 'today',
#  102: 'impressive',
#  103: 'SCREAMS',
#  104: 'caterpillar',
#  105: 'light',
#  106: 'dressed',
#  107: 'disagree',
#  108: 'hands-down',
#  109: 'certainly',
#  110: 'attentive',
#  111: 'crust',
#  112: 'raving',
#  113: 'speedy',
#  114: 'naan',
#  115: 'stomach',
#  116: 'are',
#  117: 'Tucson',
#  118: 'struck',
#  119: 'such',
#  120: 'smoothies',
#  121: 'meals',
#  122: 'Standard',
#  123: 'towards',
#  124: 'between',
#  125: 'trying',
#  126: 'totally',
#  127: 'Wo',
#  128: 'end',
#  129: 'pancake',
#  130: 'airline',
#  131: 'apparently',
#  132: 'red',
#  133: 'highly',
#  134: 'Panna',
#  135: 'Big',
#  136: 'uploaded',
#  137: 'baklava',
#  138: 'equally',
#  139: 'business',
#  140: 'attached',
#  141: 'Bean',
#  142: "'s",
#  143: 'fails',
#  144: 'shoots',
#  145: 'over-whelm',
#  146: 'Sadly',
#  147: 'NO',
#  148: 'expectations',
#  149: 'Han',
#  150: 'poisoning',
#  151: '2',
#  152: 'sticks',
#  153: 'Nan',
#  154: 'jalapeno',
#  155: 'chains',
#  156: 'appetizers',
#  157: 'Blah',
#  158: 'portion',
#  159: 'papers',
#  160: 'grocery',
#  161: 'pissd',
#  162: 'tartare',
#  163: 'mixed',
#  164: 'discount',
#  165: 'disappointment',
#  166: 'personable',
#  167: 'Then',
#  168: 'Your',
#  169: 'arrives',
#  170: 'promise',
#  171: 'anticipated',
#  172: 'cold',
#  173: 'Large',
#  174: 'Which',
#  175: 'covers',
#  176: 'WILL',
#  177: 'single',
#  178: 'word',
#  179: 'bartenders',
#  180: 'small',
#  181: '6',
#  182: 'Four',
#  183: 'By',
#  184: 'folks',
#  185: 'Voodoo',
#  186: 'take',
#  187: 'Every',
#  188: 'familiar',
#  189: 'tasteless',
#  190: 'hella',
#  191: 'OMG',
#  192: 'Nice',
#  193: 'judging',
#  194: 'WAAAAAAyyyyyyyyyy',
#  195: 'sunglasses',
#  196: 'spring',
#  197: 'companions',
#  198: 'fine',
#  199: 'Sushi',
#  200: 'patron',
#  201: 'leave',
#  202: 'real',
#  203: 'bunch',
#  204: 'serves',
#  205: 'out',
#  206: 'quality',
#  207: 'sorely',
#  208: 'idea',
#  209: 'quit',
#  210: 'ribeye',
#  211: 'simple',
#  212: 'uninspired',
#  213: 'version',
#  214: 'unexperienced',
#  215: 'law',
#  216: '5',
#  217: 'MUST',
#  218: 'positive',
#  219: 'Back',
#  220: 'garden',
#  221: 'profound',
#  222: 'their',
#  223: "n't",
#  224: 'These',
#  225: 'thats',
#  226: 'looking',
#  227: 'Pizza',
#  228: 'plus',
#  229: 'amazing',
#  230: 'friend',
#  231: 'mom',
#  232: 'letdown',
#  233: 'The',
#  234: 'Hard',
#  235: 'him',
#  236: 'believe',
#  237: 'ball',
#  238: 'took',
#  239: 'stuff',
#  240: 'outstanding',
#  241: 'You',
#  242: '/hand',
#  243: 'rest',
#  244: 'takeout',
#  245: 'yukon',
#  246: 'callings',
#  247: 'reasons',
#  248: 'blanket',
#  249: 'else',
#  250: 'multiple',
#  251: 'which',
#  252: 'dessert',
#  253: 'first',
#  254: 'larger',
#  255: 'work',
#  256: 'besides',
#  257: 'regular',
#  258: '8',
#  259: 'cannoli',
#  260: 'olives',
#  261: 'lived',
#  262: 'Bellagio',
#  263: 'seasoned',
#  264: 'each',
#  265: 'Jeff',
#  266: 'better',
#  267: 'he',
#  268: '45',
#  269: 'circumstances',
#  270: 'clean',
#  271: 'seemed',
#  272: 'nay',
#  273: 'Insults',
#  274: 'muffin',
#  275: 'lacking',
#  276: 'correction',
#  277: 'giant',
#  278: 'Appetite',
#  279: 'too',
#  280: 'However',
#  281: 'wrapped',
#  282: 'beer',
#  283: 'live',
#  284: 'accountant',
#  285: 'pepper',
#  286: 'hole',
#  287: 'strawberry',
#  288: 'until',
#  289: 'again',
#  290: 'side',
#  291: 'ever',
#  292: 'pastry',
#  293: 'above',
#  294: 'ordered',
#  295: 'either',
#  296: 'breakfast',
#  297: 'professional',
#  298: '15',
#  299: 'read',
#  300: 'whatsoever',
#  301: 'sad',
#  302: 'Eclectic',
#  303: 'home',
#  304: 'funny',
#  305: 'high',
#  306: 'asking',
#  307: 'Noca',
#  308: 'Greek',
#  309: 'mussels',
#  310: 'Yelpers',
#  311: 'this',
#  312: 'wines',
#  313: 'deep',
#  314: 'drag',
#  315: 'tell',
#  316: 'decent',
#  317: 'want',
#  318: 'ethic',
#  319: 'sore',
#  320: 'High-quality',
#  321: 'edible',
#  322: 'REALLY',
#  323: 'turn',
#  324: 'delight',
#  325: 'Loved',
#  326: 'Soi',
#  327: 'beers',
#  328: 'were',
#  329: 'Heimer',
#  330: 'Delicious',
#  331: 'recommended',
#  332: 'LEGIT',
#  333: 'bars',
#  334: 'teeth',
#  335: 'saganaki',
#  336: 'wildly',
#  337: 'ALL',
#  338: 'dedicated',
#  339: 'why',
#  340: 'nachos',
#  341: 'second',
#  342: 'changing',
#  343: 'wontons',
#  344: 'family',
#  345: 'consider',
#  346: 'smells',
#  347: 'expert/connisseur',
#  348: 'temp.I',
#  349: 'experience',
#  350: 'hostess',
#  351: 'return',
#  352: 'cover',
#  353: 'itself',
#  354: 'dealing',
#  355: 'enjoyable',
#  356: 'pneumatic',
#  357: 'Seat',
#  358: 'metro',
#  359: 'Bacon',
#  360: 'drastically',
#  361: 'special',
#  362: 'That',
#  363: 'disgrace',
#  364: 'Mom',
#  365: 'cute',
#  366: 'combination',
#  367: 'sucker',
#  368: 'flat',
#  369: 'flair',
#  370: 'most',
#  371: 'suggestions',
#  372: 'sexy',
#  373: 'After',
#  374: 'perfection',
#  375: 'crusty',
#  376: 'brisket',
#  377: 'care',
#  378: 'loves',
#  379: 'mouth',
#  380: 'Thai',
#  381: 'unbelievable',
#  382: 'happened',
#  383: '35',
#  384: 'incredible',
#  385: 'felt',
#  386: 'Caesar',
#  387: 'T.',
#  388: 'pork',
#  389: 'bloodiest',
#  390: 'Baseball',
#  391: 'bloddy',
#  392: 'An',
#  393: 'cocktails',
#  394: 'during',
#  395: 'Although',
#  396: 'Phoenix',
#  397: 'leftover',
#  398: 'Sprouts',
#  399: 'establishment',
#  400: 'vegetables',
#  401: 'Madison',
#  402: 'compliments',
#  403: 'sides',
#  404: 'transcendant',
#  405: 'about',
#  406: 'Ians',
#  407: 'welcome',
#  408: 'bartender',
#  409: 'deserves',
#  410: '70+',
#  411: 'Elk',
#  412: 'Chinese',
#  413: 'who',
#  414: 'restaraunt',
#  415: 'mac',
#  416: 'years',
#  417: 'eggplant',
#  418: 'lacked',
#  419: 'play',
#  420: 'courteous',
#  421: 'front',
#  422: 'dish',
#  423: 'Bisque',
#  424: 'visited',
#  425: 'tepid',
#  426: '4.00',
#  427: 'IN',
#  428: 'Worst',
#  429: 'whether',
#  430: 'swung',
#  431: 'North',
#  432: 'tuna',
#  433: 'Dos',
#  434: 'Really',
#  435: 'sucked',
#  436: 'climbing',
#  437: 'and',
#  438: 'shoe',
#  439: 'worries',
#  440: 'ok',
#  441: 'fruit',
#  442: 'good',
#  443: 'huge',
#  444: 'done',
#  445: 'show',
#  446: 'may',
#  447: 'Firehouse',
#  448: 'dishes',
#  449: 'section',
#  450: 'including',
#  451: 'nut',
#  452: 'charcoal',
#  453: 'loyal',
#  454: 'char',
#  455: 'expect',
#  456: 'thanks',
#  457: 'margaritas',
#  458: 'atmosphere',
#  459: 'piano',
#  460: 'returning',
#  461: 'offers',
#  462: 'hungry',
#  463: 'guests',
#  464: 'cart',
#  465: 'appetizer',
#  466: 'Cod',
#  467: 'does',
#  468: 'dine',
#  469: 'tried',
#  470: 'area',
#  471: 'complaints',
#  472: 'tacos',
#  473: 'court',
#  474: 'article',
#  475: 'pretty',
#  476: 'Before',
#  477: 'fan',
#  478: 'ago',
#  479: 'melt',
#  480: 'awkwardly',
#  481: 'Hopefully',
#  482: 'happier',
#  483: 'healthy',
#  484: 'seriously',
#  485: 'power',
#  486: 'Sunday',
#  487: 'lovers',
#  488: '%',
#  489: 'largely',
#  490: 'Las',
#  491: 'calamari',
#  492: 'winner',
#  493: 'HAD',
#  494: 'rubber',
#  495: 'offered',
#  496: 'accommodations',
#  497: 'succulent',
#  498: 'voted',
#  499: 'Nothing',
#  500: 'tops',
#  501: 'Unfortunately',
#  502: 'entire',
#  503: 'No',
#  504: 'Ramsey',
#  505: 'human',
#  506: 'son',
#  507: 'bakery',
#  508: 'grow',
#  509: 'Filet',
#  510: 'girlfriend',
#  511: 'doughy',
#  512: 'blown',
#  513: 'Bunch',
#  514: 'two',
#  515: 'seasonal',
#  516: 'peanuts',
#  517: 'movies',
#  518: 'closed',
#  519: 'very',
#  520: 'do',
#  521: 'nigiri',
#  522: 'heart',
#  523: 'needs',
#  524: 'fabulous',
#  525: 'into',
#  526: 'miss',
#  527: 'shops',
#  528: 'receives',
#  529: 'guacamole',
#  530: 'enjoyed',
#  531: 'Dog',
#  532: 'So',
#  533: 'promptly',
#  534: 'tomato',
#  535: 'Maria',
#  536: 'refill',
#  537: 'specials',
#  538: 'pleasure',
#  539: 'pine',
#  540: 'my',
#  541: 'frustrated',
#  542: 'generic',
#  543: 'disaster',
#  544: 'outshining',
#  545: 'rave',
#  546: 'menus',
#  547: 'sign',
#  548: 'Italian',
#  549: 'opened',
#  550: 'hate',
#  551: 'yay',
#  552: 'pleased',
#  553: 'final',
#  554: 'Coming',
#  555: 'overcooked',
#  556: 'outrageously',
#  557: 'received',
#  558: 'exquisite',
#  559: 'kind',
#  560: 'hour',
#  561: 'exceptional',
#  562: 'old',
#  563: 'places',
#  564: 'NYC',
#  565: 'tip',
#  566: 'empty',
#  567: 'come',
#  568: 'Food',
#  569: 'par',
#  570: 'Nargile',
#  571: 'taste',
#  572: 'bread',
#  573: 'overhaul',
#  574: 'Check',
#  575: 'despicable',
#  576: 'fact',
#  577: 'Frenchman',
#  578: 'decor',
#  579: 'then',
#  580: 'biggest',
#  581: 'MANAGEMENT',
#  582: 'bought',
#  583: 'limited',
#  584: 'eel',
#  585: '!',
#  586: 'reheated',
#  587: 'ladies',
#  588: 'couple',
#  589: 'mouths',
#  590: 'lack',
#  591: 'tater',
#  592: 'groups',
#  593: 'usual',
#  594: 'OVERPRICED',
#  595: 'almonds',
#  596: 'sewer',
#  597: 'Roll',
#  598: 'guy',
#  599: 'shall',
#  600: 'songs',
#  601: 'hello',
#  602: 'sub',
#  603: 'Cartel',
#  604: 'though',
#  605: 'tables',
#  606: 'how',
#  607: 'due',
#  608: 'name',
#  609: 'ways',
#  610: 'room',
#  611: 'Maybe',
#  612: 'vinegrette',
#  613: 'Philadelphia',
#  614: 'cheated',
#  615: 'half',
#  616: 'puréed',
#  617: 'capers',
#  618: 'overpriced',
#  619: 'had',
#  620: 'Crystals',
#  621: 'relax',
#  622: 'check',
#  623: 'typical',
#  624: 'chocolate',
#  625: 'generous',
#  626: 'NASTY',
#  627: 'set',
#  628: 'service',
#  629: 'puree',
#  630: 'sergeant',
#  631: 'all',
#  632: 'disappointing',
#  633: 'walls',
#  634: 'think',
#  635: 'fill',
#  636: 'tap',
#  637: 'fat',
#  638: 'boyfriend',
#  639: 'polite',
#  640: 'GO',
#  641: 'lawyers',
#  642: 'genuinely',
#  643: 'FANTASTIC',
#  644: 'patty',
#  645: 'Waitress',
#  646: 'past',
#  647: 'mistake',
#  648: 'grab',
#  649: 'ordering',
#  650: 'possible',
#  651: 'thirty',
#  652: 'Hiro',
#  653: 'they',
#  654: 'mostly',
#  655: 'immediately',
#  656: 'note',
#  657: 'living',
#  658: 'three',
#  659: 'probably',
#  660: 'Eew',
#  661: 'signs',
#  662: 'talk',
#  663: ')',
#  664: 'wall',
#  665: 'Omelets',
#  666: '.',
#  667: '...',
#  668: 'stinks',
#  669: 'unless',
#  670: 'treat',
#  671: 'thought',
#  672: 'businesses',
#  673: 'starving',
#  674: 'Why',
#  675: 'Highly',
#  676: 'head',
#  677: 'say',
#  678: 'vibe',
#  679: 'kid',
#  680: 'thick',
#  681: 'Overall',
#  682: 'food/service',
#  683: 'grease',
#  684: 'spaghetti',
#  685: 'overwhelmed',
#  686: 'BACK',
#  687: 'understand',
#  688: 'begin',
#  689: 'eat',
#  690: 'sangria',
#  691: 'douchey',
#  692: 'strange',
#  693: 'them',
#  694: 'dipping',
#  695: 'also',
#  696: 'It',
#  697: 'inspired',
#  698: 'drinks',
#  699: 'week',
#  700: 'a',
#  701: 'Flower',
#  702: 'sense',
#  703: 'ahead',
#  704: 'ventilation',
#  705: 'but',
#  706: 'over',
#  707: 'salad',
#  708: '20',
#  709: 'occasions',
#  710: 'up',
#  711: 'try',
#  712: 'dispenser',
#  713: 'beyond',
#  714: 'profiterole',
#  715: 'serivce',
#  716: 'Eggplant',
#  717: 'bother',
#  718: 'THIS',
#  719: 'decision',
#  720: 'writing',
#  721: 'anymore',
#  722: 'completely',
#  723: 'Horrible',
#  724: 'waiting',
#  725: 'petrified',
#  726: 'covered',
#  727: 'Burrittos',
#  728: 'pears',
#  729: 'ca',
#  730: 'handed',
#  731: 'croutons',
#  732: 'hooked',
#  733: 'relationship',
#  734: 'convenient',
#  735: 'Service-check',
#  736: 'truly',
#  737: 'Waiter',
#  738: 'especially',
#  739: 'anytime',
#  740: '&',
#  741: 'pizzas',
#  742: 'Joey',
#  743: 'unfortunately',
#  744: 'soggy',
#  745: 'clue',
#  746: 'crab',
#  747: 'under-services',
#  748: 'cheek',
#  749: 'Mellow',
#  750: 'app',
#  751: 'fail',
#  752: 'presentation',
#  753: 'Ha',
#  754: 'owner/chef',
#  755: 'flavorful',
#  756: 'milkshake',
#  757: 'to-go',
#  758: 'proclaimed',
#  759: 'Attack',
#  760: 'eating',
#  761: 'bird',
#  762: 'Very',
#  763: 'thing',
#  764: 'affordable',
#  765: 'Hot',
#  766: 'honest',
#  767: 'wedges',
#  768: 'count',
#  769: 'flirting',
#  770: 'making',
#  771: 'right',
#  772: 'biscuits',
#  773: 'rudely',
#  774: 'away',
#  775: 'point',
#  776: 'Go',
#  777: 'Vegetarian',
#  778: 'Francisco',
#  779: 'tummy',
#  780: 'definitely',
#  781: 'moist',
#  782: 'passed',
#  783: 'iced',
#  784: 'horrible',
#  785: 'in',
#  786: 'PEOPLE',
#  787: 'please',
#  788: 'steaks',
#  789: 'obviously',
#  790: 'Disappointing',
#  791: 'Gordon',
#  792: 'somethat',
#  793: 'Disappointed',
#  794: 'Google',
#  795: 'combo',
#  796: 'checked',
#  797: 'short',
#  798: 'revisiting',
#  799: 'accordingly',
#  800: 'Crust',
#  801: 'chip',
#  802: 'might',
#  803: 'crazy',
#  804: 'HANDS',
#  805: 'fuzzy',
#  806: 'other',
#  807: 'many',
#  808: 'mean',
#  809: 'made',
#  810: 'rude',
#  811: 'vain',
#  812: 'fun',
#  813: 'exactly',
#  814: 'delicate',
#  815: 'average',
#  816: 'considering',
#  817: 'held',
#  818: 'And',
#  819: 'brought',
#  820: 'butter',
#  821: 'store',
#  822: 'fiancé',
#  823: 'Dylan',
#  824: 'shopping',
#  825: 'literally',
#  826: 'refused',
#  827: 'Kabuki',
#  828: 'daily',
#  829: 'down',
#  830: 'redeeming',
#  831: 'last',
#  832: 'wonderful',
#  833: 'opposed',
#  834: 'Buldogis',
#  835: 'Baba',
#  836: 'imaginative',
#  837: 'helpful',
#  838: 'brunch',
#  839: 'mary',
#  840: 'We',
#  841: 'recall',
#  842: 'what',
#  843: 'grossed',
#  844: 'Steak',
#  845: "ya'all",
#  846: 'common',
#  847: 'GREAT',
#  848: 'They',
#  849: 'street',
#  850: 'Gave',
#  851: 'touched',
#  852: 'prefer',
#  853: 'gristle',
#  854: 'hit',
#  855: 'Japanese',
#  856: 'event',
#  857: 'cook',
#  858: 'neighborhood',
#  859: 'star',
#  860: 'First',
#  861: 'disappointed',
#  862: 'plantains',
#  863: 'etc',
#  864: 'Mediterranean',
#  865: 'INCONSIDERATE',
#  866: 'worst',
#  867: 'falafels',
#  868: 'gross',
#  869: 'money',
#  870: 'Favorite',
#  871: 'Awesome',
#  872: 'fish',
#  873: 'satifying',
#  874: 'Overpriced',
#  875: 'golden-crispy',
#  876: 'register',
#  877: 'Rice',
#  878: 'Mandalay',
#  879: 'one',
#  880: 'Camelback',
#  881: 'readers',
#  882: 'desired',
#  883: 'vomited',
#  884: 'Reasonably',
#  885: 'prepare',
#  886: 'bottom',
#  887: 'course',
#  888: 'waited',
#  889: 'always',
#  890: 'pasta',
#  891: 'outside',
#  892: 'refried',
#  893: 'greatest',
#  894: 'dripping',
#  895: 'Stopped',
#  896: 'parents',
#  897: 'cooking',
#  898: 'warmer',
#  899: 'sound',
#  900: 'oven',
#  901: '7',
#  902: '$',
#  903: 'wants',
#  904: 'Halibut',
#  905: 'his',
#  906: 'afternoon',
#  907: 'skimp',
#  908: 'informative',
#  909: 'low-key',
#  910: 'ranch',
#  911: 'Over',
#  912: 'Once',
#  913: 'little',
#  914: 'Have',
#  915: 'Rock',
#  916: 'ourselves',
#  917: 'CONCLUSION',
#  918: 'giving',
#  919: 'satisfied',
#  920: 'meet',
#  921: 'hottest',
#  922: 'favor',
#  923: 'FS',
#  924: 'be',
#  925: 'Rick',
#  926: 'spicier',
#  927: 'toro',
#  928: 'on',
#  929: 'cocktail',
#  930: 'expected',
#  931: 'tots',
#  932: 'glad',
#  933: 'could',
#  934: 'favorite',
#  935: 'non-customer',
#  936: 'allergy',
#  937: 'hard',
#  938: 'group',
#  939: '12',
#  940: 'joy',
#  941: 'gloves.Everything',
#  942: 'Owner',
#  943: 'WEAK',
#  944: 'did',
#  945: 'tiny',
#  946: 'stop',
#  947: 'disgust',
#  948: 'handled',
#  949: 'suck',
#  950: 'MGM',
#  951: 'stupid',
#  952: 'melted',
#  953: 'Ample',
#  954: 'FORWARD',
#  955: 'late',
#  956: 'Boy',
#  957: 'Toast',
#  958: 'Sour',
#  959: 'Nicest',
#  960: 'soundtrack',
#  961: 'these',
#  962: 'mmmm',
#  963: 'disgraceful',
#  964: 'Same',
#  965: 'soup',
#  966: 'wire',
#  967: 'disrespected',
#  968: 'Casino',
#  969: 'here',
#  970: 'ravoli',
#  971: 'Seriously',
#  972: 'Costco',
#  973: 'reminded',
#  974: 'wave',
#  975: 'house',
#  976: 'ten',
#  977: 'To',
#  978: 'showed',
#  979: 'greens',
#  980: 'wish',
#  981: 'forever',
#  982: '3/4ths',
#  983: 'daughter',
#  984: 'staff',
#  985: 'bigger',
#  986: 'in-house',
#  987: 'charged',
#  988: 'burger',
#  989: 'under',
#  990: 'Level',
#  991: 'Denny',
#  992: 'lighting',
#  993: 'contain',
#  994: 'our',
#  995: 'wings',
#  996: 'meatloaf',
#  997: 'guess',
#  998: 'This',
#  999: 'privileged',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
whole_words
# Out:
# {'lady',
#  'events',
#  'AVOID',
#  '....',
#  'thumbs',
#  'raspberry',
#  'connoisseur',
#  'when',
#  'box',
#  'unhealthy',
#  'Went',
#  'Taco',
#  'go',
#  'Stars',
#  'evening',
#  'similar',
#  'finish',
#  'tastings',
#  'decorated',
#  'warm',
#  'next',
#  'Outstanding',
#  'dates',
#  'beef',
#  'When',
#  'Everyone',
#  'correct',
#  'massive',
#  'hardly',
#  'Lox',
#  'restaurants',
#  'sever',
#  'Point',
#  'wine',
#  'without',
#  '11.99',
#  'gave',
#  'Tasty',
#  'Christmas',
#  'paid',
#  'Ganoush',
#  'bill',
#  'Poor',
#  'from',
#  'Last',
#  'rushed',
#  'space',
#  'nutshell',
#  'large',
#  'market',
#  'rings',
#  'definately',
#  'egg',
#  'legs',
#  'packed',
#  'die',
#  'myself',
#  'lot',
#  'buffets',
#  'stood',
#  'email',
#  'mein',
#  'bamboo',
#  'bar',
#  'foot',
#  'jerk',
#  'dinners',
#  'brownish',
#  'Always',
#  'pack',
#  'barely',
#  'authentic',
#  'perpared',
#  'drawing',
#  'joint',
#  'Soups',
#  'greasy',
#  'six',
#  'bathroom',
#  'roast',
#  'solid',
#  'almost',
#  'door',
#  'same',
#  'drunk',
#  '*',
#  'somewhat',
#  'weekend',
#  'problem',
#  'disappoint',
#  'Fridays',
#  'hearts',
#  'tapas',
#  'donut',
#  'lunch',
#  'imagined',
#  'providing',
#  'day',
#  'Veggitarian',
#  'hereas',
#  'Mary',
#  'today',
#  'impressive',
#  'SCREAMS',
#  'caterpillar',
#  'light',
#  'dressed',
#  'disagree',
#  'hands-down',
#  'certainly',
#  'attentive',
#  'crust',
#  'raving',
#  'speedy',
#  'naan',
#  'stomach',
#  'are',
#  'Tucson',
#  'struck',
#  'such',
#  'smoothies',
#  'meals',
#  'Standard',
#  'towards',
#  'between',
#  'trying',
#  'totally',
#  'Wo',
#  'end',
#  'pancake',
#  'airline',
#  'apparently',
#  'red',
#  'highly',
#  'Panna',
#  'Big',
#  'uploaded',
#  'baklava',
#  'equally',
#  'business',
#  'attached',
#  'Bean',
#  "'s",
#  'fails',
#  'shoots',
#  'over-whelm',
#  'Sadly',
#  'NO',
#  'expectations',
#  'Han',
#  'poisoning',
#  '2',
#  'sticks',
#  'Nan',
#  'jalapeno',
#  'chains',
#  'appetizers',
#  'Blah',
#  'portion',
#  'papers',
#  'grocery',
#  'pissd',
#  'tartare',
#  'mixed',
#  'discount',
#  'disappointment',
#  'personable',
#  'Then',
#  'Your',
#  'arrives',
#  'promise',
#  'anticipated',
#  'cold',
#  'Large',
#  'Which',
#  'covers',
#  'WILL',
#  'single',
#  'word',
#  'bartenders',
#  'small',
#  '6',
#  'Four',
#  'By',
#  'folks',
#  'Voodoo',
#  'take',
#  'Every',
#  'familiar',
#  'tasteless',
#  'hella',
#  'OMG',
#  'Nice',
#  'judging',
#  'WAAAAAAyyyyyyyyyy',
#  'sunglasses',
#  'spring',
#  'companions',
#  'fine',
#  'Sushi',
#  'patron',
#  'leave',
#  'real',
#  'bunch',
#  'serves',
#  'out',
#  'quality',
#  'sorely',
#  'idea',
#  'quit',
#  'ribeye',
#  'simple',
#  'uninspired',
#  'version',
#  'unexperienced',
#  'law',
#  '5',
#  'MUST',
#  'positive',
#  'Back',
#  'garden',
#  'profound',
#  'their',
#  "n't",
#  'These',
#  'thats',
#  'looking',
#  'Pizza',
#  'plus',
#  'amazing',
#  'friend',
#  'mom',
#  'letdown',
#  'The',
#  'Hard',
#  'him',
#  'believe',
#  'ball',
#  'took',
#  'stuff',
#  'outstanding',
#  'You',
#  '/hand',
#  'rest',
#  'takeout',
#  'yukon',
#  'callings',
#  'reasons',
#  'blanket',
#  'else',
#  'multiple',
#  'which',
#  'dessert',
#  'first',
#  'larger',
#  'work',
#  'besides',
#  'regular',
#  '8',
#  'cannoli',
#  'olives',
#  'lived',
#  'Bellagio',
#  'seasoned',
#  'each',
#  'Jeff',
#  'better',
#  'he',
#  '45',
#  'circumstances',
#  'clean',
#  'seemed',
#  'nay',
#  'Insults',
#  'muffin',
#  'lacking',
#  'correction',
#  'giant',
#  'Appetite',
#  'too',
#  'However',
#  'wrapped',
#  'beer',
#  'live',
#  'accountant',
#  'pepper',
#  'hole',
#  'strawberry',
#  'until',
#  'again',
#  'side',
#  'ever',
#  'pastry',
#  'above',
#  'ordered',
#  'either',
#  'breakfast',
#  'professional',
#  '15',
#  'read',
#  'whatsoever',
#  'sad',
#  'Eclectic',
#  'home',
#  'funny',
#  'high',
#  'asking',
#  'Noca',
#  'Greek',
#  'mussels',
#  'Yelpers',
#  'this',
#  'wines',
#  'deep',
#  'drag',
#  'tell',
#  'decent',
#  'want',
#  'ethic',
#  'sore',
#  'High-quality',
#  'edible',
#  'REALLY',
#  'turn',
#  'delight',
#  'Loved',
#  'Soi',
#  'beers',
#  'were',
#  'Heimer',
#  'Delicious',
#  'recommended',
#  'LEGIT',
#  'bars',
#  'teeth',
#  'saganaki',
#  'wildly',
#  'ALL',
#  'dedicated',
#  'why',
#  'nachos',
#  'second',
#  'changing',
#  'wontons',
#  'family',
#  'consider',
#  'smells',
#  'expert/connisseur',
#  'temp.I',
#  'experience',
#  'hostess',
#  'return',
#  'cover',
#  'itself',
#  'dealing',
#  'enjoyable',
#  'pneumatic',
#  'Seat',
#  'metro',
#  'Bacon',
#  'drastically',
#  'special',
#  'That',
#  'disgrace',
#  'Mom',
#  'cute',
#  'combination',
#  'sucker',
#  'flat',
#  'flair',
#  'most',
#  'suggestions',
#  'sexy',
#  'After',
#  'perfection',
#  'crusty',
#  'brisket',
#  'care',
#  'loves',
#  'mouth',
#  'Thai',
#  'unbelievable',
#  'happened',
#  '35',
#  'incredible',
#  'felt',
#  'Caesar',
#  'T.',
#  'pork',
#  'bloodiest',
#  'Baseball',
#  'bloddy',
#  'An',
#  'cocktails',
#  'during',
#  'Although',
#  'Phoenix',
#  'leftover',
#  'Sprouts',
#  'establishment',
#  'vegetables',
#  'Madison',
#  'compliments',
#  'sides',
#  'transcendant',
#  'about',
#  'Ians',
#  'welcome',
#  'bartender',
#  'deserves',
#  '70+',
#  'Elk',
#  'Chinese',
#  'who',
#  'restaraunt',
#  'mac',
#  'years',
#  'eggplant',
#  'lacked',
#  'play',
#  'courteous',
#  'front',
#  'dish',
#  'Bisque',
#  'visited',
#  'tepid',
#  '4.00',
#  'IN',
#  'Worst',
#  'whether',
#  'swung',
#  'North',
#  'tuna',
#  'Dos',
#  'Really',
#  'sucked',
#  'climbing',
#  'and',
#  'shoe',
#  'worries',
#  'ok',
#  'fruit',
#  'good',
#  'huge',
#  'done',
#  'show',
#  'may',
#  'Firehouse',
#  'dishes',
#  'section',
#  'including',
#  'nut',
#  'charcoal',
#  'loyal',
#  'char',
#  'expect',
#  'thanks',
#  'margaritas',
#  'atmosphere',
#  'piano',
#  'returning',
#  'offers',
#  'hungry',
#  'guests',
#  'cart',
#  'appetizer',
#  'Cod',
#  'does',
#  'dine',
#  'tried',
#  'area',
#  'complaints',
#  'tacos',
#  'court',
#  'article',
#  'pretty',
#  'Before',
#  'fan',
#  'ago',
#  'melt',
#  'awkwardly',
#  'Hopefully',
#  'happier',
#  'healthy',
#  'seriously',
#  'power',
#  'Sunday',
#  'lovers',
#  '%',
#  'largely',
#  'Las',
#  'calamari',
#  'winner',
#  'HAD',
#  'rubber',
#  'offered',
#  'accommodations',
#  'succulent',
#  'voted',
#  'Nothing',
#  'tops',
#  'Unfortunately',
#  'entire',
#  'No',
#  'Ramsey',
#  'human',
#  'son',
#  'bakery',
#  'grow',
#  'Filet',
#  'girlfriend',
#  'doughy',
#  'blown',
#  'Bunch',
#  'two',
#  'seasonal',
#  'peanuts',
#  'movies',
#  'closed',
#  'very',
#  'do',
#  'nigiri',
#  'heart',
#  'needs',
#  'fabulous',
#  'into',
#  'miss',
#  'shops',
#  'receives',
#  'guacamole',
#  'enjoyed',
#  'Dog',
#  'So',
#  'promptly',
#  'tomato',
#  'Maria',
#  'refill',
#  'specials',
#  'pleasure',
#  'pine',
#  'my',
#  'frustrated',
#  'generic',
#  'disaster',
#  'outshining',
#  'rave',
#  'menus',
#  'sign',
#  'Italian',
#  'opened',
#  'hate',
#  'yay',
#  'pleased',
#  'final',
#  'Coming',
#  'overcooked',
#  'outrageously',
#  'received',
#  'exquisite',
#  'kind',
#  'hour',
#  'exceptional',
#  'old',
#  'places',
#  'NYC',
#  'tip',
#  'empty',
#  'come',
#  'Food',
#  'par',
#  'Nargile',
#  'taste',
#  'bread',
#  'overhaul',
#  'Check',
#  'despicable',
#  'fact',
#  'Frenchman',
#  'decor',
#  'then',
#  'biggest',
#  'MANAGEMENT',
#  'bought',
#  'limited',
#  'eel',
#  '!',
#  'reheated',
#  'ladies',
#  'couple',
#  'mouths',
#  'lack',
#  'tater',
#  'groups',
#  'usual',
#  'OVERPRICED',
#  'almonds',
#  'sewer',
#  'Roll',
#  'guy',
#  'shall',
#  'songs',
#  'hello',
#  'sub',
#  'Cartel',
#  'though',
#  'tables',
#  'how',
#  'due',
#  'name',
#  'ways',
#  'room',
#  'Maybe',
#  'vinegrette',
#  'Philadelphia',
#  'cheated',
#  'half',
#  'puréed',
#  'capers',
#  'overpriced',
#  'had',
#  'Crystals',
#  'relax',
#  'check',
#  'typical',
#  'chocolate',
#  'generous',
#  'NASTY',
#  'set',
#  'service',
#  'puree',
#  'sergeant',
#  'all',
#  'disappointing',
#  'walls',
#  'think',
#  'fill',
#  'tap',
#  'fat',
#  'boyfriend',
#  'polite',
#  'GO',
#  'lawyers',
#  'genuinely',
#  'FANTASTIC',
#  'patty',
#  'Waitress',
#  'past',
#  'mistake',
#  'grab',
#  'ordering',
#  'possible',
#  'thirty',
#  'Hiro',
#  'they',
#  'mostly',
#  'immediately',
#  'note',
#  'living',
#  'three',
#  'probably',
#  'Eew',
#  'signs',
#  'talk',
#  ')',
#  'wall',
#  'Omelets',
#  '.',
#  '...',
#  'stinks',
#  'unless',
#  'treat',
#  'thought',
#  'businesses',
#  'starving',
#  'Why',
#  'Highly',
#  'head',
#  'say',
#  'vibe',
#  'kid',
#  'thick',
#  'Overall',
#  'food/service',
#  'grease',
#  'spaghetti',
#  'overwhelmed',
#  'BACK',
#  'understand',
#  'begin',
#  'eat',
#  'sangria',
#  'douchey',
#  'strange',
#  'them',
#  'dipping',
#  'also',
#  'It',
#  'inspired',
#  'drinks',
#  'week',
#  'a',
#  'Flower',
#  'sense',
#  'ahead',
#  'ventilation',
#  'but',
#  'over',
#  'salad',
#  '20',
#  'occasions',
#  'up',
#  'try',
#  'dispenser',
#  'beyond',
#  'profiterole',
#  'serivce',
#  'Eggplant',
#  'bother',
#  'THIS',
#  'decision',
#  'writing',
#  'anymore',
#  'completely',
#  'Horrible',
#  'waiting',
#  'petrified',
#  'covered',
#  'Burrittos',
#  'pears',
#  'ca',
#  'handed',
#  'croutons',
#  'hooked',
#  'relationship',
#  'convenient',
#  'Service-check',
#  'truly',
#  'Waiter',
#  'especially',
#  'anytime',
#  '&',
#  'pizzas',
#  'Joey',
#  'unfortunately',
#  'soggy',
#  'clue',
#  'crab',
#  'under-services',
#  'cheek',
#  'Mellow',
#  'app',
#  'fail',
#  'presentation',
#  'Ha',
#  'owner/chef',
#  'flavorful',
#  'milkshake',
#  'to-go',
#  'proclaimed',
#  'Attack',
#  'eating',
#  'bird',
#  'Very',
#  'thing',
#  'affordable',
#  'Hot',
#  'honest',
#  'wedges',
#  'count',
#  'flirting',
#  'making',
#  'right',
#  'biscuits',
#  'rudely',
#  'away',
#  'point',
#  'Go',
#  'Vegetarian',
#  'Francisco',
#  'tummy',
#  'definitely',
#  'moist',
#  'passed',
#  'iced',
#  'horrible',
#  'in',
#  'PEOPLE',
#  'please',
#  'steaks',
#  'obviously',
#  'Disappointing',
#  'Gordon',
#  'somethat',
#  'Disappointed',
#  'Google',
#  'combo',
#  'checked',
#  'short',
#  'revisiting',
#  'accordingly',
#  'Crust',
#  'chip',
#  'might',
#  'crazy',
#  'HANDS',
#  'fuzzy',
#  'other',
#  'many',
#  'mean',
#  'made',
#  'rude',
#  'vain',
#  'fun',
#  'exactly',
#  'delicate',
#  'average',
#  'considering',
#  'held',
#  'And',
#  'brought',
#  'butter',
#  'store',
#  'fiancé',
#  'Dylan',
#  'shopping',
#  'literally',
#  'refused',
#  'Kabuki',
#  'daily',
#  'down',
#  'redeeming',
#  'last',
#  'wonderful',
#  'opposed',
#  'Buldogis',
#  'Baba',
#  'imaginative',
#  'helpful',
#  'brunch',
#  'mary',
#  'We',
#  'recall',
#  'what',
#  'grossed',
#  'Steak',
#  "ya'all",
#  'common',
#  'GREAT',
#  'They',
#  'street',
#  'Gave',
#  'touched',
#  'prefer',
#  'gristle',
#  'hit',
#  'Japanese',
#  'event',
#  'cook',
#  'neighborhood',
#  'star',
#  'First',
#  'disappointed',
#  'plantains',
#  'etc',
#  'Mediterranean',
#  'INCONSIDERATE',
#  'worst',
#  'falafels',
#  'gross',
#  'money',
#  'Favorite',
#  'Awesome',
#  'fish',
#  'satifying',
#  'Overpriced',
#  'golden-crispy',
#  'register',
#  'Rice',
#  'Mandalay',
#  'one',
#  'Camelback',
#  'readers',
#  'desired',
#  'vomited',
#  'Reasonably',
#  'prepare',
#  'bottom',
#  'course',
#  'waited',
#  'always',
#  'pasta',
#  'outside',
#  'refried',
#  'greatest',
#  'dripping',
#  'Stopped',
#  'parents',
#  'cooking',
#  'warmer',
#  'sound',
#  'oven',
#  '7',
#  '$',
#  'wants',
#  'Halibut',
#  'his',
#  'afternoon',
#  'skimp',
#  'informative',
#  'low-key',
#  'ranch',
#  'Over',
#  'Once',
#  'little',
#  'Have',
#  'Rock',
#  'ourselves',
#  'CONCLUSION',
#  'giving',
#  'satisfied',
#  'meet',
#  'hottest',
#  'favor',
#  'FS',
#  'be',
#  'Rick',
#  'spicier',
#  'toro',
#  'on',
#  'cocktail',
#  'expected',
#  'tots',
#  'glad',
#  'could',
#  'favorite',
#  'non-customer',
#  'allergy',
#  'hard',
#  'group',
#  '12',
#  'joy',
#  'gloves.Everything',
#  'Owner',
#  'WEAK',
#  'did',
#  'tiny',
#  'stop',
#  'disgust',
#  'handled',
#  'suck',
#  'MGM',
#  'stupid',
#  'melted',
#  'Ample',
#  'FORWARD',
#  'late',
#  'Boy',
#  'Toast',
#  'Sour',
#  'Nicest',
#  'soundtrack',
#  'these',
#  'mmmm',
#  'disgraceful',
#  'Same',
#  'soup',
#  'wire',
#  'disrespected',
#  'Casino',
#  'here',
#  'ravoli',
#  'Seriously',
#  'Costco',
#  'reminded',
#  'wave',
#  'house',
#  'ten',
#  'To',
#  'showed',
#  'greens',
#  'wish',
#  'forever',
#  '3/4ths',
#  'daughter',
#  'staff',
#  'bigger',
#  'in-house',
#  'charged',
#  'burger',
#  'under',
#  'Level',
#  'Denny',
#  'lighting',
#  'contain',
#  'our',
#  'wings',
#  'meatloaf',
#  'guess',
#  'This',
#  'privileged',
#  ...}

# %%
sentence = corpus[0]
vector = np.zeros(len(whole_words))
for word in nltk.word_tokenize(sentence):
    if word in whole_words:
        vector
# Out:
# 2351

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            # word_index[word] 返回的是 index(每個單字相對應的 index)
            vector[word_index[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
