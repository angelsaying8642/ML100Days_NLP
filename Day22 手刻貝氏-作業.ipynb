# %% [markdown]
# # 手刻基本Naive Bayes模型

# %% [markdown]
# #### 學習重點：理解單純貝氏模型原理

# %% [markdown]
# ---

# %%
import re
import numpy as np
import math
import os
import glob
import codecs

from collections import defaultdict
from collections import Counter

def tokenize(message):
    message=message.lower()
    all_words=re.findall("[a-z0-9]+",message)
    return set(all_words)

# %% [markdown]
# ### 讀入資料並分割為 train/testset

# %%
X = []
Y = []
paths =[r'spam_data/spam', r'spam_data/easy_ham', r'spam_data/hard_ham'] # 設定路徑
# 讀取檔案
for path in paths:
    for fn in glob.glob(path+"/*"):
        if "ham" not in fn:
            is_spam = True
        else:
            is_spam = False
        #codecs.open可以避開錯誤，用errors='ignore'
        with codecs.open(fn,encoding='utf-8', errors='ignore') as file:
            for line in file:
                #這個line的開頭為Subject:
                if line.startswith("Subject:"): # 判斷字串開頭是否為該字元
                    subject=re.sub(r"^Subject:","",line).strip()
                    X.append(subject)
                    Y.append(is_spam)

# %%
X
# Out:
# ['Friend, Copy ANY DVD or Playstation Game with this software......',
#  '5% Guaranteed for Eight Years',
#  'Congratulations! You Get a Free Handheld Organizer!',
#  'One of a kind Money maker! Try it for free!',
#  'Online Doctors will fill your Viagra Prescription Now!!!                QEEB',
#  'Take your Marketing to the Next Level',
#  'One Sale - Three Commission Streams',
#  'Find Peace, Harmony, Tranquility, And Happiness Right Now!',
#  'ADV: Extended Auto Warranties Here                                                    undoc',
#  'Definitely the answer many have been waiting for!!',
#  "Save $100's, maybe $1,000's with No Lender's Fees. Click here!",
#  'Get the Computer Skills you need - Free',
#  '[WM] CEVIRI YAZILIMLARI',
#  'Let me know what you think!32482',
#  'International calls for only 33 cents per minute with no subscription',
#  'Garden Ornaments | ppu',
#  'A marketplace where lenders compete for your business LFHLXHU',
#  'Cheap Fags',
#  'Hey, rates are low. What are you waiting for?',
#  'One of a kind Money maker! Try it for free!',
#  '=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=',
#  '[ILUG-Social] Lose 22.5lbs in 3 weeks!',
#  'Outstanding Opportunities for "Premier Producers"',
#  'Re: girls',
#  'Attn:Targeted email addresses',
#  'Your eBay account is about to expire!',
#  '=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=',
#  'Act Now - Reach Hundreds of Prospects',
#  'Relationship',
#  'Re: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!    COXR',
#  'One of a kind Money maker! Try it for free!',
#  'NEU IM HANDEL! K1-Ausgabe Nr.66',
#  'FBI & IRS seized goods at 99% off! Police Auctions!',
#  'RE: Important Information Concerning Your Bank Account',
#  '[ILUG-Social] Poker for money againts real players',
#  '!Gorgeous,Custom Websites - $399 Complete! (4156cumG9-855YQKc5@17)',
#  'wives and girlfriends cheating and whoring around',
#  'Ou Wei Lighting,Nights Will Be Lightening!',
#  'The best possible mortgage',
#  '[ILUG] Re: This is NO JOKE! Speed up your CPU for under $30!',
#  'Re: Here is your Free Access',
#  '3 Cd Package: 300 Million Email Addresses + 1.5 Mil Fax Numbers $99.95',
#  'you can watch me',
#  'Up to $1,500.00 Part time                         22311',
#  'Let us find the right mortgage lender for you      AFPE',
#  'HOME REPS WANTED-FORTUNE 500 COMP HIRING',
#  'MSNBC: Rates Hit 35 year Low 4.75% ...12021',
#  'Re: Adult Classifieds',
#  'Term Insurance Is Out',
#  'GET IN AT THE TOP!',
#  'Get $100 Free - Beat the House at Royal Vegas!',
#  'HELP WANTED.  WORK FROM HOME REPS.',
#  'SPS se odrekao Slobodana Milosevica',
#  'Re: Want to go on a date?',
#  'Industry Forum #136',
#  'Get out of debt quick!                                        4179uKlj5-057SXua1524UHkC5-900-28',
#  'Dont waste your TIME!!! Why?',
#  'Powerball Results Saturday September 14, 2002 Estimated Jackpot $100 Million',
#  'MAKE MONEY GIVING AWAY FREE STUFF!',
#  'ANTICAIPTING TO HEARING FROM YOU SOON.',
#  'Everybody Gets Paid - No Recruiting Needed',
#  'Low Price Tobacco',
#  'CIGARETTES WHOLESALE!       HYWWZZLZD',
#  'Introducing Chase Platinum for Students with a 0% Introductory APR',
#  'Mothers you want to fuck',
#  "Newsletter Coach'Invest - Septembre 2002",
#  'Pics for you',
#  'Boost Your Cell Signal ...10782',
#  '[ILUG] Create a PAYCHECK with your COMPUTER and Enjoy Cheap ISP & shopping Discount.',
#  'Friend,Instantly Copy ANY DVD or Playstation Game with this software......',
#  'Partnership.',
#  'We Build The Internet.  WebXperts.com  (Design / Programming / Consultation)',
#  'URGENT BUSINESS ASSISTANCE.',
#  '[ILUG] Discount Fags',
#  '[ILUG] ilug,Bigger, Fuller Breasts Naturally In Just Weeks',
#  'FORTUNE 500 COMPANY HIRING, AT HOME REPS.',
#  '[ILUG] BUSINESS',
#  'MULTIPLY YOUR CUSTOMER BASE!',
#  '[ILUG-Social] Best Replica Goods - Best Prices',
#  "Join the Web's Hottest & Fastest Growing Community                     11.70",
#  'Slim Factors - A totally new approach to weight loss',
#  'Paperless Publishing is Here and Now',
#  'SPS se odrekao Slobodana Milosevica',
#  '[ILUG] re: popular .BIZ and .COM extensions for only $14.95',
#  'Fw: NORTON SYSTEMWORKS 2002 FINAL CLEARANCE SALE!           DJHL',
#  'Financial Power You Can Depend On',
#  'May I have a moment of your Time PLEASE',
#  'taint.org',
#  'Funds Investment',
#  'Re: zzzz@example.com',
#  'Shape up for summer now',
#  'Remeber me?',
#  '.Message report from your contact page....//ytu855 rkq',
#  'Market Internet Access - No Investment Needed',
#  'ADV: Promote Your Website!',
#  'Get the money you need while mortgage rates are down.',
#  'EIN News - FREE Trial',
#  'ADV: Extended Auto Warranties Here iubrq',
#  'Claim a Free $25 Kmart(R) Gift Card!',
#  'WWW Form Submission',
#  '[ILUG-Social] URGENT ASSISTANT NEEDED',
#  "UK's Leading PC Specialist",
#  'ADV: Extended Auto Warranties Here                                                   aanfh',
#  'Play a Hilarious Phone Prank',
#  'YOUR ACCOUNT HAS BEEN CLOSED!',
#  'BUSINESS PARTNERSHIP(URGENT/CONFIDENTIAL)',
#  'Get a FREE Bottle of Wine & Tasting Kit',
#  'Welcome to the concept of RESIDUAL Income!',
#  '<---- FREAK ME ---->',
#  '---> Undervalued Company',
#  'Please help Home Entertainment Companies with Survey - Win a DVR!',
#  're: domain registration savings',
#  '[WM] zr dileriz',
#  'zzzz, do we have your money?',
#  'Hosting from ?6.50 per month',
#  'Congratulations on Your 6 New Signups',
#  'Guaranteed Best Mortgage Rate',
#  'Re: SYSTEMWORKS CLEARANCE SALE_LIMITED QUANTITIES_ONLY $29.99 TJ',
#  'A must have for "Gadget" lovers 7134-4',
#  'zzzz,All New! Breast Enhancement',
#  'Attn: PROTECT YOURSELF AGAINST HARMFUL VIRUSES! SONLSNAIK',
#  '[ILUG] From the desk of : George Osawa',
#  '=?GBK?B?U3VuZnJvbSBsaWdodGluZyDE+rXEwvrS4srHztLDx9e3x/O1xMS/seo=?=',
#  'iiu.taint.org',
#  'FORTUNE 500 WORK AT HOME REPS NEEDED!',
#  'Vacation Time,House need work,Behind in Bills? Refinance while rates are low',
#  'Email Marketing',
#  '[ILUG] Seeking Your Partnership',
#  '(_) Increase Your Sales!!!!',
#  "** You're approved. **",
#  'Please help Home Entertainment Companies with Survey - Win a DVR!',
#  'Half Price Cigarettes and Tobacco',
#  'HELP WANTED.  WORK FROM HOME REPS.',
#  'Earn $139,000 a year as a DAY TRADER!',
#  "Unleash your PC's Multimedia POWER at 70% off retail!",
#  'are you in the mood             XGHTMTGGC',
#  '[scoop] ....It is not my fault. .- vwiid',
#  'Incredible Pictures!!!!!!!!',
#  'Ou Wei Lighting,Nights Will Be Lightening!',
#  '[ILUG] °ӷ~줽ǥX',
#  'Behind Every Elite Producer...',
#  'found a secret link   ADV',
#  'We Dare You to Find a Better Annuity',
#  'Did I give you the money yet?          DLRA',
#  'Adv: Mortgage Quotes Fast Online, No Cost',
#  'Approved Online, Internet, Buy Viagra              SJHFL',
#  'TEEN LESBIAN WEBSITE',
#  'The Best Critical Illness Policy on the Market',
#  'Guaranteed to lose 10-12 lbs in 30 days with Slim Patch                    10.24',
#  '=?Big5?B?rEKq96SjrE5+fqdPtsykRn5+?=',
#  'private',
#  'Shape up for summer now',
#  '[ILUG] STOP THE MLM INSANITY',
#  'Work at Home - $5000 a month',
#  'You have been hand selected... Free Info!',
#  'Get on the Bus.. gbvzzzz',
#  'University Diplomas',
#  'Free Shipping on all orders at Blair.com',
#  '8 Free Movie Tickets for doing a 2 Minute survey! Any Movie, Any Theater!',
#  'Your Shipment Status',
#  'Start Your Private Photo Album Online!                             13.200',
#  'Make a Fortune On eBay                         24772',
#  'Re: Super CHARGE your desktop or laptop today!     17639',
#  'The Government Grants You $25,000!',
#  'Free big cock in Pussy',
#  'http://www.efi.ie/',
#  'I just put my webcam on 4u hunnie=)',
#  'take advantage of this offer                24344',
#  'NEW TECHNOLOGY - DIGITAL VIDEO RECORDER (Smart IP Technology)',
#  'Immediate Reply Needed',
#  '=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=',
#  'Best Long Distance On the Net - 3.9 Cents With No Monthly Fees',
#  'WORK FROM HOME.  WE ARE HIRING',
#  'First Time Generic V*agra under $3 per 50mg',
#  '$14.95 per year for .COM, .BIZ, and .INFO extensions',
#  'Congratualtions zzzz8969 ! !!',
#  '-> IN THE NEWS TODAY <----',
#  'FW: SHORT TERM BUY RECOMMENDATION',
#  'One Sale - Three Commission Streams',
#  'Z-app the Competition with Roster',
#  'Join & Get 4 DVDs for 49 ea. (+shipping & processing)! Details Inside...',
#  'fwd:  NORTON SYSTEMWORKS CLEARANCE SALE!',
#  '[ILUG-Social] please kindly get back to me',
#  'Meet other Singles just like you',
#  'Chicago Meeting Site',
#  'A CRY FOR HELP',
#  'Make $500 - $2500/Week on Ebay                     3352',
#  "DON'T LET A COMPUTER VIRUS RUIN YOUR DAY!          12879",
#  'Email marketing info',
#  'NORTON SYSTEMWORKS 2002 CLEARANCE SALE! 6801wbRq4-940mJbj463-19',
#  'New Version 7: Uncover the TRUTH about ANYONE!',
#  '[ILUG-Social] HELLO',
#  '=?GB2312?B?NTDUqrvxtcPSu9LazuXHp83yRU1BSUy12Na3tcS7+rvh?=',
#  'A better investment than the stock market.',
#  "Join the Web's Fastest Growing Singles Community                       14.51",
#  'FREE Health Insurance Quotes',
#  'Welcome to OfferClub!',
#  'link to my webcam you wanted',
#  '11th Convergence India 2003 exhibition & conference',
#  'Hottest babes!                                                       4139YAEk3--9',
#  'Too Busy Earning A Living To Make Any Money',
#  'Attn: How about being a few pounds lighter?OLIBYKN',
#  'Make Huge Profits on eBay                          951',
#  'ADV: Extended Auto Warranties Here                                                   dhzbj',
#  'enter Chinese market',
#  'Make your prints beautiful & SAVE BIG!                 OYDQH',
#  'Get the Computer Skills you need - Free',
#  'Looking for property in SPAIN?',
#  '[ILUG] HELLO',
#  'Invite: Content Management Summit, Oct. 10th New York City',
#  'Interest Rates at Forty Yr. Lows',
#  "[ILUG] Join the Web's Fastest Growing Singles Community 11.67",
#  'MULTIPLY YOUR CUSTOMER BASE!',
#  'Attn: NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99!                  Y',
#  '[ILUG-Social] re: Guaranteed to lose 10-12 lbs in 30 days 10.148',
#  'Get your own fountain of youth! HGH human growth hormone from 21st Century!17441',
#  'Commissions Too High to Publish',
#  'Tell these cam sluts what to do',
#  '[ILUG-Social] urgent assistance',
#  'Market Internet Access - No Investment Needed',
#  'Information for you',
#  'Toners and inkjet cartridges for less....               NOAZ',
#  'MSNBC: Rates Hit 35 year Low 4.75% ...12304',
#  '[ILUG] Here is the information you requested',
#  'One of a kind Money maker! Try it for free!',
#  '[ILUG-Social] Claim Your $25 Kmart Gift Card',
#  'Get your OWN piece of history.',
#  'Poker for money againts real players',
#  'A revolution in the PC world has arrived.          RSIRTR',
#  'Teach and Grow Rich',
#  'Re: Fw: User Name & Password to Membership To 5 Sites zzzz@example.com pviqg',
#  'RE: Your Bank Account Information',
#  'Grow Up And Be A Man! abm',
#  'The DEBT-$AVER Program              SKYXTGM',
#  "Wall Street's dirty little secret ...",
#  'Funds Investment',
#  'Plans for cable',
#  'Attn: SYSTEMWORKS CLEARANCE SALE_ONLY $29.99                         12173',
#  'Life Insurance - Why Pay More?',
#  'ADV: Extended Auto Warranties Here hvgxs',
#  '=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=',
#  'eBay PowerSeller Secrets                         6826',
#  '[ILUG] enter Chinese market',
#  "ADV: Interest rates slashed! Don't wait!                                                   ccaxc",
#  '[ILUG-Social] Everybody Gets Paid - No Recruiting Needed',
#  '[ILUG] Best Replica Goods - Best Prices',
#  'This one will make you money  9/20/02 11:34:52 PM',
#  'Fw: VIRUS PROTECTION IS A MUST, YOU NEED SYSTEMWORKS! CPTJ',
#  '[scoop] CEVIRI YAZILIMLARI',
#  '[ILUG] Want to play poker with other people online.',
#  'Expand Your business with our Money!',
#  'Best Life Insurance, Lowest Cost...           NTICY',
#  '--> DIRECT MARKETING WILL INCREASE SALES           23875',
#  'MSNBC: Rates Hit 18 year Low 4.75% ...28940',
#  '=?big5?Q?re:=A7=DA=AA=BE=B9D=A7A=BB=DD=ADn=A7=F3=A6h=BE=F7=B7|,=A4@=B0_=A8=D3=A7a!?=',
#  'FW: Make Money Fast And Legal! As Seen on TV! 65000$+',
#  'Re: Ink Prices Got You Down?              11956',
#  'FREE WebBook Publishing Software - Download NOW!',
#  'New Insurance Product - No Competition',
#  'BIZ, .INFO, .COM for only $14.95',
#  '*****SPAM*****',
#  "Give Away FREE CD's - Earn $5K in 30 Days!",
#  '=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=',
#  'FREE HGH - Look 10 Years Younger in 3 Weeks!!!     HMUPRZD',
#  '[ILUG] WE NEED YOUR ASSISTANCE TO INVEST IN YOUR COUNTRY',
#  'Penile enlargement method - guaranteed !',
#  'Online Doctors will fill your Viagra Prescription Now!!!                QEEB',
#  'Get the Child Support You Deserve                      10.124',
#  'Double Your Life Insurance at NO EXTRA COST!...               TCTOOM',
#  'Collect Your Money! Time:1:30:33 AM',
#  'Adult: Free Access',
#  '**** American Millionaire Reveals His Secret Source of Wealth On The Internet!!!',
#  'Shipment Status',
#  'Your Gateway to Wealth',
#  'Never pay for porn again, YOUR FREE PAYSITE is here! 6277zwyL0-111bAgY1254IhZJ0-37-27',
#  'Fw: Re: Account For Cum Shots To: zzzz@example.com OfferID: qxjx',
#  'Online Doctors will fill your Viagra Prescription Now!!!                QEEB',
#  '[ILUG] $4,000/Month with your PC ! NO SPAM ! PLEASE READ !',
#  'Save 84% on CE Credits',
#  'new extensions now only $14.95',
#  'Testing a system, please delete',
#  'Low Price Smokes',
#  'zzzz,Your HGH Request!',
#  'Over $100,000 Per Year Possible On The Net!  No Illegal MLM Junk! Time:11:43:57 PM',
#  '!Gorgeous,Custom Websites - $349 Complete! (9009zRlD0-486vNhZ47@18)',
#  'Introducing HGH: The Most Powerful Anti-Obesity Drug Ever',
#  '=?big5?Q?=A7K=B6O=B5L=AD=AD=A6=B8=A5=F4=A5=B4=A4=A4=B4=E4=AA=F8=B3~=B9q=B8=DC?=',
#  'Hit the Road with CNA',
#  '6.50% Annuity w/4.05% Lifetime Bailout',
#  '[ILUG] IMPORTANT.',
#  'ADV: Lowest life insurance rates available!                                                   hsdpr',
#  'Herbal Viagra 30 day trial....                CRUA',
#  'Are you LOSING? The answer would amaze you!',
#  'Last time you spent $25 did u make $100,000,s? Well this time you will. wju',
#  '=?big5?Q?=A7A=B7=C7=B3=C6=A6n=A4F=B6=DC=3F?=',
#  'FORTUNE 500 WORK AT HOME REPS NEEDED!',
#  'Holidays are coming?',
#  'Never pay eBay listing fees again!',
#  '[WM] GREEN CARD CEKLS  KACIRMAYIN',
#  "Newsletter Coach'Invest - Septembre 2002",
#  'The TBA Doctor Walks the Walk on Diabetes',
#  'Free Merchant Account Information                XAXFT',
#  'Best product for 2002',
#  'Save now',
#  'Not too old to put out!                   26792',
#  "Don't get caught by rising interest rates.",
#  'REQUEST FOR MUTUALLY BENEFITTING ENDEAVOUR.',
#  '[ILUG] Get the Child Support You Deserve                     10.132',
#  'WARNING: Your computer may contain a virus!',
#  'ADV: Professional Teeth Whitening At Home!                                                   ovcnd',
#  'Account zzzz@example.com',
#  'The TBA Doctor Walks the Walk on Diabetes',
#  '**urgent assistance**',
#  '[ILUG] Earn 100.000$ in one year working at home',
#  'Are you ready for 10/5/2002?',
#  'New, easy to use web conferencing software',
#  'The "Business-Owner Friendly" Pension Plan',
#  'If You Dont... Your Competition Will!              7377',
#  '[ILUG] AWARD NOTIFICATION',
#  'Place Your LTC Declines with Us',
#  'FORTUNE 500 COMPANY HIRING, AT HOME REPS.',
#  'zzzz,All New! Breast Enhancement',
#  'URGENT ASSISTANCE(CONFIDENTIAL)',
#  'Attn: How about being a few pounds lighter?OLIBYKN',
#  'Teach and Grow Rich',
#  'Impaired Risk Case of the Month',
#  'Want to play poker with other people online.',
#  'Re: Instant Quote',
#  'FREE TRIAL - Last Stock pick UP 309%................................................. cqhcp',
#  'Customized Warez CDs',
#  "ADV: Interest rates slashed! Don't wait!                                                   xoxun",
#  'YOUR ANTICIPATED ASSISTANT IS REQUIRED.',
#  '60 minute free porn movie',
#  '.. kennst mich noch ? nehrb',
#  'FORTUNE 500 COMPANY HIRING, AT HOME REPS.',
#  'Order your Viagra and weight-loss here 6117kFvc5--9',
#  'I NEED AN URGENT CAPABLE ASSISTANCE.TEL:+225 05775748',
#  'Fw: PROTECT YOUR COMPUTER,YOU NEED SYSTEMWORKS!DGYWAOG',
#  'Re: What a night!',
#  'Earn 100.000$ in one year working at home',
#  'Mortgage Rates Are Down.                    ptjti',
#  'Impaired Risk Case of the Month',
#  '=?big5?Q?=A4=A3=AC=DD=B7|=AB=E1=AE=AC?=',
#  'Best news yet',
#  'Wanna see me get fisted?',
#  "Have you planned for your family's future?         ZBM",
#  'investment',
#  'WebDesignHQ Newsletter',
#  '[SAtalk] **urgent assistance**',
#  'LIE`S, MIS-INFORMATION and FRAUD',
#  'EnenKio truth (Answers)',
#  'Death of the Monarch of the Kingdom of EnenKio',
#  'Issuance of Gold Stamps',
#  'Advance Your Career and Find a Great Job!',
#  'Take Advantage of Viral Marketing',
#  '[]  ߴ  Best 5 & ڰ  ǳ',
#  'Go get em gadgets of 2002 4497VLNz2--9',
#  '[ILUG-Social] Need a Credit Card?',
#  "Save $30k even if you've refi'd           1090",
#  'Private Label Reseller Hosting  -  Expires 9/30/2002',
#  'Half Price Cigarettes and Tobacco',
#  '*Do Your Butt, Hips And Thighs Embarrass You?*',
#  '[ILUG-Social] re: how to register one of the new domain extensions',
#  "I'm ready to bare for you!",
#  'Discount Smokes',
#  'Incredible Pictures!!!!!!!!',
#  '[ILUG-Social] my webcam is on babe!',
#  '[ILUG] Garden Ornaments | mvcmv',
#  'Attn:Targeted email addresses',
#  'Better Sex for $2.99 until 08/26/2002 !!!!',
#  'fwd:  NORTON SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 7126kyiK0-697yFCQ4277rqZm-24',
#  '$10 a hour for watching e-mmercials! No joke!',
#  '[ILUG-Social] Low Price Tobacco',
#  'Funds Investment',
#  'FW: FOCUS ON VALUE',
#  'fwd:  SYSTEMWORKS CLEARANCE SALE_ONLY $29.99',
#  'FW: Washington wire',
#  'Competitive Mortgage Rates',
#  'Tired of paying big bucks for cable',
#  'ADV: Extended Auto Warranties Here vfafu',
#  'you can watch me',
#  'NEED TO FIND SOMETHING?',
#  'Still looking for a house?',
#  "don't proscrastinate...it's only $14.95 per year",
#  'Wir suchen Erotikdarsteller!',
#  'Is Your Family Protected?',
#  'shop your loan to lenders for the best rate        OTQ',
#  'Re: Your bank account',
#  '=?big5?Q?re:=B7Q=ADn=ADP=B4I,=A7A=C1=D9=ADn=B5=A5=A6h=A4[?=',
#  'Look What Sandy is Doing in her DORM!!',
#  'ADV: Internet marketing & communications; earn $100k/year... uleio',
#  'You can gain from lowest interest rates in 30 years',
#  'Sexabenteuer gefllig?',
#  'Incredible Pictures!!!!!!!!',
#  'Adv: Mortgage Quotes Fast Online, No Cost',
#  'Printer Cartridges as low as $1.21 each!',
#  'Play a Hilarious Phone Prank',
#  'Special Affiliate Offers from Amazon.Com!',
#  '[ILUG] ASSISTANCE',
#  'eBay, Be Debt Free by 2003!                      8119',
#  'Attn: NORTON SYSTEMWORKS 2002 BLOWOUT!                 QHZHC',
#  'How many "inches" do you need to satisfy a woman in bed?',
#  'Yeni srmde',
#  'Membership Renewal',
#  'Hi,  Low price  inkjet cartridges bvax',
#  'future business Ѻس!',
#  'FWD:Direct marketing is working                16889',
#  'Plans for cable',
#  'Order your Viagra and weight-loss here 6117kFvc5--9',
#  'Have You Dreamed Of Your Own Home Based Business?       eIExvv',
#  '[ILUG] please kindly get back to me',
#  'Huge natural tits',
#  'zzzz, Is Your web Site Making Money! 2:18:15 PM 8/25/2002',
#  'FREE Cell Phone + $50 Cash Back!',
#  'ADV:  Harvest lots of E-mail addresses quickly !',
#  'Re:[1]Save over $70 on this exquisite software suite. FTS',
#  'A CRY FOR HELP',
#  'Guaranteed to lose 10-12 lbs in 30 days                          11.150',
#  'CAREER OPPORTUNITY.  WORK FROM HOME',
#  'Tell Me Where to Send Your Health Card',
#  'The Best Just Got Better',
#  '^^^^^Cell Phone Belt Clips $1.95^^^^^^                           18070',
#  "** You're -Approved-!",
#  '=?GB2312?B?0rvN+KGwu92hsczsz8KjrNK71bnM7M/C1qotLS0tMjAwM8TqNNTCMcjVLS00?=',
#  'Re: Hi',
#  'Congratulations on Your 6 New Signups',
#  'Re: PROTECT YOUR COMPUTER AGAINST HARMFUL VIRUSES! 21198',
#  "What Warren Buffett won't tell ya ...",
#  'Internet News Feeds for Executives dfvht',
#  '[ILUG] BANK ERROR IN YOUR FAVOR',
#  'Custom Warez CDs',
#  'Teach and Grow Rich',
#  'Faeries',
#  'Re: This Weekend',
#  'Free Excerpt;  Baby Makers, Loser Choosers, & Welfare Abusers...Images of My America!',
#  '$250,000... as low as $6.50 per month.             edahx',
#  'FORTUNE 500 COMPANY HIRING, AT HOME REPS.',
#  'CyberAge Dating - Invitation from Jenny',
#  'ADV: Lowest life insurance rates available!                                                   pzcby',
#  'Re: You want sex? 7099ocYT9-261UccU3485gGCz0-11-27',
#  're:  SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 0989sqJ-7',
#  'Lenders WILL COMPETE for your mortgage             IVX',
#  'Seeking Your Partnership',
#  '[ILUG] assistance needed',
#  'Hgh: safe and effective release of your own growth hormone!30543',
#  'Membership Status Notification',
#  'Business Proposal.',
#  'Toners and inkjet cartridges for less....          BSJMCOIK',
#  'ADV: Are you protected? Free Life Insurance quote oefik',
#  'MSNBC: Rates Hit 35 year Low 4.75% ...12304',
#  'Never pay for the goodz again (8SimUgQ)',
#  'We Buy Renewal Commissions',
#  'The Flight to Safety is Upon Us',
#  '[ILUG] Create a PAYCHECK with your COMPUTER and Enjoy Cheap ISP & shopping Discount.',
#  'FriendSearch and zzzzason.org Partnership',
#  'Mothers you want to fuck',
#  'Got plans tonight?',
#  'Fwd: Norton makes the BEST software available, now ONLY $29.99! 32053',
#  'Life Insurance Quotes Without the Hassle...            JHIWNS',
#  'Attn: NORTON SYSTEMWORKS 2002 CLEARANCE SALE!              VOJTGT',
#  'Memory loss?',
#  'Iraq Today Daily News - FREE Trial',
#  'English Well for you?',
#  'zzzz,Hello',
#  '[ILUG] Guaranteed to lose 10-12 lbs in 30 days 10.206',
#  'ADV: Lowest Rates Available on Term Life - Free Quote                                                   ihsxq',
#  'Get the Child Support You Deserve                            11.180',
#  'More cash for the business you already write - IMMEDIATELY',
#  'Lease Deal',
#  'zzzz,Increase your breast size. 100% safe!',
#  'Best product for 2002',
#  'Fw: NORTON SYSTEMWORKS 2002 CLEARANCE SALE!        11058',
#  '[ILUG] (no subject)',
#  '=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=',
#  '$250,000 for only $6.50 per month.                    qkdjtqsscr',
#  'New Stock Pick: BBAN - Last Pick UP 309%.......................................... gsg',
#  'Sometimes Less is More...',
#  'Low Cost Easy to Use Conferencing',
#  'Conference calls/best quality/$.18 per minute!',
#  '[ILUG] MICHAEL ! ilug',
#  '[]  ߴ  Best 5 & ڰ  ǳ',
#  'Look What Sandy is Doing in her DORM!!',
#  'PROTECT YOUR INFORMATION AND YOUR COMPUTER',
#  '=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=',
#  'I was so scared... my very first DP',
#  'Low cost quality conference calls',
#  'Re:[1]Save over $70 on this exquisite software suite. 32004',
#  '[WM] greencard 2004 ekiliini karmayn',
#  'How would you like to create your own DVD library? 4863d-5',
#  '$14.95 per year domain names',
#  'online catalog of articles, adult toys 2009vjtt6-179dML-15',
#  'zzzz, do we have your money?',
#  'Re: Your VIP Pass',
#  "Pru Life's UL Portfolio Rocks",
#  'Guaranteed Best Mortgage Rate',
#  '[ILUG] Do NOT Drop your Life Insurance',
#  "you don't satisfy me               FGTPRIL",
#  'Re: Your bank account',
#  '[scoop] Haberdar olun',
#  'Have tax problems?',
#  '- Custom Websites for $399 Complete! (1709D@5)',
#  'See your Company sales sky rocket.                 4611',
#  'ADV: Lowest life insurance rates available!                                                   moode',
#  'Priceless Rubens works stolen in raid on mansion',
#  'Making a mesh on the move',
#  'Re: Sorting',
#  'RE: Java is for kiddies',
#  'Skateboarder drives-through Subway. With his face',
#  'Re: Canadians',
#  'Re: Ouch... [Bebergflame]',
#  'RE: [SAtalk] 2.41/2.50 spamd/spamc problem',
#  'RE: [SAtalk] 2.41/2.50 spamd/spamc problem',
#  '[SAtalk] 2.41/2.50 spamd/spamc problem',
#  'RE: dylsexics of the wrold, untie!',
#  '[SAtalk] procmail help',
#  'A Non-Integer Power Function on the Pixel Shader',
#  'Re: Comrade Communism (was Re: Crony Capitalism (was RE: sed',
#  'Re: [SAtalk] testing the install',
#  'Anolther sequence related traceback',
#  'Re: The case for spam',
#  'Re: EBusiness Webforms: cluetrain has left the station',
#  '[zzzzteana] Re: Megalithomania UnPissup',
#  '[zzzzteana] Bashing the bishop',
#  'Re: Entrepreneurs',
#  '[ILUG] doolin',
#  'Mathematics film-festival in October in Berkeley',
#  "Property rights in the 3rd World (De Soto's Mystery of Capital)",
#  'Re: [zzzzteana] The Cafe Forteana is back online!!!',
#  'More fun with the PTC',
#  'Hooters Air concept crashes and burns',
#  'Re: [Razor-users] Razor with sendmail',
#  'sylpheed-claws',
#  'SChoolHouseRocks DVD',
#  'Re: [zzzzteana] Save the planet, kill the people',
#  '[SAtalk] Re: Custom actions for high scoring spam',
#  'Native American economics (was Re: sed /s/United States/Roman',
#  'Re: SunMSapple meta4 of the day',
#  'Re: [Razor-users] "No razor servers available at this time"',
#  'RE: liberal defnitions',
#  'Two in court on IRA spy charges',
#  '[ILUG] Hayes Accura ISDN PCI',
#  'Human handshake opens data stream',
#  'Nobel prize for British and US scientists',
#  '[zzzzteana] White Horse vandalised',
#  'Re: [ILUG] adsl router modem combo',
#  'Kill Your Gods',
#  'Archaeological finds show that the Incas rode dinosaurs, science',
#  'Re: Canadians',
#  '[Razor-users] Razor and Pine',
#  'Re: Java is for kiddies',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'Re: [zzzzteana] The tenth planet',
#  '[Spambayes] deleting "duplicate" spam before training?  good idea',
#  'Re: Pluck and Luck',
#  '[Spambayes] Re: [Python-Dev] Getting started with GBayes testing',
#  'find the bug',
#  'Monkey or man?',
#  'Colophon 3',
#  'Quickly',
#  '"Free" Elvis Costello CD a trojan horse for DRM malware',
#  'New Gunner Gilberto is quick to earn his stripes',
#  'Fwd: Re[2]: AA Meetings the Hottest Place to Meet Women With Big',
#  '[zzzzteana] Worryingly sophisticated bees',
#  'Encryption approach to secure web applications',
#  'Harvest Moon',
#  'Movie Quiz',
#  'The case for spam',
#  "Steven Levy's wireless neighbors",
#  '[Spambayes] Deployment',
#  'Re: dylsexics of the wrold, untie!',
#  '[Spambayes] deleting "duplicate" spam before training?  good idea or',
#  'Re: Internet Archive bookmobile',
#  'RE: introductions',
#  'RE: introductions',
#  'MyIncErrors',
#  '[zzzzteana] Latest Iraq-related news',
#  'Re: [SAdev] Re: several messages',
#  'RE: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: The Wrong Business',
#  'Re: The Big Jump',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Blix told to await new orders on Iraq',
#  'Re[2]: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'GDC 2002: Game Scripting in Python',
#  'Re: RH 8 no DMA for DVD drive',
#  'UFOs in the Sky!',
#  "Sidekick's browser blows",
#  "Rats' intestines and pigs' teeth",
#  'RE: [ILUG] VPN implementation',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: Sorting',
#  'Get your own genome, feed your hypochondria',
#  'Re: Electric car an Edsel...',
#  'Re: lifegem',
#  'alsa-driver rebuild fails with undeclared USB symbol',
#  'Re: --with ...',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: Holidays for freshrpms.net :-)',
#  'Re: Sorting',
#  'Re: ARRRGHHH Had GPG working, now it doesnt.',
#  'ru stupid',
#  'Accessibility watershed?',
#  'Netscape 7 Review',
#  'Re: exmh bug?',
#  'gpg test',
#  'Discussion',
#  'Skinny Acoustic Bass',
#  'Re: exmh bug?',
#  'to the courthouse',
#  "Postmortem: Ubi Soft China's Music Up -- Summer Rainbow",
#  'Re[2]: Oh my...',
#  'Re: Linking message [was: Re: Patch to complete a change...]',
#  'Re: alsa-driver.spec tweak for homemade kernels',
#  'Re: [Razor-users] Collision of hashes?',
#  '[IRR] [dgc.chat] First public release of NeuDist Distributed',
#  '[dgc.chat] First public release of NeuDist Distributed Transaction',
#  'TheThresher',
#  'Google? Not in China',
#  '[Spambayes] spambayes package?',
#  'Re: [zzzzteana] Re: That wacky imam',
#  'Re: apt and a hybrid system',
#  'Automated forwarding',
#  'Doom 3',
#  'Re: CVS report',
#  'Tate unveils its biggest work',
#  'Encryption approach to secure web applications',
#  'West Nile vaccine "in three years"',
#  'RE: MIT OpenCourseWare',
#  'Re: RH 8 no DMA for DVD drive',
#  'Rendering the Great Outdoors: Fast Occlusion Culling for Outdoor',
#  'Fuzzy Math',
#  'Re: New Sequences Window',
#  'Re: [Webdev] mod_usertrack',
#  'Designer\'s Notebook: Stop Calling Games "Addictive"!',
#  'Re: traceback in new exmh',
#  'Re: RH 8 no DMA for DVD drive',
#  'RE: [SAtalk] O.T. Habeus -- Why?',
#  'xine src package',
#  'Computational Recreations',
#  'Jeremy Zawodny on life in Silicon Valley: "I came out here to',
#  "[SAdev] [Bug 1006] Spamassassin's build process makes packaging",
#  'Blair apologises for exam fiasco',
#  'Re: [ILUG] Retrieving read mail from webmail.eircom.net via POP ?',
#  'Re: Java is for kiddies',
#  "[SAdev] [Bug 1046] Errors from 'perl Makefile.PL'",
#  '[Spambayes] deleting "duplicate" spam before training?  good idea',
#  'Re: [SAtalk] Reject, Blackhole, or Fake No-User',
#  'At last, I have an excuse',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  'RE: [SAtalk] user_prefs ignored',
#  'Re: Wifi query',
#  'never a cent',
#  'There are four lights',
#  'alsaplayer for (null)',
#  'RE: Slaughter in the Name of God',
#  'customising FTOC display for specific folders...',
#  '[use Perl] Stories for 2002-08-30',
#  'kitty wants to play "eat your head"',
#  'Re: [SAtalk] Re: patent on TMDA-like system',
#  '[SAtalk] Re: patent on TMDA-like system',
#  '[use Perl] Headlines for 2002-08-27',
#  'Re: [SAdev] fully-public corpus of mail available',
#  'RE: DataPower announces XML-in-silicon',
#  'Oracle of Google',
#  'Re: alsa-driver.spec tweak for homemade kernels',
#  'Re: GA Development (was Re: [SAdev] [Bug 1030] NO_INVENTORY',
#  'Football players addicted to video football',
#  'Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41',
#  'Re: [SAdev] testing with less rules',
#  'Pix from Austin',
#  'ATT Wireless Location tracking',
#  'Carcooning',
#  '[use Perl] Headlines for 2002-09-01',
#  'Re: New Sequences Window',
#  '[SAdev] [Bug 828] spamassassin.org is unreliable',
#  '[SAdev] [Bug 1053] IMG tag based rules',
#  'Re: Automated forwarding',
#  'Re: --with ...',
#  '[Spambayes] spambayes package?',
#  'Re: [Razor-users] early experiences with Razor2 (and SA)',
#  'Re: exmh bug?',
#  'Re: ALSA Problem with Null kernel',
#  'Re: [ILUG] find the biggest file',
#  'Re: How unlucky can you get?',
#  'Re: [zzzzteana] Not a materialisation, but a transfiguration',
#  'Re: Anolther sequence related traceback',
#  'Re: [SAtalk] False Positive of the Week',
#  'Re: ALSA (almost) made easy',
#  'Re: A moment of silence for the First Amendment (fwd)',
#  'Re: Linking message [was: Re: Patch to complete a change...]',
#  'Duct-tapers -- suspension and bondage fetish goes mainstream',
#  '[zzzzteana] The new Steve Earle',
#  'Re: [SAdev] 2.41 release?',
#  'Re: asynchronous I/O (was Re: Gasp!)',
#  'Re: patent on TMDA-like system',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  "Lance Knobel of Davos Newbies does a quick review of Tony Blair's",
#  'Apple Sauced...again',
#  '[Spambayes] testing results',
#  'Re: [VoID] a new low on the personals tip...',
#  'a problem with apt-get',
#  '[SACVS] CVS: spamassassin procmailrc.example,1.3,1.3.2.1',
#  'ActiveBuddy',
#  '[zzzzteana] A New Theory on Mapping the New World',
#  'Re: [zzzzteana] Nothing like mama used to make',
#  'Re: Apple Sauced...again',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: [ILUG] Using Normal IDE Device with a Dell Latitude CPx laptop',
#  'Re: Sorting',
#  'Troubled Royal Ballet eyes US director',
#  "Re: SF Weekly's Ultimate SF Date lineup :-)",
#  'RE: [zzzzteana] Moon over ocean',
#  'Re: A biblical digression',
#  'Re: [SAdev] results of scorer evaluation',
#  'Mac OS X browsers',
#  'Internet Archive bookmobile',
#  'P2P slogans for EFF',
#  'FYI - gone this weekend',
#  'Re: New Sequences Window',
#  'Re: Another sequences window nit',
#  'Re: http://apt.nixia.no/',
#  'Why marching is crucial',
#  'Shooting from the Hip: An Interview with Hip Tanaka',
#  '[Spambayes] understanding high false negative rate',
#  'Re: /home/dude',
#  '[Spambayes] understanding high false negative rate',
#  'Sidekick, your mobile blogging pal',
#  'Re: apt 0.5.7 on RH 7.x',
#  '[SACVS] CVS: spamassassin spamassassin.raw,1.68.2.12,1.68.2.13',
#  '[zzzzteana] Punch bags filled with incontinence pads',
#  '[zzzzteana] Hitler-style applicant welcomed by parties',
#  'Re: [ILUG] eircoms adsl modems',
#  'Re: Google? Not in China',
#  'QOTD: Cigarettes, fast food, beer.',
#  'Re: Java is for kiddies',
#  'Re: ALSA (almost) made easy',
#  '[SAtalk] Running SA as a user app?',
#  'Re[3]: Selling Wedded Bliss (was Re: Ouch...)',
#  '[zzzzteana] Re: Australian Catholic Kiddie Perv Steps Aside',
#  'Re: Ouch...',
#  'Re: Digital radio playlists are prohibited?!',
#  'Apple Switch parodies',
#  'Re: Slaughter in the Name of God',
#  'Iowa: "There was frost outside this morning!"',
#  "Re: Signers weren't angry young men  (was: Java is for kiddies)",
#  'Saddam set to let inspectors in',
#  'Photoshop Theme.. ways to smuggle weapons-grade Uranium .',
#  'Digital service launches with 30 free channels',
#  'Re: Slaughter in the Name of God',
#  '"Free" Elvis Costello CD a trojan horse for DRM malware',
#  'Re: CD player UI for toddlers',
#  'EFnet #fork',
#  'Re: sed /s/United States/Roman Empire/g',
#  'US use of lie detector tests criticised',
#  'Turning junk computers into activist gold',
#  '[Spambayes] Deployment',
#  'Re: Patch to complete a change...',
#  'Re: [SAdev] 2.42 to come ?',
#  'Re: A moment of silence for the First Amendment (fwd)',
#  '[ILUG] Flat rate is back lads!',
#  'Blog de jeanpoole interviews Mark',
#  'The secret passion that staggered Westminster',
#  'Since we were on the subject...',
#  'Re: The case for spam',
#  'Content management for MP3s',
#  '[use Perl] Stories for 2002-08-31',
#  '[IMG: http://radio.weblogs.com/0001015/images/2002/09/25/uncSamMedium.gif',
#  'Linking message [was: Re: Patch to complete a change...]',
#  'Senators threaten to rein in Bush',
#  'Luggage falls from plane onto Salvation Army scattering used',
#  'Re: use of base image / delta image for automated recovery from',
#  'Re: dylsexics of the wrold, untie!',
#  'Product Review: Virtools Dev 2.0',
#  '[SAtalk] Huh?',
#  'DNA match brings breakthrough',
#  "Re: The Curse of India's Socialism",
#  'Re: [Razor-users] Razor with sendmail',
#  'Comrade Communism (was Re: Crony Capitalism (was RE: sed',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'I mean why not',
#  'Re: [ILUG] converting strings of hex to ascii',
#  "Great email from the RIAA's Hillary Rosen to execs at Yahoo,",
#  '[Razor-users] Problem with Razor 2.14 and Spamassassin 2.41',
#  "'Stay on to 70' call grows",
#  'Re: CD player UI for toddlers',
#  'UFOs in the Sky!',
#  'Re: mplayer not working for me',
#  'Re: [ILUG] find the biggest file',
#  'RE: Java is for kiddies',
#  'Re: Java is for kiddies',
#  'RE: sed /s/United States/Roman Empire/g',
#  'Re: [ILUG] Email list management howto',
#  'Re: sed /s/United States/Roman Empire/g',
#  'sed /s/United States/Roman Empire/g',
#  'Re: ALSA (almost) made easy',
#  'Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#  'Re: Ouch... [Bebergflame]',
#  '[SAtalk] www.spamassassin.org: giving a HTTP/1.1 error from',
#  'Re: Java is for kiddies',
#  'Re: [SAtalk] Re: fully-public corpus of mail available',
#  'Bush blew take two',
#  'IMF shores up debt defences',
#  'Re: ActiveBuddy',
#  '[zzzzteana] Cambodian Buddhaas unearthed',
#  '[use Perl] Headlines for 2002-09-11',
#  'Re: Entrepreneurs',
#  'Pitch Dark Bar Opens for Blind Dates',
#  'Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'RE: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'Re: AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  "Iraq invasion a 'hair-trigger' away",
#  'A Non-Integer Power Function on the Pixel Shader',
#  "I'm on TV tonight",
#  'RE: Headline - Navel gazing wins an Ig Nobel',
#  'Headline - Navel gazing wins an Ig Nobel',
#  'Re: Entrepreneurs',
#  'Google Domain Suffix Census',
#  'Oh my...',
#  "Don't do the brown WiFi, the brown WiFi is BAD",
#  'Re: Gabber packages for 8.0 (was: All set for Red Hat Linux 8.0)',
#  'Re: ARRRGHHH Had GPG working, now it doesnt.',
#  'Re: RedHat 8.0 and his own freetype',
#  'Bugbear email steals card data',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  '[Spambayes] Deployment',
#  "Major's shame over affair leaves Currie indignant",
#  '[SAtalk] Re: Too funny',
#  '[ILUG] Looking for a file / directory in zip file',
#  'Re[2]: A moment of silence for the First Amendment (fwd)',
#  'Colophon 1',
#  'Re: [SAtalk] help with postfix + spamassassin',
#  "Phil Wolff: Dave Winer books I'll buy. _Sweet! _",
#  'US rejects Iraq inspections deal',
#  'Er',
#  'Re: Electric car an Edsel...',
#  'Re: Electric car an Edsel...',
#  'Re: Electric car an Edsel...',
#  'And yet more absurdity.',
#  'Sun',
#  'Hurricane Lili closes shuttle Mission Control',
#  'calling wayne baisley@#!',
#  'Photoshop this squirrel tuning in, turning on, and dropping out',
#  'Priceless',
#  'Barney Not Found',
#  'Re: Insert signature',
#  '"Hidden tree" the secret of Zen garden',
#  'Re: Fw: Re: When are we going to get. [making ALSA rpms]',
#  'dvd::rip on Red Hat 8.0?',
#  'Re: RH 8 no DMA for DVD drive',
#  'AmeriCorpsVISTA',
#  'Re: New Sequences Window',
#  'Re: Please help a newbie compile mplayer :-)',
#  '[Spambayes] understanding high false negative rate',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: [ILUG] cups question',
#  'earthviewer apps Re: whoa',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  "Black entrepreneurs 'face bank bias'",
#  '[Spambayes] understanding high false negative rate',
#  'Peruvian congressman has challenged his Vice President to a duel.',
#  'No Blackpool illumination from these control freaks',
#  'Seaman recalled for Euro campaign',
#  "If it's too loud, you're too French",
#  'MySQL 4.1 Source Tree Available',
#  'Re: bad focus/click behaviours',
#  'Re: Exmh && speed',
#  'Adam dont job for no one, see.',
#  'Clarion comes to Australia!',
#  'Cat shot through eye with horse dart tranquilizer roams',
#  'Re: Re[3]: Selling Wedded Bliss (was Re: Ouch...)',
#  'RE: Goodbye Global Warming',
#  'Re: [ILUG] find the biggest file',
#  'Re: [SAdev] nightly mass-check and hit-frequencies',
#  'Re: Java is for kiddies',
#  'Re: sed /s/United States/Roman Empire/g',
#  'Re: boycotting yahoo',
#  'Fluxbox',
#  'New Solar System body revealed',
#  'Perl programmers are so cute',
#  'RE: Prob. w/ install/uninstall',
#  'Re: Prob. w/ install/uninstall',
#  'Re: Sorting',
#  '[zzzzteana] And deliver us from weevil',
#  '[Spambayes] test sets?',
#  '[Spambayes] test sets?',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: bad focus/click behaviours',
#  'Critical US satellites could be hacked',
#  'Mac OS X browsers',
#  'Re: The GOv gets tough on Net Users.....er Pirates..',
#  'Robbie Williams signs 80m deal',
#  'Re: Unseen window versus Sequences Window',
#  'Currie returns to pile scorn on Major',
#  '[Spambayes] deleting "duplicate" spam before training?  good idea',
#  'Re: traceback in new exmh',
#  'Re: Entrepreneurs',
#  'Re: use new apt to do null to RH8 upgrade?',
#  'Re: CD player UI for toddlers',
#  "World's funniest joke revealed",
#  '<nettime> The War Prayer',
#  '<nettime> The War Prayer',
#  'what is the sound of one knee jerking?',
#  'Please help a newbie compile mplayer :-)',
#  '<strong>Two New AmphetaDesk Hacks</strong>',
#  'Re: Selling Wedded Bliss (was Re: Ouch...)',
#  'Re: [ILUG] cheap linux PCs',
#  'UFOs in the Sky!',
#  'Re: New testing packages',
#  '[Spambayes] Ditching WordInfo',
#  "[IIU] Eircom aDSL Nat'ing",
#  'ALSA (almost) made easy',
#  'Re: [Razor-users] Razor: shall I use it with AMaViS or with',
#  'Big Five record companies guilty of price fixing',
#  'Re[3]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Ack, apt-get still failing for me, stumped. [RH8]',
#  'RE: Re[2]: A moment of silence for the First Amendment (fwd)',
#  'Re: sed /s/United States/Roman Empire/g',
#  'Re: The GOv gets tough on Net Users.....er Pirates..',
#  '[Spambayes] Deployment',
#  'Un',
#  'Re: [SAtalk] O.T. Habeus -- Why?',
#  '[Spambayes] Deployment',
#  'Re: Java is for kiddies',
#  '"I meditated in a cave for 12 years and now I\'m here to tell you',
#  'Re: The GOv gets tough on Net Users.....er Pirates..',
#  '[Spambayes] understanding high false negative rate',
#  '[SACVS] CVS: spamassassin/t db_based_whitelist.t,1.6.4.1,1.6.4.2',
#  'Malicious code hidden in email software',
#  'Re: [SAtalk] checking out Razor2 (and SA 2.41) install - Net::DNS:Resolver problem?',
#  '[use Perl] Stories for 2002-10-02',
#  "RE: Hanson's Sept 11 message in the National Review",
#  'Re: sed /s/United States/Roman Empire/g',
#  'RE: Java is for kiddies',
#  'RE: [ILUG] [OT] Dell machine giving me hassle.',
#  '[IRR] Re: The 3rd Annual Consult Hyperion Digital Identity Forum',
#  'Entrepreneurs',
#  '[use Perl] Headlines for 2002-10-03',
#  'RE: Java is for kiddies',
#  'Re: EBusiness Webforms: cluetrain has left the station',
#  'Re: ALSA (almost) made easy',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Oracle of Google',
#  'Re: RSA (repost)',
#  'Re: Entrepreneurs',
#  'Conversations From GDC Europe: Mark Cerny, Jonty Barnes, Jason',
#  'Re: Changed location of incoming mail. exmh not working!!',
#  'alsa-driver rebuild fails with undeclared USB symbol',
#  'Re: [ILUG] Sun Solaris..',
#  'RE: sprint delivers the next big thing??',
#  'Re: Oh ma gawd - funny site of the day...',
#  'Re: Optical analog computing?',
#  'Rapid immune reaction key to staving off AIDS',
#  '[Razor-users] "Can\'t use and undefined value.." error',
#  '[Razor-users] Exit.status =13 ?',
#  'Re: [Razor-users] Using razor with maildrop',
#  'Re: Googlecooking',
#  'Re: Computational Recreations',
#  'Deep-fried Twinkies take America by goo',
#  'Papon release prompts healthy scepticism',
#  'apt-get http fails',
#  'Re: [zzzzteana] Which Muppet Are You?',
#  'Re: Sorting',
#  'Daniel Berlinger has noticed that Mac software shops are starting',
#  '[Spambayes] Deployment',
#  "RE: Hanson's Sept 11 message in the National Review",
#  'Re: alsa-driver rebuild fails with undeclared USB symbol',
#  'Canadians',
#  'Fred Grott: How to Keep RDF and RSS Straight.',
#  'Kid crams acorn up his nose, hilarity ensues',
#  "Re: The Curse of India's Socialism",
#  'Re: Startups, Bubbles, and Unemployment (fwd)',
#  'Re: [SAtalk] SpamAssassin v2.40 released (finally)!',
#  'Re[2]: Selling Wedded Bliss (was Re: Ouch...)',
#  'Culture Jamming',
#  'Working My_Mark2CurSeen',
#  'Kissinger',
#  'Truck driver leaves trail of smelly pizza waste along major',
#  '[Spambayes] all but one testing',
#  'Viruses that also hack computers on the rise',
#  '[Razor-users] "No razor servers available at this time"',
#  'AA Meetings the Hottest Place to Meet Women With Big Bucks',
#  'Re: hauns_froehlingsdorf@infinetivity.com',
#  'Re: Lord of the Ringtones: Arbocks vs. Seelecks',
#  'Re: [ILUG] Interesting article on free software licences',
#  "Phil Wolff: Dave Winer books I'll buy. _Sweet! _",
#  'Re: CD player UI for toddlers',
#  'Re: [SAtalk] custom score for a given domain?',
#  '[Razor-users] Re: Can\'t use and undefined value.." error',
#  'plate tectonics update',
#  'Carcooning',
#  'Re: New Sequences Window',
#  'introductions',
#  'Re: [Razor-users] Fire.cloudmark.com is having issues',
#  'Re: Optical analog computing?',
#  'whoa',
#  'Re: revocation of grlygrl201@',
#  'Re: CVS report',
#  'RE: sprint delivers the next big thing??',
#  'Re: sprint delivers the next big thing??',
#  '[Spambayes] XTreme Training',
#  ...]

# %%
from sklearn.model_selection import train_test_split
# random_state 是為了讓各為學員得到相同的結果，平時可以移除
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
train_data = []
test_data = []

for x_, y_ in zip(X_train, y_train):
    train_data.append([x_, y_])

for x_, y_ in zip(X_test, y_test):
    test_data.append([x_, y_])

# %%
train_data
# Out:
# [['Re: CVS report', False],
#  ['[Spambayes] hammie.py vs. GBayes.py', False],
#  ['DVD stills', False],
#  ['RE: Microsoft buys XDegress - more of a p2p/distributed data thing...',
#   False],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['[Lockergnome Windows Daily]  Medieval Mocha', False],
#  ['Your Daily Dilbert 07/12/2002', False],
#  ['BUG REVIEW', False],
#  ["Re: SF Weekly's Ultimate SF Date lineup :-)", False],
#  ['Re: Canadians', False],
#  ['Cypriot leaders in last-ditch attempt at unification', False],
#  ['A revolution in the PC world has arrived.          RSIRTR', True],
#  ['Ou Wei Lighting,Nights Will Be Lightening!', True],
#  ['EBusiness Webforms: cluetrain has left the station', False],
#  ['Re: DataPower announces XML-in-silicon', False],
#  ['"I read that yesterday..."', False],
#  ['[SAdev] [Bug 1053] IMG tag based rules', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['[SACVS] CVS: spamassassin/masses mass-check,1.67,1.67.2.1', False],
#  ['Funds Investment', True],
#  ['Oh ma gawd - funny site of the day...', False],
#  ['Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#   False],
#  ['[Spambayes] understanding high false negative rate', False],
#  ['Re: [VoID] a new low on the personals tip...', False],
#  ['Re: [SAtalk] spamd error messages', False],
#  ["Man's leg is found 7 miles from a hit and run accident", False],
#  ['All digital', False],
#  ['Incredible Pictures!!!!!!!!', True],
#  ['Re: Slaughter in the Name of God', False],
#  ['Re: [ILUG] Email list management howto', False],
#  ['Business Proposal.', True],
#  ['Plan to recover nuclear gas rejected', False],
#  ['Re: [Razor-users] Collision of hashes?', False],
#  ['Random hack Q: drawing on CDs with lasers?', False],
#  ['Re: [Razor-users] Razor with sendmail', False],
#  ['[ILUG] Best Replica Goods - Best Prices', True],
#  ['How about subsidizing SSL access to Google?', False],
#  ['[ILUG] enter Chinese market', True],
#  ['REQ: Beast/BSE', False],
#  ['RE: Goodbye Global Warming', False],
#  ['"Cram school" operator arrested for trying to cram it into a 13', False],
#  ['Yoga & Painfree Bliss', False],
#  ['"A billion here, a billion there..."', False],
#  ['Football players addicted to video football', False],
#  ['[use Perl] Stories for 2002-10-07', False],
#  ['the Hello Kitty vibrator has competition', False],
#  ["Broadband ISPs wise up to wireless, defend (or don't) against hackers (CNET INTERNET SERVICES)",
#   False],
#  ['RE: Prob. w/ install/uninstall', False],
#  ['RE: Java is for kiddies', False],
#  ['Yahoo! News Story - Top Stories', False],
#  ['Lord of the Ringtones: Arbocks vs. Seelecks', False],
#  ['Re: sprint delivers the next big thing??', False],
#  ['Re: Want to go on a date?', True],
#  ['Upgrade', False],
#  ['Re: Should mplayer be build with Win32 codecs?', False],
#  ['Portillo dig at Blunkett in fringe double act', False],
#  ['Re: results for giant mass-check (phew)', False],
#  ['This week: Browse or bust', False],
#  ['RE: Slaughter in the Name of God', False],
#  ['ALSA (almost) made easy', False],
#  ['Re: Sorting', False],
#  ['Re: [zzzzteana] Illusionist emerges after 24 hours underwater', False],
#  ['Re: Alsa/Redhat 8 compatability', False],
#  ['Re: Entrepreneurs', False],
#  ['=?Big5?B?rEKq96SjrE5+fqdPtsykRn5+?=', True],
#  ['Re: [Razor-users] empty mail is spamm?', False],
#  ['Re: [SAdev] GA-assigned SPAM_PHRASE_55_XX score', False],
#  ['[Spambayes] spambayes package?', False],
#  ['60 minute free porn movie', True],
#  ["RE: Living Love - Another legacy of the 60's", False],
#  ['Re: bad focus/click behaviours', False],
#  ['[SACVS] CVS: spamassassin configure,1.1.2.1,1.1.2.2', False],
#  ['Priceless Rubens works stolen in raid on mansion', False],
#  ['Canadians', False],
#  ['FORTUNE 500 COMPANY HIRING, AT HOME REPS.', True],
#  ['[Spambayes] test sets?', False],
#  ['Re: [SAtalk] O.T. Habeus -- Why?', False],
#  ['Re: Goodbye Global Warming', False],
#  ['Re: xmms and .mp3 files.', False],
#  ['Re: use of base image / delta image for automated recovery from', False],
#  ['Accessibility watershed?', False],
#  ['Jeremy Bowers: "None of the trackback mechanisms has reached the', False],
#  ['Claim a Free $25 Kmart(R) Gift Card!', True],
#  ['Re: sylpheed-claws', False],
#  ['Re: [zzzzteana] The Coming Firestorm', False],
#  ['Re: Here is your Free Access', True],
#  ['RE: [ILUG] Drop in replacement for Ingres Database?', False],
#  ['[SACVS] CVS: spamassassin/masses parse-rules-for-masses,1.1.2.2,1.1.2.3',
#   False],
#  ['Re[2]: Java is for kiddies', False],
#  ['UBID Auction Alert', False],
#  ['[SAdev] [Bug 828] spamassassin.org is unreliable', False],
#  ['FriendSearch and zzzzason.org Partnership', True],
#  ['Re: [ILUG] Interesting article on free software licences', False],
#  ['Shooting from the Hip: An Interview with Hip Tanaka', False],
#  ["Right-wing governments 'increase suicide rates'", False],
#  ["Re: The Curse of India's Socialism", False],
#  ["'Bust' market closes two Powergen stations", False],
#  ['[Spambayes] XTreme Training', False],
#  ['Re: From', False],
#  ['Re: Electric car an Edsel...', False],
#  ['Re: All set for Red Hat Linux 8.0', False],
#  ['Automated 30 day renewal reminder 2002-05-27', False],
#  ['Mice born from rat-matured eggs', False],
#  ['Re: How about subsidizing SSL access to Google?', False],
#  ['Problem with an rpm...', False],
#  ['This Week: FileSystem, AppletFile, PHP Master Editor', False],
#  ['Advance Your Career and Find a Great Job!', True],
#  ['Robbie Williams signs 80m deal', False],
#  ['Re: Lord of the Ringtones: Arbocks vs. Seelecks', False],
#  ['SEVERE THUNDERSTORM WARNING UNTIL THU AUG 15 2002 05:45 PM EDT FOR 12144',
#   False],
#  ['Senators threaten to rein in Bush', False],
#  ['Play a Hilarious Phone Prank', True],
#  ['[zzzzteana] Re: Cincinnati Group Wants To Stamp Out Hotel Sex Movies',
#   False],
#  ['[ILUG] BUSINESS', True],
#  ["Re: SF Weekly's Ultimate SF Date lineup :-)", False],
#  ['Re: alsa-driver rebuild fails with undeclared USB symbol', False],
#  ['ActiveBuddy', False],
#  ['100 not safe for work pics for chicks. WEENERS.', False],
#  ['Re: "Ouch. Ouch. Ouch. Ouch. Ouch...."(was Re: My brain hurts)', False],
#  ['Why is it so hard to get a cab in San Francisco?', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['FWD:Direct marketing is working                16889', True],
#  ['[Spambayes] Maybe change X-Spam-Disposition to something else...', False],
#  ['Keeping up with The Sims: Managing Large Scale Game Content', False],
#  ['Re: [zzzzteana] FWD [fort] Evidence Britons Were In The US In The6th Century',
#   False],
#  ['There are four lights', False],
#  ['Re: Unseen window versus Sequences Window', False],
#  ['Re: exmh bug?', False],
#  ['Re: The GOv gets tough on Net Users.....er Pirates..', False],
#  ["CNET: Why I don't use firewalls", False],
#  ['Re: use new apt to do null to RH8 upgrade?', False],
#  ['Geneticists and a tiny worm win Nobel prize', False],
#  ['More fun with the PTC', False],
#  ['Re: [SAtalk] PerMsgStatus.pm error?', False],
#  ['New Google News', False],
#  ['Hooters Air concept crashes and burns', False],
#  ['Executive pay leaps ahead 17%', False],
#  ['Gold Lake Mountain Resort looks pretty gooood. Man there are a', False],
#  ['Ink is speech', False],
#  ['Working for the Mouse', False],
#  ['Re: use of base image / delta image for automated recovery from', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Re: EBusiness Webforms: cluetrain has left the station', False],
#  ['zzzz, do we have your money?', True],
#  ['Seeing is believing', False],
#  ['Re: [SAdev] SpamAssassin POP3 proxy', False],
#  ['Daniel Berlinger has noticed that Mac software shops are starting', False],
#  ['Man kills self with home booby-traps', False],
#  ['LIE`S, MIS-INFORMATION and FRAUD', True],
#  ['testing for taint.org, part 2', False],
#  ['[Razor-users] spamassassin+razor2', False],
#  ['RE: [zzzzteana] Moon over ocean', False],
#  ['Re: [SAtalk] False Positive of the Week', False],
#  ['[Spambayes] Current histograms', False],
#  ['RE: The absurdities of life.', False],
#  ['SoE at UCSC looking for an experienced IT support person', False],
#  ['Re: [Razor-users] razor plugins for mozilla?', False],
#  ['Harvest Moon', False],
#  ['Re: xine src packge still gives errors', False],
#  ['Let us find the right mortgage lender for you      AFPE', True],
#  ['[Spambayes] test sets?', False],
#  ['[dgc.chat] First public release of NeuDist Distributed Transaction', False],
#  ['[zzzzteana] Moscow bomber', False],
#  ['Linux-Announce Digest #180', False],
#  ['CNET NEWS.CONTEXT: Adios to options excess?', False],
#  ['Re: Goodbye Global Warming', False],
#  ['Re: asynchronous I/O (was Re: Gasp!)', False],
#  ['Origins of Software Engineering', False],
#  ['Re: Problem with an rpm...', False],
#  ['Pitch Dark Bar Opens for Blind Dates', False],
#  ["Pru Life's UL Portfolio Rocks", True],
#  ['Paul Everitt: Interop in the Bazaar.', False],
#  ['Re: New testing packages', False],
#  ["World's funniest joke revealed", False],
#  ['zzzz, do we have your money?', True],
#  ['Re: Re[3]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Congratulations on Your 6 New Signups', True],
#  ["Need a PDA that's more than a phonebook? (ZDNET SHOPPER)", False],
#  ['Re: whoa', False],
#  ['apt and a hybrid system', False],
#  ['[Spambayes] Deployment', False],
#  ['How would you like to create your own DVD library? 4863d-5', True],
#  ['a deadlock problem', False],
#  ['[SAtalk] Test spam', False],
#  ['Re: RH 8 no DMA for DVD drive', False],
#  ['ADV: Lowest life insurance rates available!                                                   moode',
#   True],
#  ['ru stupid', False],
#  ['Digital radio playlists are prohibited?!', False],
#  ['[ILUG] ASSISTANCE', True],
#  ['[zzzzteana] Fake bank website cons victims', False],
#  ['The Linux Counter...', False],
#  ['Plan', False],
#  ['Returned mail: [SACVS] CVS: spamassassin/masses craig-evolve.c.ALTIVEC,NONE,1.1',
#   False],
#  ['International calls for only 33 cents per minute with no subscription',
#   True],
#  ["'Stay on to 70' call grows", False],
#  ['[use Perl] Stories for 2002-09-04', False],
#  ['[NOVICE] pl/pgsql and returns timestamp type', False],
#  ['[ILUG] connecting at 1200bps in RH7.3 (help!)', False],
#  ['RE: Slaughter in the Name of God', False],
#  ['Re: [SAdev]  spam_level_char option change/removal', False],
#  ['FREE SHIPPING! No Minimum Purchase* at Buy.com', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Want to play poker with other people online.', True],
#  ['Houses rise 1,100 a week', False],
#  ['US blueprint for smallpox mass-vaccination', False],
#  ['Saddam set to let inspectors in', False],
#  ["Subject: There's still time to enter Lifetime's New Season Sweeps!", False],
#  ["Notes from OSXCon's DRM and Digital Hub panel", False],
#  ['Huge natural tits', True],
#  ['[Spambayes] deleting "duplicate" spam before training?  good idea', False],
#  ['Re: New gkrellm 2.0.0, gtk2 version', False],
#  ['Reclaiming privacy with laser-pointers', False],
#  ['Re: [zzzzteana] Bigfoot and big feet on display at Peabody', False],
#  ['Re: dylsexics of the wrold, untie!', False],
#  ['dvd::rip on Red Hat 8.0?', False],
#  ['Tibetans see hint of detente with China', False],
#  ['Re: New Sequences Window', False],
#  ['Fwd: Norton makes the BEST software available, now ONLY $29.99! 32053',
#   True],
#  ["Show-and-tell nearly extinct because it might hurt children's", False],
#  ["What Warren Buffett won't tell ya ...", True],
#  ['New Strongbad E-Mail', False],
#  ['Re: The GOv gets tough on Net Users.....er Pirates..', False],
#  ['Re: [zzzzteana] Save the planet, kill the people', False],
#  ['investment', True],
#  ['Photoshop Theme.. ways to smuggle weapons-grade Uranium .', False],
#  ['NYTimes.com Article: Stop Those Presses! Blonds, It Seems, Will', False],
#  ['Seaman recalled for Euro campaign', False],
#  ["SF Weekly's Ultimate SF Date lineup :-)", False],
#  ['Re: ALSA (almost) made easy', False],
#  ['[ILUG] Modem Problems', False],
#  ['RE: Java is for kiddies', False],
#  ['found a secret link   ADV', True],
#  ['QOTD: Cigarettes, fast food, beer.', False],
#  ["If it's too loud, you're too French", False],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Do you have a handlebar moustache? Then the Handlebar Club is the', False],
#  ['Re: Anolther sequence related traceback', False],
#  ['West Coast port closures may cancel Christmas.', False],
#  ['Re: [ILUG] Re: Sun Solaris', False],
#  ['Skateboarder drives-through Subway. With his face', False],
#  ['NYT discovers Linux in late 2002', False],
#  ['Danger Hiptop reviewed', False],
#  ['[use Perl] Headlines for 2002-09-10', False],
#  ["Re: The Curse of India's Socialism", False],
#  ['Fatal seal epidemic burns out', False],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Congratualtions zzzz8969 ! !!', True],
#  ['[ILUG] From the desk of : George Osawa', True],
#  ['RE: Recommended Viewing', False],
#  ['Re: Recommended Viewing', False],
#  ['Light reading', False],
#  ['New Sony Vaio: When small becomes TOO small [ANCHORDESK]', False],
#  ['Neutrino and X-ray physicists win Nobel Prize', False],
#  ['The case for spam', False],
#  ['Quickly', False],
#  ['Get the Computer Skills you need - Free', True],
#  ['Cloud of anti-atoms created', False],
#  ['Re: A moment of silence for the First Amendment (fwd)', False],
#  ['Re: RH 8 no DMA for DVD drive', False],
#  ['Get your OWN piece of history.', True],
#  ['Distributed.net cracks the RC5-64 cipher', False],
#  ['=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=', True],
#  ["Re: SF Weekly's Ultimate SF Date lineup :-)", False],
#  ['Shader Integration: Merging Shading Technologies on the Nintendo', False],
#  ['Re: [zzzzteana] The Cafe Forteana is back online!!!', False],
#  ['Collect Your Money! Time:1:30:33 AM', True],
#  ['RE: The absurdities of life.', False],
#  ["Von Neumann's Best Friend, a bio-pet", False],
#  ['Looks like Google did a deal to index the NY Times. If you do', False],
#  ['Canon USA Reseller News : July', False],
#  ['Re: New Sequences Window', False],
#  ['Re: revocation of grlygrl201@', False],
#  ['are you in the mood             XGHTMTGGC', True],
#  ['Re: ALSA (almost) made easy', False],
#  ['Mothers you want to fuck', True],
#  ['FW: [ILUG] Using Normal IDE Device with a Dell Latitude CPx lapto p',
#   False],
#  ['[zzzzteana] re: Steam', False],
#  ['AmeriCorpsVISTA', False],
#  ["Newsletter Coach'Invest - Septembre 2002", True],
#  ['Re: ARRRGHHH Had GPG working, now it doesnt.', False],
#  ['Re: bad focus/click behaviours', False],
#  ['Re: [zzzzteana] That wacky imam', False],
#  ['Re: A moment of silence for the First Amendment (fwd)', False],
#  ['Re: From', False],
#  ['GOVERNMENT REGULATION IS KILLING THE STOCK MARKET', False],
#  ['ADV:  Harvest lots of E-mail addresses quickly !', True],
#  ['p2p is not a crime', False],
#  ['Re: EBusiness Webforms: cluetrain has left the station', False],
#  ['Re: [ILUG] eircoms adsl modems', False],
#  ['Iowa: "There was frost outside this morning!"', False],
#  ['Sometimes Less is More...', True],
#  ['[Razor-users] "No razor servers available at this time"', False],
#  ['New Blog Category: Yahoo', False],
#  ['Re: traceback in new exmh', False],
#  ['http://apt.nixia.no/', False],
#  ['Since we were on the subject...', False],
#  ['[Spambayes] all but one testing', False],
#  ["Ecstasy users 'risk Parkinson's disease'", False],
#  ['Mass human sacrifice unearthed in Peru', False],
#  ['My Good Easy', False],
#  ['**** American Millionaire Reveals His Secret Source of Wealth On The Internet!!!',
#   True],
#  ['Re: Internet saturation (but not in Iceland)', False],
#  ['Better Sex for $2.99 until 08/26/2002 !!!!', True],
#  ['Re: [ILUG] Sun Solaris..', False],
#  ['RE: [SAtalk] separate inbound and outbound', False],
#  ['[Spambayes] Deployment', False],
#  ['Re: http://apt.nixia.no/', False],
#  ["Shop smarter with ZDNet's price-feature analysis", False],
#  ['[SAdev] [Bug 960] COMMENT low-performing rule pruned', False],
#  ['[use Perl] Headlines for 2002-09-01', False],
#  ['Re: [VoID] a new low on the personals tip...', False],
#  ['customising FTOC display for specific folders...', False],
#  ['Re: Java is for kiddies', False],
#  ['[Spambayes] understanding high false negative rate', False],
#  ['Re: xmms and .mp3 files.', False],
#  ['Keeping up with The Sims: Managing Large Scale Game Content', False],
#  ['[Razor-users] honor is not in csl', False],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Hype is all for tired old Panorama', False],
#  ['---> Undervalued Company', True],
#  ['[SAtalk] Re: [SAdev] 2.40 RELEASE PROCESS: mass-check status, folks?',
#   False],
#  ['Teach and Grow Rich', True],
#  ['[Spambayes] Deployment', False],
#  ['a problem with apt-get', False],
#  ['Personalize your Palm OS device', False],
#  ["Postmortem: Pixelogic's The Italian Job", False],
#  ["RE: Hanson's Sept 11 message in the National Review", False],
#  ['[zzzzteana] Pravda reports cities on the moon!', False],
#  ['Re: Nessus?', False],
#  ['Re: http://apt.nixia.no/', False],
#  ['Still hunting for the perfect RAM upgrade? (CNET SHOPPER)', False],
#  ["Month by month, 'Most Beautiful Man' winners and their galleries. sfw",
#   False],
#  ['THE WEEK IN REVIEW: Quit copying', False],
#  ['Re: [SAdev] results of scorer evaluation', False],
#  ['Are you ready for 10/5/2002?', True],
#  ['zzzz,All New! Breast Enhancement', True],
#  ['Re: AA Meetings the Hottest Place to Meet Women With Big Bucks', False],
#  ['Re: Zoot apt/openssh & new DVD playing doc', False],
#  ['RE: Our friends the Palestinians, Our servants in government.', False],
#  ['Re: [ILUG] Sun Solaris..', False],
#  ['RE: revocation of grlygrl201@', False],
#  ['DivX News: DivX Affiliate Program, Nobody in DivX, and New Player', False],
#  ['New toys', False],
#  ['Re: RSA (repost)', False],
#  ['Re: Oh my...', False],
#  ['dumb question: X client behind a firewall?', False],
#  ["Phil Wolff: Dave Winer books I'll buy. _Sweet! _", False],
#  ['Get your own fountain of youth! HGH human growth hormone from 21st Century!17441',
#   True],
#  ['Sexabenteuer gefllig?', True],
#  ['Act Now - Reach Hundreds of Prospects', True],
#  ['Re: sed /s/United States/Roman Empire/g', False],
#  ['Conference calls/best quality/$.18 per minute!', True],
#  ['Re: How unlucky can you get?', False],
#  ['Re: Bug report: msg n+1 marked read', False],
#  ["[IIU] Eircom aDSL Nat'ing", False],
#  ['Re: [ILUG] find the biggest file', False],
#  ['Re: [zzzzteana] Re: That wacky imam', False],
#  ['Catalog of Tomorrow released', False],
#  ['firewalls Digest V1 #33', False],
#  ['Re: My source: RE: A biblical digression', False],
#  ["Re: Hanson's Sept 11 message in the National Review", False],
#  ['HELP WANTED.  WORK FROM HOME REPS.', True],
#  ['Over $100,000 Per Year Possible On The Net!  No Illegal MLM Junk! Time:11:43:57 PM',
#   True],
#  ['Re: Sorting', False],
#  ['Encryption approach to secure web applications', False],
#  ['[Spambayes] Deployment', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ["Re: The Curse of India's Socialism", False],
#  ['[use Perl] Stories for 2002-09-20', False],
#  ['Re[3]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['[SAdev] [Bug 1008] SpamAssassin does not work with Glance for', False],
#  ['buffer overflows', False],
#  ['Photoshop Sean Connery giving us some good advice', False],
#  ['[Spambayes] understanding high false negative rate', False],
#  ['DataPower announces XML-in-silicon', False],
#  ['Recruiting for PAIII-IV Supervisor', False],
#  ["[SAdev] [Bug 805] Razor2 lookups don't work", False],
#  ['Re: rpm-zzzlist@freshrpms.net', False],
#  ['Re: Holidays for freshrpms.net :-)', False],
#  ['Jeremy Zawodny who works at Yahoo Finance offers an RSS 0.91 feed', False],
#  ['[ILUG] Re: serial console...not quite working', False],
#  ['RE: sprint delivers the next big thing??', False],
#  ['Re: f-rpm] Python 2.2 site libs?', False],
#  ['Re: bad focus/click behaviours', False],
#  ["Wrox Press Developer's Journal", False],
#  ['[Spambayes] test sets?', False],
#  ['alsaplayer for (null)', False],
#  ['Re: [Razor-users] spamassassin+razor2', False],
#  ['Blood pressure drugs "slow ageing"', False],
#  ['Re: New Sequences Window', False],
#  ['EFFector 15.24: EFF Submits Comments to FCC, Johansen Trial', False],
#  ['Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41', False],
#  ['Perl programmers are so cute', False],
#  ['[ILUG] Can I be added to your email distribution lists?', False],
#  ['Mortgage Rates Are Down.                    ptjti', True],
#  ['Booga', False],
#  ['[Razor-users] Razor 2.14 - the day after', False],
#  ['[use Perl] Stories for 2002-08-30', False],
#  ["Second-hand sales blamed for bedbugs' comeback", False],
#  ['hi', False],
#  ['[Spambayes] test sets?', False],
#  ['Anolther sequence related traceback', False],
#  ['[dgc.chat] First public release of NeuDist Distributed Transaction', False],
#  ['[IMG: http://radio.weblogs.com/0001015/images/2002/09/25/uncSamMedium.gif',
#   False],
#  ['[SAdev] [Bug 886] Add a rule to detect Content-type message/partial',
#   False],
#  ['Re: dumb question: X client behind a firewall?', False],
#  ['UFOs in the Sky!', False],
#  ['Send me this newsletter in TEXT format&#46;', False],
#  ['the walls are alive with the sound of insects', False],
#  ['NEWS.COM INVESTOR: Techs fall again with telecoms, Dow drops below 8K',
#   False],
#  ['Sun', False],
#  ['Re: use of base image / delta image for automated recovery from', False],
#  ['Re: Ouch...', False],
#  ['CNET NEWS.COM: Jobs touts OS X, iPods, iMac', False],
#  ['My OS X Keynote', False],
#  ['DNAT with iptables question', False],
#  ['Welcome to the concept of RESIDUAL Income!', True],
#  ['RE: Our friends the Palestinians, Our servants in government.', False],
#  ['Man finds lost marbles after 70 years....', False],
#  ['Farker Chakalasp dares you to Photoshop him', False],
#  ['[use Perl] Headlines for 2002-09-14', False],
#  ['Re: [ILUG] eircoms adsl modems', False],
#  ['liberal defnitions', False],
#  ['From', False],
#  ['Life Insurance - Why Pay More?', True],
#  ['[forteana] Fwd: Explorator 5.15', False],
#  ['RE: Goodbye Global Warming', False],
#  ['RE: use of base image / delta image for automated recovery from a', False],
#  ['Re: Sorting', False],
#  ['Re: storage bits', False],
#  ['Re: sed /s/United States/Roman Empire/g', False],
#  ['Turkey City Lexicon', False],
#  ['Microsoft buys XDegress - more of a p2p/distributed data thing...', False],
#  ['Re: ActiveBuddy', False],
#  ['Big Five record companies guilty of price fixing', False],
#  ['enter Chinese market', True],
#  ['xine src packge still gives errors', False],
#  ['[WM] greencard 2004 ekiliini karmayn', True],
#  ['ADV: Lowest life insurance rates available!                                                   pzcby',
#   True],
#  ['[ILUG-Social] Everybody Gets Paid - No Recruiting Needed', True],
#  ["Postmortem: Ubi Soft China's Music Up -- Summer Rainbow", False],
#  ['Re: RSA (repost)', False],
#  ['[zzzzteana] Height, weight, girth, etc', False],
#  ["Re: Hanson's Sept 11 message in the National Review", False],
#  ['[use Perl] Stories for 2002-08-18', False],
#  ['Re: Prob. w/ install/uninstall', False],
#  ['[zzzzteana] Which Muppet Are You?', False],
#  ['Promises.', False],
#  ['Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#   False],
#  ['Re: [Razor-users] Fire.cloudmark.com is having issues', False],
#  ['Re: Encryption approach to secure web applications', False],
#  ['[SAdev] [Bug 839] mailbox corruption not fixed with procmail 3.22', False],
#  ['Re: PROTECT YOUR COMPUTER AGAINST HARMFUL VIRUSES! 21198', True],
#  ['Dear Steve Jobs: At Macworld, show me this... [ANCHORDESK]', False],
#  ['Fake News Headlines: Basque Explosion Chases Ends In', False],
#  ['Core Java Technologies Tech Tips, September 10, 2002 (ArrayList vs. LinkedList, Zero-Length Arrays)',
#   False],
#  ['Re: Entrepreneurs', False],
#  ['The Analyst Primer', False],
#  ["[ILUG] The Age Old 'Which Mailer' Question", False],
#  ['Re: "Ouch. Ouch. Ouch. Ouch. Ouch...."(was Re: My brain hurts)', False],
#  ["I'm on TV tonight", False],
#  ['Attn: NORTON SYSTEMWORKS 2002 CLEARANCE SALE!              VOJTGT', True],
#  ['Re: Wifi query', False],
#  ['RE: [ILUG] [OT] Dell machine giving me hassle.', False],
#  ['Save now', True],
#  ['[ILUG] Marketing SIG has a good start :)', False],
#  ['Re: Automated forwarding', False],
#  ['Re: About apt, kernel updates and dist-upgrade', False],
#  ['Adv: Mortgage Quotes Fast Online, No Cost', True],
#  ['Congradulate Birthday Boy Putin. Link to send birthday wishes via', False],
#  ['Goodbye Global Warming', False],
#  ['3 Cd Package: 300 Million Email Addresses + 1.5 Mil Fax Numbers $99.95',
#   True],
#  ["Market Can't Find Its Bottom With Both Hands", False],
#  ['[Spambayes] test sets?', False],
#  ['Take all your music on the road (ZDNET SHOPPER)', False],
#  ['Re: RedHat 8.0 and his own freetype', False],
#  ['Boy shot at school gate', False],
#  ["I'm a tad furry...", False],
#  ['Reg Headlines Monday July 15', False],
#  ['Rail crash bereaved sue over line safety', False],
#  ['Re: Linking message [was: Re: Patch to complete a change...]', False],
#  ['RSS Critical Mass', False],
#  ['Re: [VoID] a new low on the personals tip...', False],
#  ['ADV: Internet marketing & communications; earn $100k/year... uleio', True],
#  ['CNET NEWS.COM: Canning spam without eating up real mail', False],
#  ['Re: bad focus/click behaviours', False],
#  ['RE: \x1b$B;0I)2=3X%(%s%8%K%"%j%s%0MM%W%m%;%9%@%&%s$K$D$$$F\x1b(B  - ticket',
#   False],
#  ['Re: ActiveBuddy', False],
#  ['Best Life Insurance, Lowest Cost...           NTICY', True],
#  ['[Razor-users] Forged email address', False],
#  ['[ILUG-Social] Need a Credit Card?', True],
#  ['[SACVS] CVS: spamassassin MANIFEST,1.100.2.11,1.100.2.12', False],
#  ['[Lockergnome Windows Daily]  Dignity Shakedown', False],
#  ['Kanu at the double', False],
#  ['Grow Up And Be A Man! abm', True],
#  ['Re[2]: Oh my...', False],
#  ['[use Perl] Stories for 2002-10-08', False],
#  ['use of base image / delta image for automated recovery from attacks',
#   False],
#  ['Labels shoot selves in foot by focusing on stopping P2P', False],
#  ['RE: Java is for kiddies', False],
#  ["Great email from the RIAA's Hillary Rosen to execs at Yahoo,", False],
#  ['[SAtalk] SA CGI Configurator Scripts', False],
#  ['[ILUG] Create a PAYCHECK with your COMPUTER and Enjoy Cheap ISP & shopping Discount.',
#   True],
#  ['Re: Optical analog computing?', False],
#  ['/home/dude', False],
#  ['Re: New Sequences Window', False],
#  ['Re: [VoID] a new low on the personals tip...', False],
#  ['Crony Capitalism (was RE: sed /s/United States/Roman Empire/g)', False],
#  ['Re: About apt, kernel updates and dist-upgrade', False],
#  ['Re: Snow', False],
#  ["America's great misleader", False],
#  ['[SAtalk] Re: Spamassassin-talk digest, Vol 1 #659 - 41 msgs', False],
#  ['Re: [ILUG] [OT] Dell machine giving me hassle.', False],
#  ['Family\'s "pet" raccoon attacks baby in crib', False],
#  ['"KICK ME"', False],
#  ['RE: [SAtalk] O.T. Habeus -- Why?', False],
#  ['Re: CD player UI for toddlers', False],
#  ['[zzzzteana] Bashing the bishop', False],
#  ['Fw: some (null) eyecandy packages', False],
#  ['Re: Sorting', False],
#  ['Re: dylsexics of the wrold, untie!', False],
#  ['Re: ALSA (almost) made easy', False],
#  ['[Razor-users] Problem with SDK 2.03?', False],
#  ['Re: revocation of grlygrl201@', False],
#  ['Re: ALSA (almost) made easy', False],
#  ['Approved Online, Internet, Buy Viagra              SJHFL', True],
#  ['ADV: Extended Auto Warranties Here                                                    undoc',
#   True],
#  ['Re: [SAdev] results of scorer evaluation', False],
#  ['Re: ALSA Problem with Null kernel', False],
#  ['Re: MIT OpenCourseWare', False],
#  ['Re: Super CHARGE your desktop or laptop today!     17639', True],
#  ['Sourceforge sells out', False],
#  ['Attn programmers: support offered [FLOSS-Sarai Initiative]', False],
#  ['[SACVS] CVS: spamassassin/lib/Mail SpamAssassin.pm,1.115.2.11,1.115.2.12',
#   False],
#  ['Re: boycotting yahoo', False],
#  ['Private Label Reseller Hosting  -  Expires 9/30/2002', True],
#  ['Re:[1]Save over $70 on this exquisite software suite. 32004', True],
#  ["Re: Signers weren't angry young men  (was: Java is for kiddies)", False],
#  ['Let me know what you think!32482', True],
#  ['California needs intelligent energy deregulation', False],
#  ["Re: Signers weren't angry young men  (was: Java is for kiddies)", False],
#  ['ADV: Extended Auto Warranties Here vfafu', True],
#  ['Apple: Heinous DVD Pirates', False],
#  ['Re: Ack, apt-get still failing for me, stumped. [RH8]', False],
#  ['RE: [ILUG] Newby to Linux looking for information on cvs', False],
#  ['Re: [SAdev] 2.42 to come ?', False],
#  ['Re: [zzzzteana] Bad Buffalo', False],
#  ['Insanely complicated', False],
#  ['RE: Goodbye Global Warming', False],
#  ['updated weblogs from blo.gs', False],
#  ["Kevin Mitnick's laptop, signed by Woz, on eBay", False],
#  ['[zzzzteana] Six arrested for attacking Palio jockey who defected', False],
#  ['Re: [ILUG] converting strings of hex to ascii', False],
#  ['Canadians', False],
#  ["Re: problems with 'apt-get -f install'", False],
#  ['ANTICAIPTING TO HEARING FROM YOU SOON.', True],
#  ['Go-ahead for new-style hospitals', False],
#  ['[Spambayes] Deployment', False],
#  ['Re: bad DCC traffic from e-corp.net', False],
#  ['Re: Insert signature', False],
#  ['Balloon flight challenges deflate', False],
#  ["Next MS Office? Here's what I'd add--and delete [ANCHORDESK]", False],
#  ['RE: [ILUG] [OT] Dell machine giving me hassle.', False],
#  ['Ultrasound blood purifier tackles fat problem', False],
#  ['Re: New testing packages', False],
#  ['Re: xmms and .mp3 files.', False],
#  ['Re: [SAtalk] Highest-scoring false positive', False],
#  ['re:  SYSTEMWORKS CLEARANCE SALE_ONLY $29.99 0989sqJ-7', True],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Low Cost Easy to Use Conferencing', True],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41', False],
#  ['Internet Archive bookmobile', False],
#  ['Re: lifegem', False],
#  ['[Spambayes] Deployment', False],
#  ['[zzzzteana] Lioness adopts fifth antelope', False],
#  ['One Sale - Three Commission Streams', True],
#  ['Vacation Time,House need work,Behind in Bills? Refinance while rates are low',
#   True],
#  ['[Lockergnome Tech Specialist]  Frequent Format', False],
#  ['Re: Sorting', False],
#  ['Re: [ILUG] converting strings of hex to ascii', False],
#  ['[Spambayes] Deployment', False],
#  ['You can gain from lowest interest rates in 30 years', True],
#  ['Olympus Brio D-100 1.3 MegaPixel Digital Camera: Starting Bid $99', False],
#  ['Information for you', True],
#  ["If you're going to turn on an electric pump to remove water from", False],
#  ['NEWS.COM INVESTOR: Techs slump with Intel', False],
#  ['Fight Piracy -- Regulate Potty Chairs!', False],
#  ['[Spambayes] Current histograms', False],
#  ['MAKE MONEY GIVING AWAY FREE STUFF!', True],
#  ['[Spambayes] Deployment', False],
#  ['[Lockergnome Tech Specialist]  Geothermal Caffeine', False],
#  ["Clinton: Blair's the man to trust", False],
#  ['[zzzzteana] A New Theory on Mapping the New World', False],
#  ['Halley: "When is someone going to create _audio fonts_ for', False],
#  ["Give Away FREE CD's - Earn $5K in 30 Days!", True],
#  ['Cosmic polarisation detected from South Pole', False],
#  ['Adams linked to IRA death squad', False],
#  ['10 die as Israeli helicopter fires on Palestinian crowd', False],
#  ['Comrade Communism (was Re: Crony Capitalism (was RE: sed', False],
#  ['Re: Goodbye Global Warming', False],
#  ["'Miracle' gene therapy trial halted", False],
#  ['Re: [SAdev] Re: [Razor-users] Mutating spam', False],
#  ['John Robb has an interesting perspective on trust-based,', False],
#  ['Wir suchen Erotikdarsteller!', True],
#  ['RE: [ILUG] VPN implementation', False],
#  ['Re: ActiveBuddy', False],
#  ['[SAdev] [Bug 1075] RPM build puts wrong path in the *.cf files', False],
#  ['[SAtalk] help with postfix + spamassassin', False],
#  ['[ILUG] Newbie seeks advice - Suse 7.2', False],
#  ["[IRR] Klez: The Virus That  Won't Die", False],
#  ['Re: ALSA (almost) made easy', False],
#  ['Apt 0.3 and 0.5', False],
#  ['earthviewer apps Re: whoa', False],
#  ['[Ximian Updates] Hyperlink handling in Gaim allows arbitrary code to be executed',
#   False],
#  ['Wired: "An urgent business proposition and requests for urgent', False],
#  ['[use Perl] Stories for 2002-09-13', False],
#  ['Reg Headlines Tuesday July 23', False],
#  ['[use Perl] Headlines for 2002-09-13', False],
#  ['[Spambayes] test sets?', False],
#  ['Ray Ozzie: Software Platform Dynamics.', False],
#  ['Re: Gabber packages for 8.0 (was: All set for Red Hat Linux 8.0)', False],
#  ['RH 8 no DMA for DVD drive', False],
#  ['Re: [ILUG] Seconds to date?', False],
#  ['Re: remove', False],
#  ['Mothers you want to fuck', True],
#  ['SPS se odrekao Slobodana Milosevica', True],
#  ['Re: [SAdev] 2.40: ready for release?', False],
#  ['=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=', True],
#  ['Re: sprint delivers the next big thing??', False],
#  ['Re[2]: [Razor-users] Reducing impact from tons of email', False],
#  ["Join the Web's Fastest Growing Singles Community                       14.51",
#   True],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['How the other half gives', False],
#  ['Play by Play: Effective Memory Management', False],
#  ['[SAtalk] moving SPAM: results to bottom of message.', False],
#  ['[ILUG] WE NEED YOUR ASSISTANCE TO INVEST IN YOUR COUNTRY', True],
#  ['Re: storage bits', False],
#  ['Re: [Razor-users] Razor and Pine', False],
#  ['Googlenews', False],
#  ["[vox] Anarchist 'Scavenger Hunt' Raises D.C. Police Ire (fwd)", False],
#  ['[Spambayes] stack.pop() ate my multipart message', False],
#  ["Re: Living Love - Another legacy of the 60's", False],
#  ['RE: [Razor-users] Fire.cloudmark.com is having issues', False],
#  ['Re: The Big Jump', False],
#  ['The Ryder Cup', False],
#  ['UCI Creative Writing', False],
#  ['Medical notes', False],
#  ['Term Insurance Is Out', True],
#  ['Central', False],
#  ['[zzzzteana] Cambodian Buddhaas unearthed', False],
#  ['Forged documents, public drinking, massive fistfights... Who knew', False],
#  ['[ILUG] Here is the information you requested', True],
#  ['UFOs in the Sky!', False],
#  ['Re: New testing packages', False],
#  ['Scientists prove that shoe size and penis size are not linked.', False],
#  ['Re: [SAtalk] PerMsgStatus.pm error?', False],
#  ['NY Times piece on reporters with weblogs.', False],
#  ['Colophon 1', False],
#  ['Re: Please help a newbie compile mplayer :-)', False],
#  ['Good Earnings Report', False],
#  ['latest php upgrade in 7.3', False],
#  ['Re: [ILUG] Formatting a windows partition from Linux', False],
#  ["RE: Hanson's Sept 11 message in the National Review", False],
#  ['CNET NEWS.COM: The tech side of homeland defense', False],
#  ['Re: Economist: Internet models, viral spread, social diseases', False],
#  ['[Spambayes] Deployment', False],
#  ['=?big5?Q?=A7K=B6O=B5L=AD=AD=A6=B8=A5=F4=A5=B4=A4=A4=B4=E4=AA=F8=B3~=B9q=B8=DC?=',
#   True],
#  ['[Spambayes] Deployment', False],
#  ['Re: [zzzzteana] Moon over ocean', False],
#  ['Re: CVS report', False],
#  ['[use Perl] Headlines for 2002-10-08', False],
#  ['Re: Recommended Viewing', False],
#  ['ADV: Extended Auto Warranties Here iubrq', True],
#  ['San Francisco caffeine tour', False],
#  ['Enlightenment', False],
#  ['[SAtalk] "Broken Pipe" on initial test', False],
#  ['Re: no matter where you go', False],
#  ['Re: [SAtalk] SA very slow (hangs?) on this message, or is it just me?',
#   False],
#  ['Check out the new CLIE PEG-T665C from Sony! (CNET SHOPPER)', False],
#  ['Re: RH 8 no DMA for DVD drive', False],
#  ['Introducing HGH: The Most Powerful Anti-Obesity Drug Ever', True],
#  ['Colophon 3', False],
#  ['Re: [Razor-users] Problem with Razor 2.14 and Spamassassin 2.41', False],
#  ['YOUR a STUPID Idj0t', False],
#  ['Maps', False],
#  ['[Lockergnome Digital Media]  Endorsed Compatibility', False],
#  ['Re: apt 0.5.7 on RH 7.x', False],
#  ['Re: Nessus?', False],
#  ['[SACVS] CVS: spamassassin/t db_based_whitelist.t,1.6.4.1,1.6.4.2', False],
#  ['Earn $139,000 a year as a DAY TRADER!', True],
#  ['Re: [SAtalk] O.T. Habeus -- Why?', False],
#  ['[ILUG] freeserve in the uk?', False],
#  ["'Seminal' eczema study reveals skin's broken defences", False],
#  ['Netscape 7 Review', False],
#  ['Re: /home/dude', False],
#  ['Re: [SAtalk] Bayesian and bogofilter', False],
#  ['[zzzzteana] Man admits Soham kidnapping hoax calls', False],
#  ['CNET NEWS.COM: Copies, Webcasts tangled in draft bill', False],
#  ['Re: Oh ma gawd - funny site of the day...', False],
#  ['CD player UI for toddlers', False],
#  ['Re: CVS report', False],
#  ['Re: [SAtalk] Re: patent on TMDA-like system', False],
#  ['Get the Computer Skills you need - Free', True],
#  ['Re: http://apt.nixia.no/', False],
#  ['Warchalking FAQ', False],
#  ['[Lockergnome Webmaster Weekly]  Educational Capabilities', False],
#  ['[ILUG] Using Normal IDE Device with a Dell Latitude CPx laptop', False],
#  ['Seeking Your Partnership', True],
#  ['Re: ActiveBuddy', False],
#  ['Re: Xine Dependencies', False],
#  ['Free Shipping on all orders at Blair.com', True],
#  ['Wedding music', False],
#  ['[Spambayes] Ditching WordInfo', False],
#  ['Re: Sorting', False],
#  ['Re: boycotting yahoo', False],
#  ['Intel 900MHz / 256MB PC-133 / 10X DVD / 20GB PC: Starting Bid $229', False],
#  ['dubyadubyadubya.dubyaspeak.com', False],
#  ['Hey, rates are low. What are you waiting for?', True],
#  ['RSS revolt', False],
#  ['Too Busy Earning A Living To Make Any Money', True],
#  ["Today's news: Serious PHP flaw found", False],
#  ['Re: About apt, kernel updates and dist-upgrade', False],
#  ['Re: [SAtalk] Reject, Blackhole, or Fake No-User', False],
#  ['Re: Working My_Mark2CurSeen', False],
#  ['Product Review: Virtools Dev 2.0', False],
#  ['Re: Adult Classifieds', True],
#  ['In praise of evolvable formats', False],
#  ['Re: no matter where you go', False],
#  ['[Spambayes] understanding high false negative rate', False],
#  ['Mystery Indian virus heading for Europe', False],
#  ["Disney's no-good Park-Czar replaced", False],
#  ['Re: ALSA (almost) made easy', False],
#  ['[zzzzteana] US Army tests portable translator', False],
#  ["Re: Apt repository authentication: it's time", False],
#  ['Re: [SAdev] Live Rule Updates after Release ???', False],
#  ['Photoshop the worlds ugliest truck', False],
#  ['Re: CD player UI for toddlers', False],
#  ['gkrellm 2 plugins?', False],
#  ['kitty wants to play "eat your head"', False],
#  ['Re: [ILUG] Newby to Linux looking for information on cvs', False],
#  ['Blair challenge to IRA', False],
#  ['[Razor-users] empty mail is spamm?', False],
#  ["Re: The Curse of India's Socialism", False],
#  ['Re: RedHat 8.0 and his own freetype', False],
#  ['[Spambayes] spambayes package?', False],
#  ['Re: mplayer not working for me', False],
#  ['FREE Cell Phone + $50 Cash Back!', True],
#  ['NEWS: GNU/DEVELOPMENT... intl orgns take a close look at GNU/Linux', False],
#  ['=?big5?Q?re:=A7=DA=AA=BE=B9D=A7A=BB=DD=ADn=A7=F3=A6h=BE=F7=B7|,=A4@=B0_=A8=D3=A7a!?=',
#   True],
#  ['Re: Secure Sofware Key', False],
#  ['Re: "requires:" and relational operators', False],
#  ['Re: [Razor-users] spamassassin+razor2', False],
#  ['Re: [zzzzteana] Not a materialisation, but a transfiguration', False],
#  ['The TBA Doctor Walks the Walk on Diabetes', True],
#  ['(_) Increase Your Sales!!!!', True],
#  ['Re: Zoot apt/openssh & new DVD playing doc', False],
#  ['Re: [SAdev] [Bug 735] spamassassin -t lies', False],
#  ['Re: apt 0.5.7 on RH 7.x', False],
#  ['[CYBERIA] [Final CfP]: Int. J. on IT Standards Research', False],
#  ['Re[2]: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Re: Fw: Re: When are we going to get. [making ALSA rpms]', False],
#  ["'I'm just an idiot'", False],
#  ['Not Many OS X Conference Blogs', False],
#  ['shop your loan to lenders for the best rate        OTQ', True],
#  ['never a cent', False],
#  ["CNET Cool Gear:  Leica's legendary charm", False],
#  ['United We Fall?', False],
#  ['catalogs.google.com - in time for xmas?', False],
#  ['Re: Entrepreneurs', False],
#  ['[zzzzteana] Betamax finally laid to rest', False],
#  ['[ILUG-Social] my webcam is on babe!', True],
#  ['Bright dust rings highlight Earth-like planets', False],
#  ['Re: Entrepreneurs', False],
#  ['Re: The Wrong Business', False],
#  ["Re: Apt repository authentication: it's time", False],
#  ['CNET NEWS.COM: Cable companies cracking down on Wi-Fi', False],
#  ['[zzzzteana] RE: Alexander', False],
#  ['Re: Tiny DNS Swap', False],
#  ['Gambler wins 7,000 - and spends it all on horse shiat', False],
#  ["Re: Hi! I'm new here.", False],
#  ['Our Dumb Pipeline', False],
#  ['Re: [SAdev] fully-public corpus of mail available', False],
#  ['Re: http://apt.nixia.no/', False],
#  ['Re: [SAtalk] Lotus Notes users?', False],
#  ['Life Insurance Quotes Without the Hassle...            JHIWNS', True],
#  ['Reuters: "Pets may not only provide good company for their', False],
#  ['Thanks to Jenny for the pointer to this Yale Law article about', False],
#  ['RE: Recommended Viewing', False],
#  ['Re: [SAtalk] dependencies / pre-requisites for installation in', False],
#  ['Re: The case for spam', False],
#  ['Reg Headlines Thursday July 11', False],
#  ['[ILUG] Got me a crappy laptop', False],
#  ['[zzzzteana] Crop Idol: Crop circle competition', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['taint.org', True],
#  ['AOL Keyword: Fraud Probe', False],
#  ['Re: Optical analog computing?', False],
#  ['Re: [SAtalk] Getting yourself removed from spam lists', False],
#  ['Take Advantage of Viral Marketing', True],
#  ['Dotcom Scoop: "CNET\'s Download.com is set to introduce a new', False],
#  ['Re: CD player UI for toddlers', False],
#  ['SOURCEFORGE.NET UPDATE: August 14, 2002', False],
#  ['Fluxbox', False],
#  ['Hgh: safe and effective release of your own growth hormone!30543', True],
#  ['Make a Fortune On eBay                         24772', True],
#  ['[SAtalk] updating SA', False],
#  ['[ILUG] Want to play poker with other people online.', True],
#  ["Triple your dial-up Web surfing speeds! Here's how [ANCHORDESK]", False],
#  ['AA Meetings the Hottest Place to Meet Women With Big Bucks', False],
#  ['[Spambayes] test sets?', False],
#  ['Re: K3B', False],
#  ['New P2P network funded by US government', False],
#  ['Re: lifegem', False],
#  ['First Time Generic V*agra under $3 per 50mg', True],
#  ['Re: bad focus/click behaviours', False],
#  ['Public domain superheroes reborn in Tom Strong', False],
#  ['Re: sed /s/United States/Roman Empire/g', False],
#  ['Bugbear email steals card data', False],
#  ['Re: boycotting yahoo', False],
#  ['Re: GA Development (was Re: [SAdev] [Bug 1030] NO_INVENTORY', False],
#  ["When search results don't count (Tech Update)", False],
#  ['Synthetic vitamin boosts bone growth', False],
#  ['Re: [SAtalk] My SA went crazy.', False],
#  ['Re: [VoID] a new low on the personals tip...', False],
#  ['8 Free Movie Tickets for doing a 2 Minute survey! Any Movie, Any Theater!',
#   True],
#  ['[ILUG] °ӷ~줽ǥX', True],
#  ['MyIncErrors', False],
#  ["Warplane system 'could stop mid-air explosions'", False],
#  ['Female circumcision does not reduce sexual activity', False],
#  ['Tiny DNS Swap', False],
#  ['[SAtalk] Huh?', False],
#  ['Re: [SAtalk] Ignore System Messages - How?', False],
#  ['Amorous ostriches scoop Ig Nobel prize', False],
#  ['=?big5?Q?=A4=A3=AC=DD=B7|=AB=E1=AE=AC?=', True],
#  ['Re: sed /s/United States/Roman Empire/g', False],
#  ['Training Courses in Python in UK', False],
#  ['RE: [SAdev] phew!', False],
#  ['Lenders WILL COMPETE for your mortgage             IVX', True],
#  ['Re: Java is for kiddies', False],
#  ['[zzzzteana] Re: Latest Iraq-related news', False],
#  ['Xine dependencies', False],
#  ['Five', False],
#  ['wifi progress', False],
#  ['Native American economics (was Re: sed /s/United States/Roman', False],
#  ['SunMSapple meta4 of the day', False],
#  ['Re: sed /s/United States/Roman Empire/g', False],
#  ['Patch to complete a change...', False],
#  ['Re: How unlucky can you get?', False],
#  ['Up to $1,500.00 Part time                         22311', True],
#  ['OSXCon Thoughts for Tuesday', False],
#  ['Polit-spam', False],
#  ['Davis stirs grassroots with right to buy promise', False],
#  ['Slim Factors - A totally new approach to weight loss', True],
#  ['Now we are 10', False],
#  ['Adult: Free Access', True],
#  ['MacNet Journal reports that OmniOutliner will support OPML soon.', False],
#  ['Re: ALSA (almost) made easy', False],
#  ['Re: K3B', False],
#  ['New Stock Pick: BBAN - Last Pick UP 309%.......................................... gsg',
#   True],
#  ['SChoolHouseRocks DVD', False],
#  ['Re: Ringing bell on other computer', False],
#  ['Re: All set for Red Hat Linux 8.0', False],
#  ['Rebuild at Ground Zero', False],
#  ['Re: Optical analog computing?', False],
#  ['[Razor-users] Fun Uses of Razored Mail', False],
#  ['Get the Child Support You Deserve                      10.124', True],
#  ['Re: http://apt.nixia.no/', False],
#  ['The DEBT-$AVER Program              SKYXTGM', True],
#  ['Re: [SAdev] phew!', False],
#  ['Your Daily Dilbert 07/18/2002', False],
#  ['Dinosaurs Eggs and the Origins of Good and Evil', False],
#  ['Re: apt and a hybrid system', False],
#  ['Hit the Road with CNA', True],
#  ['Re: Insert signature', False],
#  ['QOTD: Cigarettes, fast food, beer.', False],
#  ['[Spambayes] test sets?', False],
#  ['[SAtalk] 2.41/2.50 spamd/spamc problem', False],
#  ["Iraq invasion a 'hair-trigger' away", False],
#  ["Re: Tech's Major Decline", False],
#  ['A productive thread', False],
#  ['Re: Entrepreneurs', False],
#  ['Re[2]: A moment of silence for the First Amendment (fwd)', False],
#  ['[Spambayes] spambayes package?', False],
#  ['Re: [SAtalk] O.T. Habeus -- Why?', False],
#  ['new extensions now only $14.95', True],
#  ["I'm back in town...", False],
#  ["[zzzzteana] Compensation for World's youngest mother", False],
#  ['Expand Your business with our Money!', True],
#  ['Re: [SAtalk] Trend: Spam disguised as newsletters', False],
#  ['[Spambayes] timtest broke?', False],
#  ['Re: Selling Wedded Bliss (was Re: Ouch...)', False],
#  ['Tags reveal if frozen food is rotten', False],
#  ['Of Muslims and Morris men', False],
#  ['[use Perl] Headlines for 2002-09-20', False],
#  ['A different sort of Fox News', False],
#  ['NEU IM HANDEL! K1-Ausgabe Nr.66', True],
#  ['[SQL] Database joins', False],
#  ['Re: bad focus/click behaviours', False],
#  ['F2M - Ihre kostenlose Faxnummer - Newsletter', False],
#  ['RE: Goodbye Global Warming', False],
#  ['[NOVICE] pl/pgsql and returns timestamp type', False],
#  ['[Spambayes] Ditching WordInfo', False],
#  ['1987 copy of Nintendo zine going for $700 on eBay', False],
#  ['Priceless', False],
#  ['Re: Whitelisting (Re: [SAtalk] SA In The News)', False],
#  ['Family Targetted Advertising', False],
#  ['Re: EBusiness Webforms: cluetrain has left the station', False],
#  ['Googlecooking', False],
#  ["Classic Novels, Aesop's Fables, Issue 49", False],
#  ['Re: Optical analog computing?', False],
#  ['Brother, Can You Spare a Jet?', False],
#  ['Keillor voices up on what to do with the WTC site', False],
#  ['Re: New Sequences Window', False],
#  ['ADV: Professional Teeth Whitening At Home!                                                   ovcnd',
#   True],
#  ['bad focus/click behaviours', False],
#  ['Whither vCard?', False],
#  ['online catalog of articles, adult toys 2009vjtt6-179dML-15', True],
#  ["Don't do the brown WiFi, the brown WiFi is BAD", False],
#  ['Flying cars here, jetpacks next?', False],
#  ['[Spambayes] Current histograms', False],
#  ['[Lockergnome Windows Daily]  Beefier Vinyl', False],
#  ['Re: lifegem', False],
#  ['[Spambayes] testing results', False],
#  ['[zzzzteana] A Billy for the septics', False],
#  ['Best', False],
#  ['Re: [SAdev] Suggestion - 2 levels of Spam Status', False],
#  ['RE: [Razor-users] spamassassin+razor2', False],
#  ['Mplayer', False],
#  ['Currie returns to pile scorn on Major', False],
#  ['Re: Startups, Bubbles, and Unemployment (fwd)', False],
#  ['"Holiday Season" 2002 begins', False],
#  ['The Office: too painful to watch?', False],
#  ['[EVENT NOTIFICATION] UUnet North American Backbone Problems', False],
#  ['Think before you leap, man flies powered parachute into', False],
#  ['Re: The case for spam', False],
#  ['RE: [zzzzteana] Digest Number 2453', False],
#  ['[zzzzteana] Re: Megalithomania UnPissup', False],
#  ['On The Way to Telluride, On My Way Back to the World', False],
#  ['Incredible Pictures!!!!!!!!', True],
#  ['MULTIPLY YOUR CUSTOMER BASE!', True],
#  ['Re: Secure Sofware Key', False],
#  ['Apple Switch parodies', False],
#  ["[Spambayes] can't write to CVS...", False],
#  ['=?iso-2022-jp?B?GyRCJDckOCRfJEgkYiRiJE4lMyVpJVwlbCE8JTclZyVzGyhK?=', True],
#  ['11th Convergence India 2003 exhibition & conference', True],
#  ["Re: Hanson's Sept 11 message in the National Review", False],
#  ['=?ISO-2022-JP?B?GyRCTCQ+NUJ6OS05cCIoPF5HLiEqPVAycSQkJE45LT5sGyhC?=', True],
#  ['Why marching is crucial', False],
#  ['NY Times: "Google\'s automated editors appeared to match the work', False],
#  ['RE: [SAtalk] O.T. Habeus -- Why?', False],
#  ['Re: Mplayer', False],
#  ['Re: Goodbye Global Warming', False],
#  ['Four free e-mailers reviewed, Get the gear you need to burn DVDs', False],
#  ['Re: [SAtalk] Re: fully-public corpus of mail available', False],
#  ['Re: [SAtalk] Re: patent on TMDA-like system', False],
#  ['Re: Python 2.2 site libs?', False],
#  ['NEED TO FIND SOMETHING?', True],
#  ['Africa\'s deserts are in "spectacular" retreat', False],
#  ['Jakob Nielsen on Offshore Usability: "To save costs, some', False],
#  ['The ISO17799 Newsletter - Issue 4', False],
#  ['[zzzzteana] Language problems', False],
#  ['Re: RH 8 no DMA for DVD drive', False],
#  ['http://english.pravda.ru/main/2002/10/05/37771.html', False],
#  ['Fading blue', False],
#  ['[Razor-users] Bug ... still', False],
#  ['Cell phones coming soon', False],
#  ['Re: [SAtalk] Re: AWL bug in 2.42?', False],
#  ['Get a FREE Bottle of Wine & Tasting Kit', True],
#  ['Financial Power You Can Depend On', True],
#  ['Re: bad focus/click behaviours', False],
#  ['Re: Quick, Outlaw Touching', False],
#  ['$250,000 for only $6.50 per month.                    qkdjtqsscr', True],
#  ["Re: SF Weekly's Ultimate SF Date lineup :-)", False],
#  ['Re: ActiveBuddy', False],
#  ['[use Perl] Headlines for 2002-09-23', False],
#  ['[zzzzteana] Playboy wants to go out with a bang', False],
#  ['Teach and Grow Rich', True],
#  ['[Razor-users] Collision of hashes?', False],
#  ['RE: dylsexics of the wrold, untie!', False],
#  ['Italy goes over old battlegrounds', False],
#  ["Re: Hanson's Sept 11 message in the National Review", False],
#  ["Blatantly stolen from a friend's LJ", False],
#  ['Designer\'s Notebook: Stop Calling Games "Addictive"!', False],
#  ['RE: Recommended Viewing', False],
#  ['Rendering the Great Outdoors: Fast Occlusion Culling for Outdoor', False],
#  ['Re: Problem with an rpm...', False],
#  ['[SACVS] CVS: spamassassin spamassassin.raw,1.76,1.77', False],
#  ['Drivezilla -- 200GB Drives from Western Digital', False],
#  ['Re: [SAtalk] spamc -c problems on 2.41?', False],
#  ['Re: OSCOM Berkeley report: Xopus, Bitflux, Plone, Xoops', False],
#  ['Re: Prob. w/ install/uninstall', False],
#  ["Have you planned for your family's future?         ZBM", True],
#  ['Phone companies compared', False],
#  ['Re: Exmh && speed', False],
#  ['OO Programming Newsletter #41 from Bruce Eckel', False],
#  ['10 die as Israeli helicopter fires on Palestinian crowd', False],
#  ['Account zzzz@example.com', True],
#  ['Re: ALSA (almost) made easy', False],
#  ["DON'T LET A COMPUTER VIRUS RUIN YOUR DAY!          12879", True],
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ### defaultdict用法示範

# %%
counts=defaultdict()

# %%
counts['I'] = 2

# %%
counts
# Out:
# defaultdict(None, {'I': 2})

# %%
from collections import defaultdict

mess='This is our first time in Taiwan,,,,, such a beautiful contury'

counts=defaultdict(lambda:[0,0])
counts['you'][0]+=1
counts['hi'][0]+=1
counts['hi'][1]+=2
counts['no'][1]+=1
counts['no'][0]+=8
print('dic : {}'.format(counts))
print('you : {}'.format(counts['you']))
# Out:
# dic : defaultdict(<function <lambda> at 0x1a1709a7b8>, {'you': [1, 0], 'hi': [1, 2], 'no': [8, 1]})
# you : [1, 0]

# %% [markdown]
# ### 創造一個字典，裡面是{'hi': [1, 0]}，對應第一個數字是是垃圾郵件的次數，對應第二個數字是不是垃圾郵件的次數

# %%
def count_words(training_set):
    counts=defaultdict(lambda:[0,0])
    for message,is_spam in training_set:
        for word in tokenize(message):
            '''自行填入， list[0]為出現在spam中的次數，list[1]為出現在ham(非spam)中的次數'''
            counts[word][0 if is_spam == True else 1]+=1
    return counts

# %% [markdown]
# ---

# %% [markdown]
# ## 計算 p(w|spam) / p(w|non_spam)
# * 其中K為超參數，為了確保分母/分子皆不為0

# %%
def word_probabilities(counts,total_spams,total_non_spams,k=0.5):
    #獲得三組數據，分別為w這個字，p(w|spam)，p(w|non_spam)
    #counts[w][0]=spam,counts[w][1]=non_spam
    return [(w,(counts[w][0]+k)/(total_spams+2*k),(counts[w][1]+k)/(total_non_spams+2*k)) for w in counts]

# %% [markdown]
# ---

# %% [markdown]
# ## 計算貝氏結果

# %%
def spam_probability(word_probs,message, is_spam_probability, is_not_spam_probability):
    #先把這個mail的文字處理一下
    message_words=tokenize(message)
    #初始化值
    log_prob_if_spam=log_prob_if_not_spam=0.0
    #將w這個字，p(w|spam)，p(w|non_spam)依序引入
    for word,prob_if_spam,prob_if_not_spam in word_probs:
        if word in message_words:
            #假如這個字有在這個mail中出現
            #把他的p(w|spam)轉log值加上log_prob_if_spam
            log_prob_if_spam=log_prob_if_spam + math.log(prob_if_spam)
            #把他的p(w|non_spam)轉log值加上log_prob_if_not_spam
            log_prob_if_not_spam= log_prob_if_not_spam + math.log(prob_if_not_spam)
        else:
            #如果沒出現log_prob_if_spam➕上得值就是1-p(w|spam)也就是這封信是垃圾郵件但是w這個字卻沒在裡面
            log_prob_if_spam=log_prob_if_spam+math.log(1-prob_if_spam)
            log_prob_if_not_spam=log_prob_if_not_spam+math.log(1-prob_if_not_spam)
    # 表達的是P([x1,x2,x3...]|Yspam)*p(Yspam)
    log_prob_if_spam = log_prob_if_spam + math.log(is_spam_probability) 
    # 表達的是P([x1,x2,x3...]|Ynon-spam)*p(Ynon-spam)
    log_prob_if_not_spam = log_prob_if_not_spam + math.log(is_not_spam_probability) 
    
    #把+起來的值轉成exp再算NaiveBayes
    prob_if_spam=math.exp(log_prob_if_spam)
    prob_if_not_spam=math.exp(log_prob_if_not_spam)
    #貝氏
    return prob_if_spam/(prob_if_spam+prob_if_not_spam)

# %% [markdown]
# ---

# %% [markdown]
# ### 打包整個模型

# %%
class NaiveBayesClassifier:
    def __init__(self,k=0.5):
        self.k=k
        self.word_probs=[]
    def train(self,training_set):
        #訓練的資料格式為(message,is_spam)
        #所有垃圾郵件的數量
        num_spams=len([is_spam for message,is_spam in training_set if is_spam])
        #所有不是垃圾郵件的數量
        num_non_spams=len(training_set)-num_spams
        
        self.is_spam_probability = num_spams/ len(training_set)
        self.is_not_spam_probability = num_non_spams/  len(training_set)
        #把training_set裡面的所有字體轉成('Bad',num_is_spam,num_not_spam)
        word_counts=count_words(training_set)
        self.word_probs=word_probabilities(word_counts,num_spams,num_non_spams,self.k)
    def classify(self,message):
        return spam_probability(self.word_probs,message, self.is_spam_probability, self.is_not_spam_probability)

# %% [markdown]
# ---

# %% [markdown]
# ### Fit 訓練集

# %%
classifier=NaiveBayesClassifier()

# %%
classifier.train(train_data)

# %% [markdown]
# ### 預測

# %%
classified=[(subject,is_spam,classifier.classify(subject)) for subject,is_spam in test_data]
counts=Counter((is_spam,spam_probability>0.5) for _,is_spam,spam_probability in classified)

# %%
counts
# Out:
# Counter({(False, False): 578,
#          (False, True): 9,
#          (True, False): 41,
#          (True, True): 57})

# %%
precision=counts[(True, True)]/(counts[(True, True)]+counts[(False, True)])
recall=counts[(True, True)]/(counts[(True, True)]+counts[(True, False)])
binary_accuracy = (counts[(True, True)]+counts[(False, False)])/(counts[(False, True)]+counts[(False, False)]+counts[(True, True)]+counts[(True, False)])
print('accuracy : {:.2f}%'.format(binary_accuracy*100))
print('precision : {:.2f}%'.format(precision*100))
print('recall : {:.2f}%'.format(recall*100))
# Out:
# accuracy : 92.70%
# precision : 86.36%
# recall : 58.16%
